# %% [markdown]
# # Please read the [README](https://github.com/ibudiselic/covid/blob/master/README.md) file in this repository.

# %%
# Load all the data and functionality.
# %run lib.ipynb

countries_to_plot = ['Croatia', 'Sweden', 'Norway', 'Finland', 'Denmark', 'Iceland', 'Belgium', 'United Kingdom', 'Italy']

# %%
# %%javascript
# IPython.OutputArea.auto_scroll_threshold = 9999;

# %% [markdown]
# # Cross-country comparison over absolute dates

# %%
for series in ['confirmed', 'dead']:
    compare_countries_absolute_dates(series)
# Out:
# ## Confirmed
# ## Dead

# %% [markdown]
# # Cross-country comparison with approximately aligned start days

# %%
compare_countries_relative_dates('confirmed', start_info=(0.01, '10 confirmed per million'))
# Out:
# ## Confirmed

# %%
compare_countries_relative_dates('dead', start_info=(0.001, '1 death per million'))
# Out:
# ## Dead

# %% [markdown]
# # Per-country analysis with exponential and sigmoidal projections, and new cases analysis
#
# <span style="color:red;">
# IMPORTANT: The projections are only accurate if the fit is good (it often isn't), and assuming nothing changes
# going forward. The sigmoid is omitted if a reasonable fit can't be computed, but this still doesn't mean that
# the fit is good if it is shown.
# </span>
#
# The dashed lines show best fit projections from a few previous days for comparison.

# %%
for country in countries_to_plot:
    country_deep_dive(country)
# Out:
# ## Croatia
# Population \\(4,105,267\\)
# ### Confirmed
# Start date 2020-02-28 (1st day with 1 confirmed per million)
# Latest number \\(1,908\\) on 2020-04-21
# Best fit exponential: \(108 \times 10^{0.025t}\) (doubling rate \(12.2\) days)
# Best fit sigmoid: \(\dfrac{1,948.4}{1 + 10^{-0.071 (t - 35.1)}}\) (asimptote \(1,948.4\))
# ### Dead
# Start date 2020-03-19 (1st day with 0.1 dead per million)
# Latest number \\(48\\) on 2020-04-21
# Best fit exponential: \(2.39 \times 10^{0.040t}\) (doubling rate \(7.6\) days)
# Best fit sigmoid: \(\dfrac{78.5}{1 + 10^{-0.060 (t - 30.4)}}\) (asimptote \(78.5\))
# ### Active
# Start date 2020-02-28 (1st day with 1 active per million)
# Latest number \\(1,059\\) on 2020-04-21
# ## Sweden
# Population \\(10,099,265\\)
# ### Confirmed
# Start date 2020-02-29 (1st day with 1 confirmed per million)
# Latest number \\(15,322\\) on 2020-04-21
# Best fit exponential: \(569 \times 10^{0.028t}\) (doubling rate \(10.8\) days)
# Best fit sigmoid: \(\dfrac{19,800.6}{1 + 10^{-0.049 (t - 42.7)}}\) (asimptote \(19,800.6\))
# ### Dead
# Start date 2020-03-14 (1st day with 0.1 dead per million)
# Latest number \\(1,765\\) on 2020-04-21
# Best fit exponential: \(51.9 \times 10^{0.040t}\) (doubling rate \(7.5\) days)
# Best fit sigmoid: \(\dfrac{2,179.4}{1 + 10^{-0.072 (t - 31.5)}}\) (asimptote \(2,179.4\))
# ### Active
# Start date 2020-02-29 (1st day with 1 active per million)
# Latest number \\(13,007\\) on 2020-04-21
# ## Norway
# Population \\(5,421,241\\)
# ### Confirmed
# Start date 2020-02-28 (1st day with 1 confirmed per million)
# Latest number \\(7,191\\) on 2020-04-21
# Best fit exponential: \(892 \times 10^{0.018t}\) (doubling rate \(16.3\) days)
# Best fit sigmoid: \(\dfrac{7,185.3}{1 + 10^{-0.065 (t - 28.8)}}\) (asimptote \(7,185.3\))
# ### Dead
# Start date 2020-03-14 (1st day with 0.1 dead per million)
# Latest number \\(182\\) on 2020-04-21
# Best fit exponential: \(11.9 \times 10^{0.032t}\) (doubling rate \(9.4\) days)
# Best fit sigmoid: \(\dfrac{197.1}{1 + 10^{-0.075 (t - 26.4)}}\) (asimptote \(197.1\))
# ### Active
# Start date 2020-02-28 (1st day with 1 active per million)
# Latest number \\(6,977\\) on 2020-04-21
# ## Finland
# Population \\(5,540,720\\)
# ### Confirmed
# Start date 2020-03-01 (1st day with 1 confirmed per million)
# Latest number \\(4,014\\) on 2020-04-21
# Best fit exponential: \(204 \times 10^{0.026t}\) (doubling rate \(11.6\) days)
# Best fit sigmoid: \(\dfrac{4,631.7}{1 + 10^{-0.052 (t - 38.1)}}\) (asimptote \(4,631.7\))
# ### Dead
# Start date 2020-03-21 (1st day with 0.1 dead per million)
# Latest number \\(141\\) on 2020-04-21
# Best fit exponential: \(5.29 \times 10^{0.043t}\) (doubling rate \(7.0\) days)
# Best fit sigmoid: \(\dfrac{534.8}{1 + 10^{-0.048 (t - 43.0)}}\) (asimptote \(534.8\))
# ### Active
# Start date 2020-03-05 (1st day with 1 active per million)
# Latest number \\(1,873\\) on 2020-04-21
# ## Denmark
# Population \\(5,792,202\\)
# ### Confirmed
# Start date 2020-03-03 (1st day with 1 confirmed per million)
# Latest number \\(7,891\\) on 2020-04-21
# Best fit exponential: \(618 \times 10^{0.023t}\) (doubling rate \(12.8\) days)
# Best fit sigmoid: \(\dfrac{8,965.9}{1 + 10^{-0.053 (t - 33.8)}}\) (asimptote \(8,965.9\))
# ### Dead
# Start date 2020-03-14 (1st day with 0.1 dead per million)
# Latest number \\(370\\) on 2020-04-21
# Best fit exponential: \(29.9 \times 10^{0.030t}\) (doubling rate \(10.1\) days)
# Best fit sigmoid: \(\dfrac{389.7}{1 + 10^{-0.077 (t - 24.7)}}\) (asimptote \(389.7\))
# ### Active
# Start date 2020-03-03 (1st day with 1 active per million)
# Latest number \\(2,632\\) on 2020-04-21
# ## Iceland
# Population \\(341,243\\)
# ### Confirmed
# Start date 2020-02-28 (1st day with 1 confirmed per million)
# Latest number \\(1,778\\) on 2020-04-21
# Best fit exponential: \(205 \times 10^{0.019t}\) (doubling rate \(15.5\) days)
# Best fit sigmoid: \(\dfrac{1,802.4}{1 + 10^{-0.077 (t - 29.3)}}\) (asimptote \(1,802.4\))
# ### Dead
# Start date 2020-03-15 (1st day with 0.1 dead per million)
# Latest number \\(10\\) on 2020-04-21
# Best fit exponential: \(1.15 \times 10^{0.026t}\) (doubling rate \(11.6\) days)
# Best fit sigmoid: \(\dfrac{11.7}{1 + 10^{-0.057 (t - 25.0)}}\) (asimptote \(11.7\))
# ### Active
# Start date 2020-02-28 (1st day with 1 active per million)
# Latest number \\(351\\) on 2020-04-21
# ## Belgium
# Population \\(11,589,623\\)
# ### Confirmed
# Start date 2020-03-03 (1st day with 1 confirmed per million)
# Latest number \\(40,956\\) on 2020-04-21
# Best fit exponential: \(1.73 \times 10^{3} \times 10^{0.029t}\) (doubling rate \(10.5\) days)
# Best fit sigmoid: \(\dfrac{44,802.0}{1 + 10^{-0.063 (t - 36.1)}}\) (asimptote \(44,802.0\))
# ### Dead
# Start date 2020-03-11 (1st day with 0.1 dead per million)
# Latest number \\(5,998\\) on 2020-04-21
# Best fit exponential: \(141 \times 10^{0.040t}\) (doubling rate \(7.5\) days)
# Best fit sigmoid: \(\dfrac{7,012.4}{1 + 10^{-0.084 (t - 32.8)}}\) (asimptote \(7,012.4\))
# ### Active
# Start date 2020-03-03 (1st day with 1 active per million)
# Latest number \\(25,956\\) on 2020-04-21
# ## United Kingdom
# Population \\(67,886,011\\)
# ### Confirmed
# Start date 2020-03-04 (1st day with 1 confirmed per million)
# Latest number \\(130,172\\) on 2020-04-21
# Best fit exponential: \(3.26 \times 10^{3} \times 10^{0.034t}\) (doubling rate \(8.9\) days)
# Best fit sigmoid: \(\dfrac{152,830.9}{1 + 10^{-0.067 (t - 38.5)}}\) (asimptote \(152,830.9\))
# ### Dead
# Start date 2020-03-11 (1st day with 0.1 dead per million)
# Latest number \\(17,378\\) on 2020-04-21
# Best fit exponential: \(459 \times 10^{0.039t}\) (doubling rate \(7.7\) days)
# Best fit sigmoid: \(\dfrac{19,386.6}{1 + 10^{-0.084 (t - 32.0)}}\) (asimptote \(19,386.6\))
# ### Active
# Start date 2020-03-04 (1st day with 1 active per million)
# Latest number \\(112,156\\) on 2020-04-21
# ## Italy
# Population \\(60,461,826\\)
# ### Confirmed
# Start date 2020-02-22 (1st day with 1 confirmed per million)
# Latest number \\(183,957\\) on 2020-04-21
# Best fit exponential: \(1.41 \times 10^{4} \times 10^{0.020t}\) (doubling rate \(15.1\) days)
# Best fit sigmoid: \(\dfrac{184,507.6}{1 + 10^{-0.056 (t - 36.8)}}\) (asimptote \(184,507.6\))
# ### Dead
# Start date 2020-02-24 (1st day with 0.1 dead per million)
# Latest number \\(24,648\\) on 2020-04-21
# Best fit exponential: \(1.47 \times 10^{3} \times 10^{0.022t}\) (doubling rate \(13.5\) days)
# Best fit sigmoid: \(\dfrac{24,845.6}{1 + 10^{-0.060 (t - 37.6)}}\) (asimptote \(24,845.6\))
# ### Active
# Start date 2020-02-23 (1st day with 1 active per million)
# Latest number \\(107,709\\) on 2020-04-21

# %% [markdown]
# # Please read the [README](https://github.com/ibudiselic/covid/blob/master/README.md) file in this repository.

# %%
# Load all the data and functionality.
# %run lib.ipynb

countries_to_plot = ['Croatia', 'Sweden', 'Norway', 'Finland', 'Denmark', 'Iceland', 'Belgium', 'United Kingdom', 'Italy']

# %%
# %%javascript
# IPython.OutputArea.auto_scroll_threshold = 9999;

# %% [markdown]
# # Cross-country comparison over absolute dates

# %%
for series in ['confirmed', 'dead']:
    compare_countries_absolute_dates(series)
# Out:
# ## Confirmed
# ## Dead

# %% [markdown]
# # Cross-country comparison with approximately aligned start days

# %%
compare_countries_relative_dates('confirmed', start_info=(0.01, '10 confirmed per million'))
# Out:
# ## Confirmed

# %%
compare_countries_relative_dates('dead', start_info=(0.001, '1 death per million'))
# Out:
# ## Dead

# %% [markdown]
# # Per-country analysis with exponential and sigmoidal projections, and new cases analysis
#
# <span style="color:red;">
# IMPORTANT: The projections are only accurate if the fit is good (it often isn't), and assuming nothing changes
# going forward. The sigmoid is omitted if a reasonable fit can't be computed, but this still doesn't mean that
# the fit is good if it is shown.
# </span>
#
# The dashed lines show best fit projections from a few previous days for comparison.

# %%
for country in countries_to_plot:
    country_deep_dive(country)
# Out:
# ## Croatia
# Population \\(4,105,267\\)
# ### Confirmed
# Start date 2020-02-28 (1st day with 1 confirmed per million)
# Latest number \\(1,832\\) on 2020-04-18
# Best fit exponential: \(84.7 \times 10^{0.028t}\) (doubling rate \(10.8\) days)
# Best fit sigmoid: \(\dfrac{1,896.4}{1 + 10^{-0.073 (t - 34.6)}}\) (asimptote \(1,896.4\))
# ### Dead
# Start date 2020-03-19 (1st day with 0.1 dead per million)
# Latest number \\(39\\) on 2020-04-18
# Best fit exponential: \(2.1 \times 10^{0.042t}\) (doubling rate \(7.2\) days)
# Best fit sigmoid: \(\dfrac{55.8}{1 + 10^{-0.068 (t - 26.1)}}\) (asimptote \(55.8\))
# ### Active
# Start date 2020-02-28 (1st day with 1 active per million)
# Latest number \\(1,178\\) on 2020-04-18
# ## Sweden
# Population \\(10,099,265\\)
# ### Confirmed
# Start date 2020-02-29 (1st day with 1 confirmed per million)
# Latest number \\(13,822\\) on 2020-04-18
# Best fit exponential: \(471 \times 10^{0.030t}\) (doubling rate \(10.0\) days)
# Best fit sigmoid: \(\dfrac{18,595.4}{1 + 10^{-0.051 (t - 41.6)}}\) (asimptote \(18,595.4\))
# ### Dead
# Start date 2020-03-14 (1st day with 0.1 dead per million)
# Latest number \\(1,511\\) on 2020-04-18
# Best fit exponential: \(37.4 \times 10^{0.045t}\) (doubling rate \(6.6\) days)
# Best fit sigmoid: \(\dfrac{2,008.6}{1 + 10^{-0.076 (t - 30.5)}}\) (asimptote \(2,008.6\))
# ### Active
# Start date 2020-02-29 (1st day with 1 active per million)
# Latest number \\(11,761\\) on 2020-04-18
# ## Norway
# Population \\(5,421,241\\)
# ### Confirmed
# Start date 2020-02-28 (1st day with 1 confirmed per million)
# Latest number \\(7,036\\) on 2020-04-18
# Best fit exponential: \(776 \times 10^{0.020t}\) (doubling rate \(14.7\) days)
# Best fit sigmoid: \(\dfrac{7,088.1}{1 + 10^{-0.066 (t - 28.5)}}\) (asimptote \(7,088.1\))
# ### Dead
# Start date 2020-03-14 (1st day with 0.1 dead per million)
# Latest number \\(164\\) on 2020-04-18
# Best fit exponential: \(9.32 \times 10^{0.036t}\) (doubling rate \(8.3\) days)
# Best fit sigmoid: \(\dfrac{187.4}{1 + 10^{-0.079 (t - 25.7)}}\) (asimptote \(187.4\))
# ### Active
# Start date 2020-02-28 (1st day with 1 active per million)
# Latest number \\(6,840\\) on 2020-04-18
# ## Finland
# Population \\(5,540,720\\)
# ### Confirmed
# Start date 2020-03-01 (1st day with 1 confirmed per million)
# Latest number \\(3,681\\) on 2020-04-18
# Best fit exponential: \(170 \times 10^{0.028t}\) (doubling rate \(10.7\) days)
# Best fit sigmoid: \(\dfrac{4,376.0}{1 + 10^{-0.055 (t - 37.1)}}\) (asimptote \(4,376.0\))
# ### Dead
# Start date 2020-03-21 (1st day with 0.1 dead per million)
# Latest number \\(90\\) on 2020-04-18
# Best fit exponential: \(5.25 \times 10^{0.043t}\) (doubling rate \(7.0\) days)
# Best fit sigmoid: \(\dfrac{137.6}{1 + 10^{-0.066 (t - 25.5)}}\) (asimptote \(137.6\))
# ### Active
# Start date 2020-03-05 (1st day with 1 active per million)
# Latest number \\(1,891\\) on 2020-04-18
# ## Denmark
# Population \\(5,792,202\\)
# ### Confirmed
# Start date 2020-03-03 (1st day with 1 confirmed per million)
# Latest number \\(7,437\\) on 2020-04-18
# Best fit exponential: \(518 \times 10^{0.026t}\) (doubling rate \(11.6\) days)
# Best fit sigmoid: \(\dfrac{9,005.7}{1 + 10^{-0.053 (t - 33.8)}}\) (asimptote \(9,005.7\))
# ### Dead
# Start date 2020-03-14 (1st day with 0.1 dead per million)
# Latest number \\(346\\) on 2020-04-18
# Best fit exponential: \(23.9 \times 10^{0.034t}\) (doubling rate \(8.9\) days)
# Best fit sigmoid: \(\dfrac{370.4}{1 + 10^{-0.081 (t - 23.9)}}\) (asimptote \(370.4\))
# ### Active
# Start date 2020-03-03 (1st day with 1 active per million)
# Latest number \\(3,060\\) on 2020-04-18
# ## Iceland
# Population \\(341,243\\)
# ### Confirmed
# Start date 2020-02-28 (1st day with 1 confirmed per million)
# Latest number \\(1,760\\) on 2020-04-18
# Best fit exponential: \(173 \times 10^{0.022t}\) (doubling rate \(13.8\) days)
# Best fit sigmoid: \(\dfrac{1,803.3}{1 + 10^{-0.077 (t - 29.3)}}\) (asimptote \(1,803.3\))
# ### Dead
# Start date 2020-03-15 (1st day with 0.1 dead per million)
# Latest number \\(9\\) on 2020-04-18
# ### Active
# Start date 2020-02-28 (1st day with 1 active per million)
# Latest number \\(460\\) on 2020-04-18
# ## Belgium
# Population \\(11,589,623\\)
# ### Confirmed
# Start date 2020-03-03 (1st day with 1 confirmed per million)
# Latest number \\(37,183\\) on 2020-04-18
# Best fit exponential: \(1.37 \times 10^{3} \times 10^{0.032t}\) (doubling rate \(9.5\) days)
# Best fit sigmoid: \(\dfrac{41,428.2}{1 + 10^{-0.067 (t - 34.8)}}\) (asimptote \(41,428.2\))
# ### Dead
# Start date 2020-03-11 (1st day with 0.1 dead per million)
# Latest number \\(5,453\\) on 2020-04-18
# Best fit exponential: \(89.3 \times 10^{0.047t}\) (doubling rate \(6.4\) days)
# Best fit sigmoid: \(\dfrac{6,940.4}{1 + 10^{-0.085 (t - 32.7)}}\) (asimptote \(6,940.4\))
# ### Active
# Start date 2020-03-03 (1st day with 1 active per million)
# Latest number \\(23,382\\) on 2020-04-18
# ## United Kingdom
# Population \\(67,886,011\\)
# ### Confirmed
# Start date 2020-03-04 (1st day with 1 confirmed per million)
# Latest number \\(115,314\\) on 2020-04-18
# Best fit exponential: \(2.41 \times 10^{3} \times 10^{0.038t}\) (doubling rate \(8.0\) days)
# Best fit sigmoid: \(\dfrac{140,369.7}{1 + 10^{-0.071 (t - 37.3)}}\) (asimptote \(140,369.7\))
# ### Dead
# Start date 2020-03-11 (1st day with 0.1 dead per million)
# Latest number \\(15,498\\) on 2020-04-18
# Best fit exponential: \(307 \times 10^{0.045t}\) (doubling rate \(6.7\) days)
# Best fit sigmoid: \(\dfrac{18,087.9}{1 + 10^{-0.089 (t - 31.2)}}\) (asimptote \(18,087.9\))
# ### Active
# Start date 2020-03-04 (1st day with 1 active per million)
# Latest number \\(99,402\\) on 2020-04-18
# ## Italy
# Population \\(60,461,826\\)
# ### Confirmed
# Start date 2020-02-22 (1st day with 1 confirmed per million)
# Latest number \\(175,925\\) on 2020-04-18
# Best fit exponential: \(1.21 \times 10^{4} \times 10^{0.022t}\) (doubling rate \(13.9\) days)
# Best fit sigmoid: \(\dfrac{177,317.8}{1 + 10^{-0.059 (t - 36.0)}}\) (asimptote \(177,317.8\))
# ### Dead
# Start date 2020-02-24 (1st day with 0.1 dead per million)
# Latest number \\(23,227\\) on 2020-04-18
# Best fit exponential: \(1.22 \times 10^{3} \times 10^{0.025t}\) (doubling rate \(12.3\) days)
# Best fit sigmoid: \(\dfrac{23,674.3}{1 + 10^{-0.064 (t - 36.7)}}\) (asimptote \(23,674.3\))
# ### Active
# Start date 2020-02-23 (1st day with 1 active per million)
# Latest number \\(107,771\\) on 2020-04-18

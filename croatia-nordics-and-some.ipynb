# %% [markdown]
# # Please read the [README](https://github.com/ibudiselic/covid/blob/master/README.md) file in this repository.

# %%
# Load all the data and functionality.
# %run lib.ipynb

countries_to_plot = ['Croatia', 'Sweden', 'Norway', 'Finland', 'Denmark', 'Iceland', 'Belgium', 'United Kingdom', 'Italy']

# %%
# %%javascript
# IPython.OutputArea.auto_scroll_threshold = 9999;

# %% [markdown]
# # Cross-country comparison over absolute dates

# %%
for series in ['confirmed', 'dead']:
    compare_countries_absolute_dates(series)
# Out:
# ## Confirmed
# ## Dead

# %% [markdown]
# # Cross-country comparison with approximately aligned start days

# %%
compare_countries_relative_dates('confirmed', start_info=(0.01, '10 confirmed per million'))
# Out:
# ## Confirmed

# %%
compare_countries_relative_dates('dead', start_info=(0.001, '1 death per million'))
# Out:
# ## Dead

# %% [markdown]
# # Per-country analysis with exponential and sigmoidal projections, and new cases analysis
#
# <span style="color:red;">
# IMPORTANT: The projections are only accurate if the fit is good (it often isn't), and assuming nothing changes
# going forward. The sigmoid is omitted if a reasonable fit can't be computed, but this still doesn't mean that
# the fit is good if it is shown.
# </span>
#
# The dashed lines show best fit projections from a few previous days for comparison.

# %%
for country in countries_to_plot:
    country_deep_dive(country)
# Out:
# ## Croatia
# Population \\(4,105,267\\)
# ### Confirmed
# Start date 2020-02-28 (1st day with 1 confirmed per million)
# Latest number \\(1,881\\) on 2020-04-20
# Best fit exponential: \(100 \times 10^{0.026t}\) (doubling rate \(11.7\) days)
# Best fit sigmoid: \(\dfrac{1,934.0}{1 + 10^{-0.072 (t - 34.9)}}\) (asimptote \(1,934.0\))
# ### Dead
# Start date 2020-03-19 (1st day with 0.1 dead per million)
# Latest number \\(47\\) on 2020-04-20
# Best fit exponential: \(2.2 \times 10^{0.041t}\) (doubling rate \(7.3\) days)
# Best fit sigmoid: \(\dfrac{82.4}{1 + 10^{-0.059 (t - 31.1)}}\) (asimptote \(82.4\))
# ### Active
# Start date 2020-02-28 (1st day with 1 active per million)
# Latest number \\(1,063\\) on 2020-04-20
# ## Sweden
# Population \\(10,099,265\\)
# ### Confirmed
# Start date 2020-02-29 (1st day with 1 confirmed per million)
# Latest number \\(14,777\\) on 2020-04-20
# Best fit exponential: \(534 \times 10^{0.029t}\) (doubling rate \(10.5\) days)
# Best fit sigmoid: \(\dfrac{19,449.9}{1 + 10^{-0.050 (t - 42.4)}}\) (asimptote \(19,449.9\))
# ### Dead
# Start date 2020-03-14 (1st day with 0.1 dead per million)
# Latest number \\(1,580\\) on 2020-04-20
# Best fit exponential: \(47.9 \times 10^{0.041t}\) (doubling rate \(7.3\) days)
# Best fit sigmoid: \(\dfrac{2,026.8}{1 + 10^{-0.075 (t - 30.6)}}\) (asimptote \(2,026.8\))
# ### Active
# Start date 2020-02-29 (1st day with 1 active per million)
# Latest number \\(12,647\\) on 2020-04-20
# ## Norway
# Population \\(5,421,241\\)
# ### Confirmed
# Start date 2020-02-28 (1st day with 1 confirmed per million)
# Latest number \\(7,156\\) on 2020-04-20
# Best fit exponential: \(853 \times 10^{0.019t}\) (doubling rate \(15.8\) days)
# Best fit sigmoid: \(\dfrac{7,155.5}{1 + 10^{-0.065 (t - 28.7)}}\) (asimptote \(7,155.5\))
# ### Dead
# Start date 2020-03-14 (1st day with 0.1 dead per million)
# Latest number \\(181\\) on 2020-04-20
# Best fit exponential: \(11 \times 10^{0.033t}\) (doubling rate \(9.0\) days)
# Best fit sigmoid: \(\dfrac{193.5}{1 + 10^{-0.077 (t - 26.1)}}\) (asimptote \(193.5\))
# ### Active
# Start date 2020-02-28 (1st day with 1 active per million)
# Latest number \\(6,943\\) on 2020-04-20
# ## Finland
# Population \\(5,540,720\\)
# ### Confirmed
# Start date 2020-03-01 (1st day with 1 confirmed per million)
# Latest number \\(3,868\\) on 2020-04-20
# Best fit exponential: \(193 \times 10^{0.027t}\) (doubling rate \(11.3\) days)
# Best fit sigmoid: \(\dfrac{4,537.4}{1 + 10^{-0.053 (t - 37.7)}}\) (asimptote \(4,537.4\))
# ### Dead
# Start date 2020-03-21 (1st day with 0.1 dead per million)
# Latest number \\(98\\) on 2020-04-20
# Best fit exponential: \(6 \times 10^{0.040t}\) (doubling rate \(7.5\) days)
# Best fit sigmoid: \(\dfrac{144.9}{1 + 10^{-0.065 (t - 26.1)}}\) (asimptote \(144.9\))
# ### Active
# Start date 2020-03-05 (1st day with 1 active per million)
# Latest number \\(1,770\\) on 2020-04-20
# ## Denmark
# Population \\(5,792,202\\)
# ### Confirmed
# Start date 2020-03-03 (1st day with 1 confirmed per million)
# Latest number \\(7,711\\) on 2020-04-20
# Best fit exponential: \(584 \times 10^{0.024t}\) (doubling rate \(12.4\) days)
# Best fit sigmoid: \(\dfrac{8,953.4}{1 + 10^{-0.053 (t - 33.7)}}\) (asimptote \(8,953.4\))
# ### Dead
# Start date 2020-03-14 (1st day with 0.1 dead per million)
# Latest number \\(364\\) on 2020-04-20
# Best fit exponential: \(27.8 \times 10^{0.031t}\) (doubling rate \(9.7\) days)
# Best fit sigmoid: \(\dfrac{384.6}{1 + 10^{-0.078 (t - 24.5)}}\) (asimptote \(384.6\))
# ### Active
# Start date 2020-03-03 (1st day with 1 active per million)
# Latest number \\(2,848\\) on 2020-04-20
# ## Iceland
# Population \\(341,243\\)
# ### Confirmed
# Start date 2020-02-28 (1st day with 1 confirmed per million)
# Latest number \\(1,773\\) on 2020-04-20
# Best fit exponential: \(194 \times 10^{0.020t}\) (doubling rate \(15.0\) days)
# Best fit sigmoid: \(\dfrac{1,802.7}{1 + 10^{-0.077 (t - 29.3)}}\) (asimptote \(1,802.7\))
# ### Dead
# Start date 2020-03-15 (1st day with 0.1 dead per million)
# Latest number \\(10\\) on 2020-04-20
# Best fit exponential: \(1.1 \times 10^{0.027t}\) (doubling rate \(11.2\) days)
# Best fit sigmoid: \(\dfrac{11.6}{1 + 10^{-0.058 (t - 24.9)}}\) (asimptote \(11.6\))
# ### Active
# Start date 2020-02-28 (1st day with 1 active per million)
# Latest number \\(401\\) on 2020-04-20
# ## Belgium
# Population \\(11,589,623\\)
# ### Confirmed
# Start date 2020-03-03 (1st day with 1 confirmed per million)
# Latest number \\(39,983\\) on 2020-04-20
# Best fit exponential: \(1.6 \times 10^{3} \times 10^{0.030t}\) (doubling rate \(10.1\) days)
# Best fit sigmoid: \(\dfrac{43,773.1}{1 + 10^{-0.064 (t - 35.7)}}\) (asimptote \(43,773.1\))
# ### Dead
# Start date 2020-03-11 (1st day with 0.1 dead per million)
# Latest number \\(5,828\\) on 2020-04-20
# Best fit exponential: \(121 \times 10^{0.043t}\) (doubling rate \(7.1\) days)
# Best fit sigmoid: \(\dfrac{7,027.8}{1 + 10^{-0.084 (t - 32.8)}}\) (asimptote \(7,027.8\))
# ### Active
# Start date 2020-03-03 (1st day with 1 active per million)
# Latest number \\(25,260\\) on 2020-04-20
# ## United Kingdom
# Population \\(67,886,011\\)
# ### Confirmed
# Start date 2020-03-04 (1st day with 1 confirmed per million)
# Latest number \\(125,856\\) on 2020-04-20
# Best fit exponential: \(2.95 \times 10^{3} \times 10^{0.035t}\) (doubling rate \(8.6\) days)
# Best fit sigmoid: \(\dfrac{149,350.1}{1 + 10^{-0.068 (t - 38.2)}}\) (asimptote \(149,350.1\))
# ### Dead
# Start date 2020-03-11 (1st day with 0.1 dead per million)
# Latest number \\(16,550\\) on 2020-04-20
# Best fit exponential: \(406 \times 10^{0.041t}\) (doubling rate \(7.4\) days)
# Best fit sigmoid: \(\dfrac{18,911.7}{1 + 10^{-0.086 (t - 31.7)}}\) (asimptote \(18,911.7\))
# ### Active
# Start date 2020-03-04 (1st day with 1 active per million)
# Latest number \\(108,860\\) on 2020-04-20
# ## Italy
# Population \\(60,461,826\\)
# ### Confirmed
# Start date 2020-02-22 (1st day with 1 confirmed per million)
# Latest number \\(181,228\\) on 2020-04-20
# Best fit exponential: \(1.34 \times 10^{4} \times 10^{0.020t}\) (doubling rate \(14.7\) days)
# Best fit sigmoid: \(\dfrac{182,251.2}{1 + 10^{-0.057 (t - 36.6)}}\) (asimptote \(182,251.2\))
# ### Dead
# Start date 2020-02-24 (1st day with 0.1 dead per million)
# Latest number \\(24,114\\) on 2020-04-20
# Best fit exponential: \(1.38 \times 10^{3} \times 10^{0.023t}\) (doubling rate \(13.1\) days)
# Best fit sigmoid: \(\dfrac{24,449.6}{1 + 10^{-0.062 (t - 37.3)}}\) (asimptote \(24,449.6\))
# ### Active
# Start date 2020-02-23 (1st day with 1 active per million)
# Latest number \\(108,237\\) on 2020-04-20

# %% [markdown]
# # Please read the [README](https://github.com/ibudiselic/covid/blob/master/README.md) file in this repository.

# %%
# Load all the data and functionality.
# %run lib.ipynb

nb_continent = 'Africa'
display(Markdown(f'# Analysis of the most affected countries in {nb_continent}'))
countries_to_plot = get_top_countries_by_relative_deaths(continent=nb_continent)
# Out:
# # Analysis of the most affected countries in Africa

# %%
# %%javascript
# IPython.OutputArea.auto_scroll_threshold = 9999;

# %% [markdown]
# # Cross-country comparison over absolute dates

# %%
for series in ['confirmed', 'dead', 'active']:
    compare_countries_absolute_dates(series, skip_days=55)
# Out:
# ## Confirmed
# ## Dead
# ## Active

# %% [markdown]
# # Cross-country comparison with approximately aligned start days

# %%
for series, start_info in [
        ('confirmed', (0.01, '10 confirmed per million')),
        ('dead', (0.001, '1 death per million')),
        ('active', (0.01, '10 active per million'))]:
    compare_countries_relative_dates(series, start_info)
# Out:
# ## Confirmed
# ## Dead
# ## Active

# %% [markdown]
# # Per-country analysis with exponential and sigmoidal projections, and new cases analysis
#
# <span style="color:red;">
# IMPORTANT: The projections are only accurate if the fit is good (it often isn't), and assuming nothing changes
# going forward. The sigmoid is omitted if a reasonable fit can't be computed, but this still doesn't mean that
# the fit is good if it is shown.
# </span>
#
# The dashed lines show best fit projections from a few previous days for comparison.

# %%
for country in countries_to_plot:
    country_deep_dive(country)
# Out:
# ## Algeria
# Population \\(43,851,044\\)
# ### Confirmed
# Start date 2020-03-15 (1st day with 1 confirmed per million)
# Latest number \\(4,006\\) on 2020-04-30
# Best fit exponential: \(351 \times 10^{0.023t}\) (doubling rate \(13.0\) days)
# Best fit sigmoid: \(\dfrac{4,468.1}{1 + 10^{-0.047 (t - 32.0)}}\) (asimptote \(4,468.1\))
# ### Dead
# Start date 2020-03-18 (1st day with 0.1 dead per million)
# Latest number \\(450\\) on 2020-04-30
# Best fit exponential: \(58.3 \times 10^{0.022t}\) (doubling rate \(13.6\) days)
# Best fit sigmoid: \(\dfrac{434.9}{1 + 10^{-0.089 (t - 22.6)}}\) (asimptote \(434.9\))
# ### Active
# Start date 2020-03-17 (1st day with 1 active per million)
# Latest number \\(1,777\\) on 2020-04-30
# ## Mauritius
# Population \\(1,271,768\\)
# ### Confirmed
# Start date 2020-03-18 (1st day with 1 confirmed per million)
# Latest number \\(332\\) on 2020-04-30
# Best fit exponential: \(98.4 \times 10^{0.014t}\) (doubling rate \(20.9\) days)
# Best fit sigmoid: \(\dfrac{335.9}{1 + 10^{-0.102 (t - 15.3)}}\) (asimptote \(335.9\))
# ### Dead
# Start date 2020-03-21 (1st day with 0.1 dead per million)
# Latest number \\(10\\) on 2020-04-30
# Best fit exponential: \(3.6 \times 10^{0.012t}\) (doubling rate \(24.3\) days)
# Best fit sigmoid: \(\dfrac{9.4}{1 + 10^{-0.094 (t - 11.1)}}\) (asimptote \(9.4\))
# ### Active
# Start date 2020-03-18 (1st day with 1 active per million)
# Latest number \\(12\\) on 2020-04-30
# ## Congo (Kinshasa)
# Population \\(5,518,087\\)
# ### Confirmed
# Start date 2020-03-19 (1st day with 1 confirmed per million)
# Latest number \\(572\\) on 2020-04-30
# Best fit exponential: \(51.9 \times 10^{0.024t}\) (doubling rate \(12.6\) days)
# Best fit sigmoid: \(\dfrac{848.1}{1 + 10^{-0.036 (t - 37.8)}}\) (asimptote \(848.1\))
# ### Dead
# Start date 2020-03-21 (1st day with 0.1 dead per million)
# Latest number \\(31\\) on 2020-04-30
# Best fit exponential: \(6.79 \times 10^{0.017t}\) (doubling rate \(17.5\) days)
# Best fit sigmoid: \(\dfrac{27.8}{1 + 10^{-0.072 (t - 15.7)}}\) (asimptote \(27.8\))
# ### Active
# Start date 2020-03-19 (1st day with 1 active per million)
# Latest number \\(468\\) on 2020-04-30
# ## Morocco
# Population \\(36,910,560\\)
# ### Confirmed
# Start date 2020-03-17 (1st day with 1 confirmed per million)
# Latest number \\(4,423\\) on 2020-04-30
# Best fit exponential: \(292 \times 10^{0.028t}\) (doubling rate \(10.9\) days)
# Best fit sigmoid: \(\dfrac{5,727.9}{1 + 10^{-0.052 (t - 34.0)}}\) (asimptote \(5,727.9\))
# ### Dead
# Start date 2020-03-22 (1st day with 0.1 dead per million)
# Latest number \\(170\\) on 2020-04-30
# Best fit exponential: \(34.6 \times 10^{0.019t}\) (doubling rate \(15.7\) days)
# Best fit sigmoid: \(\dfrac{163.8}{1 + 10^{-0.078 (t - 17.1)}}\) (asimptote \(163.8\))
# ### Active
# Start date 2020-03-18 (1st day with 1 active per million)
# Latest number \\(3,269\\) on 2020-04-30
# ## Egypt
# Population \\(102,334,404\\)
# ### Confirmed
# Start date 2020-03-14 (1st day with 1 confirmed per million)
# Latest number \\(5,537\\) on 2020-04-30
# Best fit exponential: \(294 \times 10^{0.027t}\) (doubling rate \(11.1\) days)
# Best fit sigmoid: \(\dfrac{8,974.1}{1 + 10^{-0.040 (t - 43.5)}}\) (asimptote \(8,974.1\))
# ### Dead
# Start date 2020-03-22 (1st day with 0.1 dead per million)
# Latest number \\(392\\) on 2020-04-30
# Best fit exponential: \(35.6 \times 10^{0.027t}\) (doubling rate \(11.2\) days)
# Best fit sigmoid: \(\dfrac{506.3}{1 + 10^{-0.048 (t - 30.2)}}\) (asimptote \(506.3\))
# ### Active
# Start date 2020-03-16 (1st day with 1 active per million)
# Latest number \\(3,764\\) on 2020-04-30
# ## Tunisia
# Population \\(11,818,619\\)
# ### Confirmed
# Start date 2020-03-13 (1st day with 1 confirmed per million)
# Latest number \\(994\\) on 2020-04-30
# Best fit exponential: \(169 \times 10^{0.017t}\) (doubling rate \(17.3\) days)
# Best fit sigmoid: \(\dfrac{964.1}{1 + 10^{-0.067 (t - 22.7)}}\) (asimptote \(964.1\))
# ### Dead
# Start date 2020-03-22 (1st day with 0.1 dead per million)
# Latest number \\(41\\) on 2020-04-30
# Best fit exponential: \(10.5 \times 10^{0.017t}\) (doubling rate \(18.1\) days)
# Best fit sigmoid: \(\dfrac{40.3}{1 + 10^{-0.079 (t - 15.3)}}\) (asimptote \(40.3\))
# ### Active
# Start date 2020-03-13 (1st day with 1 active per million)
# Latest number \\(648\\) on 2020-04-30
# ## Cameroon
# Population \\(26,545,863\\)
# ### Confirmed
# Start date 2020-03-21 (1st day with 1 confirmed per million)
# Latest number \\(1,832\\) on 2020-04-30
# Best fit exponential: \(188 \times 10^{0.025t}\) (doubling rate \(12.0\) days)
# Best fit sigmoid: \(\dfrac{2,488.9}{1 + 10^{-0.042 (t - 31.4)}}\) (asimptote \(2,488.9\))
# ### Dead
# Start date 2020-03-29 (1st day with 0.1 dead per million)
# Latest number \\(61\\) on 2020-04-30
# Best fit exponential: \(5.11 \times 10^{0.035t}\) (doubling rate \(8.7\) days)
# Best fit sigmoid: \(\dfrac{85.2}{1 + 10^{-0.064 (t - 25.4)}}\) (asimptote \(85.2\))
# ### Active
# Start date 2020-03-21 (1st day with 1 active per million)
# Latest number \\(837\\) on 2020-04-30
# ## Burkina Faso
# Population \\(20,903,273\\)
# ### Confirmed
# Start date 2020-03-19 (1st day with 1 confirmed per million)
# Latest number \\(645\\) on 2020-04-30
# Best fit exponential: \(168 \times 10^{0.015t}\) (doubling rate \(19.6\) days)
# Best fit sigmoid: \(\dfrac{660.0}{1 + 10^{-0.059 (t - 17.0)}}\) (asimptote \(660.0\))
# ### Dead
# Start date 2020-03-22 (1st day with 0.1 dead per million)
# Latest number \\(43\\) on 2020-04-30
# Best fit exponential: \(9.82 \times 10^{0.018t}\) (doubling rate \(16.9\) days)
# Best fit sigmoid: \(\dfrac{47.3}{1 + 10^{-0.051 (t - 19.0)}}\) (asimptote \(47.3\))
# ### Active
# Start date 2020-03-19 (1st day with 1 active per million)
# Latest number \\(96\\) on 2020-04-30

# %% [markdown]
# # Recovering countries that had over 300 active cases at peak

# %%
draw_recovering_countries(get_recovering_countries_info(continent=nb_continent))
# Out:
# ## List of all recovering countries (the top 4 not covered above are also analyzed below)
# Burkina Faso recovered 70%
# Niger recovered 54%
# Djibouti recovered 46%
# ## Niger
# Population \\(24,206,644\\)
# ### Confirmed
# Start date 2020-03-30 (1st day with 1 confirmed per million)
# Latest number \\(719\\) on 2020-04-30
# Best fit exponential: \(219 \times 10^{0.019t}\) (doubling rate \(16.2\) days)
# Best fit sigmoid: \(\dfrac{689.3}{1 + 10^{-0.124 (t - 10.3)}}\) (asimptote \(689.3\))
# ### Dead
# Start date 2020-03-30 (1st day with 0.1 dead per million)
# Latest number \\(32\\) on 2020-04-30
# Best fit exponential: \(5.47 \times 10^{0.025t}\) (doubling rate \(12.0\) days)
# Best fit sigmoid: \(\dfrac{64.3}{1 + 10^{-0.036 (t - 31.4)}}\) (asimptote \(64.3\))
# ### Active
# Start date 2020-04-01 (1st day with 1 active per million)
# Latest number \\(235\\) on 2020-04-30
# ## Djibouti
# Population \\(988,000\\)
# ### Confirmed
# Start date 2020-03-18 (1st day with 1 confirmed per million)
# Latest number \\(1,089\\) on 2020-04-30
# Best fit exponential: \(43.6 \times 10^{0.034t}\) (doubling rate \(8.8\) days)
# Best fit sigmoid: \(\dfrac{1,082.6}{1 + 10^{-0.140 (t - 29.6)}}\) (asimptote \(1,082.6\))
# ### Dead
# Start date 2020-04-10 (1st day with 0.1 dead per million)
# Latest number \\(2\\) on 2020-04-30
# ### Active
# Start date 2020-03-18 (1st day with 1 active per million)
# Latest number \\(445\\) on 2020-04-30

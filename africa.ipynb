# %% [markdown]
# # Please read the [README](https://github.com/ibudiselic/covid/blob/master/README.md) file in this repository.

# %%
# Load all the data and functionality.
# %run lib.ipynb

nb_continent = 'Africa'
display(Markdown(f'# Analysis of the most affected countries in {nb_continent}'))
countries_to_plot = get_top_countries_by_relative_deaths(continent=nb_continent)
# Out:
# # Analysis of the most affected countries in Africa

# %%
# %%javascript
# IPython.OutputArea.auto_scroll_threshold = 9999;

# %% [markdown]
# # Cross-country comparison over absolute dates

# %%
for series in ['confirmed', 'dead']:
    compare_countries_absolute_dates(series)
# Out:
# ## Confirmed
# ## Dead

# %% [markdown]
# # Cross-country comparison with approximately aligned start days

# %%
compare_countries_relative_dates('confirmed', start_info=(0.01, '10 confirmed per million'))
# Out:
# ## Confirmed

# %%
compare_countries_relative_dates('dead', start_info=(0.001, '1 death per million'))
# Out:
# ## Dead

# %% [markdown]
# # Per-country analysis with exponential and sigmoidal projections, and new cases analysis
#
# <span style="color:red;">
# IMPORTANT: The projections are only accurate if the fit is good (it often isn't), and assuming nothing changes
# going forward. The sigmoid is omitted if a reasonable fit can't be computed, but this still doesn't mean that
# the fit is good if it is shown.
# </span>
#
# The dashed lines show best fit projections from a few previous days for comparison.

# %%
for country in countries_to_plot:
    country_deep_dive(country)
# Out:
# ## Algeria
# Population \\(43,851,044\\)
# ### Confirmed
# Start date 2020-03-15 (1st day with 1 confirmed per million)
# Latest number \\(3,007\\) on 2020-04-23
# Best fit exponential: \(273 \times 10^{0.027t}\) (doubling rate \(11.0\) days)
# Best fit sigmoid: \(\dfrac{3,257.2}{1 + 10^{-0.061 (t - 25.9)}}\) (asimptote \(3,257.2\))
# ### Dead
# Start date 2020-03-18 (1st day with 0.1 dead per million)
# Latest number \\(407\\) on 2020-04-23
# Best fit exponential: \(37.5 \times 10^{0.030t}\) (doubling rate \(9.9\) days)
# Best fit sigmoid: \(\dfrac{409.9}{1 + 10^{-0.098 (t - 21.8)}}\) (asimptote \(409.9\))
# ### Active
# Start date 2020-03-17 (1st day with 1 active per million)
# Latest number \\(1,245\\) on 2020-04-23
# ## Mauritius
# Population \\(1,271,768\\)
# ### Confirmed
# Start date 2020-03-18 (1st day with 1 confirmed per million)
# Latest number \\(331\\) on 2020-04-23
# Best fit exponential: \(76.5 \times 10^{0.020t}\) (doubling rate \(15.1\) days)
# Best fit sigmoid: \(\dfrac{338.2}{1 + 10^{-0.100 (t - 15.4)}}\) (asimptote \(338.2\))
# ### Dead
# Start date 2020-03-21 (1st day with 0.1 dead per million)
# Latest number \\(9\\) on 2020-04-23
# ### Active
# Start date 2020-03-18 (1st day with 1 active per million)
# Latest number \\(56\\) on 2020-04-23
# ## Congo (Kinshasa)
# Population \\(5,518,087\\)
# ### Confirmed
# Start date 2020-03-19 (1st day with 1 confirmed per million)
# Latest number \\(377\\) on 2020-04-23
# Best fit exponential: \(45.7 \times 10^{0.026t}\) (doubling rate \(11.4\) days)
# Best fit sigmoid: \(\dfrac{467.7}{1 + 10^{-0.050 (t - 25.2)}}\) (asimptote \(467.7\))
# ### Dead
# Start date 2020-03-21 (1st day with 0.1 dead per million)
# Latest number \\(25\\) on 2020-04-23
# Best fit exponential: \(5.67 \times 10^{0.021t}\) (doubling rate \(14.1\) days)
# Best fit sigmoid: \(\dfrac{23.8}{1 + 10^{-0.104 (t - 13.2)}}\) (asimptote \(23.8\))
# ### Active
# Start date 2020-03-19 (1st day with 1 active per million)
# Latest number \\(305\\) on 2020-04-23
# ## Morocco
# Population \\(36,910,560\\)
# ### Confirmed
# Start date 2020-03-17 (1st day with 1 confirmed per million)
# Latest number \\(3,568\\) on 2020-04-23
# Best fit exponential: \(189 \times 10^{0.034t}\) (doubling rate \(8.8\) days)
# Best fit sigmoid: \(\dfrac{6,429.2}{1 + 10^{-0.049 (t - 36.0)}}\) (asimptote \(6,429.2\))
# ### Dead
# Start date 2020-03-22 (1st day with 0.1 dead per million)
# Latest number \\(155\\) on 2020-04-23
# Best fit exponential: \(26.1 \times 10^{0.025t}\) (doubling rate \(11.8\) days)
# Best fit sigmoid: \(\dfrac{151.4}{1 + 10^{-0.090 (t - 15.9)}}\) (asimptote \(151.4\))
# ### Active
# Start date 2020-03-18 (1st day with 1 active per million)
# Latest number \\(2,957\\) on 2020-04-23
# ## Tunisia
# Population \\(11,818,619\\)
# ### Confirmed
# Start date 2020-03-13 (1st day with 1 confirmed per million)
# Latest number \\(918\\) on 2020-04-23
# Best fit exponential: \(127 \times 10^{0.022t}\) (doubling rate \(13.5\) days)
# Best fit sigmoid: \(\dfrac{905.7}{1 + 10^{-0.075 (t - 21.6)}}\) (asimptote \(905.7\))
# ### Dead
# Start date 2020-03-22 (1st day with 0.1 dead per million)
# Latest number \\(38\\) on 2020-04-23
# Best fit exponential: \(7.98 \times 10^{0.023t}\) (doubling rate \(13.0\) days)
# Best fit sigmoid: \(\dfrac{40.8}{1 + 10^{-0.078 (t - 15.5)}}\) (asimptote \(40.8\))
# ### Active
# Start date 2020-03-13 (1st day with 1 active per million)
# Latest number \\(690\\) on 2020-04-23
# ## Egypt
# Population \\(102,334,404\\)
# ### Confirmed
# Start date 2020-03-14 (1st day with 1 confirmed per million)
# Latest number \\(3,891\\) on 2020-04-23
# Best fit exponential: \(232 \times 10^{0.031t}\) (doubling rate \(9.9\) days)
# Best fit sigmoid: \(\dfrac{6,294.2}{1 + 10^{-0.046 (t - 36.8)}}\) (asimptote \(6,294.2\))
# ### Dead
# Start date 2020-03-22 (1st day with 0.1 dead per million)
# Latest number \\(287\\) on 2020-04-23
# Best fit exponential: \(26.9 \times 10^{0.032t}\) (doubling rate \(9.3\) days)
# Best fit sigmoid: \(\dfrac{404.9}{1 + 10^{-0.055 (t - 26.1)}}\) (asimptote \(404.9\))
# ### Active
# Start date 2020-03-16 (1st day with 1 active per million)
# Latest number \\(2,600\\) on 2020-04-23
# ## Djibouti
# Population \\(988,000\\)
# ### Confirmed
# Start date 2020-03-18 (1st day with 1 confirmed per million)
# Latest number \\(986\\) on 2020-04-23
# Best fit exponential: \(10.2 \times 10^{0.056t}\) (doubling rate \(5.4\) days)
# Best fit sigmoid: \(\dfrac{1,129.0}{1 + 10^{-0.133 (t - 30.0)}}\) (asimptote \(1,129.0\))
# ### Dead
# Start date 2020-04-10 (1st day with 0.1 dead per million)
# Latest number \\(2\\) on 2020-04-23
# ### Active
# Start date 2020-03-18 (1st day with 1 active per million)
# Latest number \\(732\\) on 2020-04-23
# ## Burkina Faso
# Population \\(20,903,273\\)
# ### Confirmed
# Start date 2020-03-19 (1st day with 1 confirmed per million)
# Latest number \\(616\\) on 2020-04-23
# Best fit exponential: \(136 \times 10^{0.020t}\) (doubling rate \(15.1\) days)
# Best fit sigmoid: \(\dfrac{646.0}{1 + 10^{-0.061 (t - 16.6)}}\) (asimptote \(646.0\))
# ### Dead
# Start date 2020-03-22 (1st day with 0.1 dead per million)
# Latest number \\(41\\) on 2020-04-23
# Best fit exponential: \(7.75 \times 10^{0.023t}\) (doubling rate \(13.0\) days)
# Best fit sigmoid: \(\dfrac{49.5}{1 + 10^{-0.049 (t - 20.0)}}\) (asimptote \(49.5\))
# ### Active
# Start date 2020-03-19 (1st day with 1 active per million)
# Latest number \\(165\\) on 2020-04-23

# %% [markdown]
# # Recovering countries that had over 300 active cases at peak

# %%
draw_recovering_countries(get_recovering_countries_info(continent=nb_continent))
# Out:
# ## List of all recovering countries (the top 4 not covered above are also analyzed below)
# Burkina Faso recovered 49%

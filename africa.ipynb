# %% [markdown]
# # Please read the [README](https://github.com/ibudiselic/covid/blob/master/README.md) file in this repository.

# %%
# Load all the data and functionality.
# %run lib.ipynb

nb_continent = 'Africa'
display(Markdown(f'# Analysis of the most affected countries in {nb_continent}'))
countries_to_plot = get_top_countries_by_relative_deaths(continent=nb_continent)
# Out:
# # Analysis of the most affected countries in Africa

# %%
# %%javascript
# IPython.OutputArea.auto_scroll_threshold = 9999;

# %% [markdown]
# # Cross-country comparison over absolute dates

# %%
for series in ['confirmed', 'dead']:
    compare_countries_absolute_dates(series)
# Out:
# ## Confirmed
# ## Dead

# %% [markdown]
# # Cross-country comparison with approximately aligned start days

# %%
compare_countries_relative_dates('confirmed', start_info=(0.01, '10 confirmed per million'))
# Out:
# ## Confirmed

# %%
compare_countries_relative_dates('dead', start_info=(0.001, '1 death per million'))
# Out:
# ## Dead

# %% [markdown]
# # Per-country analysis with exponential and sigmoidal projections, and new cases analysis
#
# <span style="color:red;">
# IMPORTANT: The projections are only accurate if the fit is good (it often isn't), and assuming nothing changes
# going forward. The sigmoid is omitted if a reasonable fit can't be computed, but this still doesn't mean that
# the fit is good if it is shown.
# </span>
#
# The dashed lines show best fit projections from a few previous days for comparison.

# %%
for country in countries_to_plot:
    country_deep_dive(country)
# Out:
# ## Algeria
# Population \\(43,851,044\\)
# ### Confirmed
# Start date 2020-03-15 (1st day with 1 confirmed per million)
# Latest number \\(2,629\\) on 2020-04-19
# Best fit exponential: \(223 \times 10^{0.031t}\) (doubling rate \(9.7\) days)
# Best fit sigmoid: \(\dfrac{2,795.0}{1 + 10^{-0.071 (t - 23.4)}}\) (asimptote \(2,795.0\))
# ### Dead
# Start date 2020-03-18 (1st day with 0.1 dead per million)
# Latest number \\(375\\) on 2020-04-19
# Best fit exponential: \(26.1 \times 10^{0.037t}\) (doubling rate \(8.0\) days)
# Best fit sigmoid: \(\dfrac{396.1}{1 + 10^{-0.103 (t - 21.4)}}\) (asimptote \(396.1\))
# ### Active
# Start date 2020-03-17 (1st day with 1 active per million)
# Latest number \\(1,207\\) on 2020-04-19
# ## Mauritius
# Population \\(1,271,768\\)
# ### Confirmed
# Start date 2020-03-18 (1st day with 1 confirmed per million)
# Latest number \\(328\\) on 2020-04-19
# Best fit exponential: \(62.4 \times 10^{0.025t}\) (doubling rate \(12.1\) days)
# Best fit sigmoid: \(\dfrac{343.0}{1 + 10^{-0.098 (t - 15.6)}}\) (asimptote \(343.0\))
# ### Dead
# Start date 2020-03-21 (1st day with 0.1 dead per million)
# Latest number \\(9\\) on 2020-04-19
# ### Active
# Start date 2020-03-18 (1st day with 1 active per million)
# Latest number \\(111\\) on 2020-04-19
# ## Congo (Kinshasa)
# Population \\(5,518,087\\)
# ### Confirmed
# Start date 2020-03-19 (1st day with 1 confirmed per million)
# Latest number \\(327\\) on 2020-04-19
# Best fit exponential: \(40.4 \times 10^{0.029t}\) (doubling rate \(10.4\) days)
# Best fit sigmoid: \(\dfrac{377.3}{1 + 10^{-0.058 (t - 21.3)}}\) (asimptote \(377.3\))
# ### Dead
# Start date 2020-03-21 (1st day with 0.1 dead per million)
# Latest number \\(25\\) on 2020-04-19
# Best fit exponential: \(4.8 \times 10^{0.026t}\) (doubling rate \(11.7\) days)
# Best fit sigmoid: \(\dfrac{22.4}{1 + 10^{-0.120 (t - 12.5)}}\) (asimptote \(22.4\))
# ### Active
# Start date 2020-03-19 (1st day with 1 active per million)
# Latest number \\(276\\) on 2020-04-19
# ## Morocco
# Population \\(36,910,560\\)
# ### Confirmed
# Start date 2020-03-17 (1st day with 1 confirmed per million)
# Latest number \\(2,855\\) on 2020-04-19
# Best fit exponential: \(160 \times 10^{0.037t}\) (doubling rate \(8.1\) days)
# Best fit sigmoid: \(\dfrac{5,261.7}{1 + 10^{-0.052 (t - 33.0)}}\) (asimptote \(5,261.7\))
# ### Dead
# Start date 2020-03-22 (1st day with 0.1 dead per million)
# Latest number \\(141\\) on 2020-04-19
# Best fit exponential: \(21 \times 10^{0.031t}\) (doubling rate \(9.7\) days)
# Best fit sigmoid: \(\dfrac{145.7}{1 + 10^{-0.095 (t - 15.4)}}\) (asimptote \(145.7\))
# ### Active
# Start date 2020-03-18 (1st day with 1 active per million)
# Latest number \\(2,387\\) on 2020-04-19
# ## Tunisia
# Population \\(11,818,619\\)
# ### Confirmed
# Start date 2020-03-13 (1st day with 1 confirmed per million)
# Latest number \\(879\\) on 2020-04-19
# Best fit exponential: \(103 \times 10^{0.026t}\) (doubling rate \(11.5\) days)
# Best fit sigmoid: \(\dfrac{858.4}{1 + 10^{-0.081 (t - 20.7)}}\) (asimptote \(858.4\))
# ### Dead
# Start date 2020-03-22 (1st day with 0.1 dead per million)
# Latest number \\(38\\) on 2020-04-19
# Best fit exponential: \(6.38 \times 10^{0.029t}\) (doubling rate \(10.4\) days)
# Best fit sigmoid: \(\dfrac{42.5}{1 + 10^{-0.074 (t - 16.1)}}\) (asimptote \(42.5\))
# ### Active
# Start date 2020-03-13 (1st day with 1 active per million)
# Latest number \\(798\\) on 2020-04-19
# ## Egypt
# Population \\(102,334,404\\)
# ### Confirmed
# Start date 2020-03-14 (1st day with 1 confirmed per million)
# Latest number \\(3,144\\) on 2020-04-19
# Best fit exponential: \(195 \times 10^{0.033t}\) (doubling rate \(9.0\) days)
# Best fit sigmoid: \(\dfrac{5,930.4}{1 + 10^{-0.047 (t - 35.8)}}\) (asimptote \(5,930.4\))
# ### Dead
# Start date 2020-03-22 (1st day with 0.1 dead per million)
# Latest number \\(239\\) on 2020-04-19
# Best fit exponential: \(22.6 \times 10^{0.036t}\) (doubling rate \(8.3\) days)
# Best fit sigmoid: \(\dfrac{362.2}{1 + 10^{-0.058 (t - 24.4)}}\) (asimptote \(362.2\))
# ### Active
# Start date 2020-03-16 (1st day with 1 active per million)
# Latest number \\(2,173\\) on 2020-04-19
# ## Djibouti
# Population \\(988,000\\)
# ### Confirmed
# Start date 2020-03-18 (1st day with 1 confirmed per million)
# Latest number \\(846\\) on 2020-04-19
# Best fit exponential: \(2.24 \times 10^{0.079t}\) (doubling rate \(3.8\) days)
# Best fit sigmoid: \(\dfrac{1,838.6}{1 + 10^{-0.106 (t - 33.4)}}\) (asimptote \(1,838.6\))
# ### Dead
# Start date 2020-04-10 (1st day with 0.1 dead per million)
# Latest number \\(2\\) on 2020-04-19
# ### Active
# Start date 2020-03-18 (1st day with 1 active per million)
# Latest number \\(742\\) on 2020-04-19
# ## Burkina Faso
# Population \\(20,903,273\\)
# ### Confirmed
# Start date 2020-03-19 (1st day with 1 confirmed per million)
# Latest number \\(576\\) on 2020-04-19
# Best fit exponential: \(118 \times 10^{0.023t}\) (doubling rate \(12.9\) days)
# Best fit sigmoid: \(\dfrac{630.4}{1 + 10^{-0.063 (t - 16.2)}}\) (asimptote \(630.4\))
# ### Dead
# Start date 2020-03-22 (1st day with 0.1 dead per million)
# Latest number \\(36\\) on 2020-04-19
# Best fit exponential: \(6.86 \times 10^{0.026t}\) (doubling rate \(11.5\) days)
# Best fit sigmoid: \(\dfrac{47.8}{1 + 10^{-0.050 (t - 19.3)}}\) (asimptote \(47.8\))
# ### Active
# Start date 2020-03-19 (1st day with 1 active per million)
# Latest number \\(202\\) on 2020-04-19

# %% [markdown]
# # Recovering countries that had over 300 active cases at peak

# %%
draw_recovering_countries(get_recovering_countries_info(continent=nb_continent))
# Out:
# ## List of all recovering countries (the top 4 not covered above are also analyzed below)
# Burkina Faso recovered 37%

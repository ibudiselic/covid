# %% [markdown]
# # Please read the [README](https://github.com/ibudiselic/covid/blob/master/README.md) file in this repository.

# %%
# Load all the data and functionality.
# %run lib.ipynb

nb_continent = 'Africa'
display(Markdown(f'# Analysis of the most affected countries in {nb_continent}'))
countries_to_plot = get_top_countries_by_relative_deaths(continent=nb_continent)
# Out:
# # Analysis of the most affected countries in Africa

# %%
# %%javascript
# IPython.OutputArea.auto_scroll_threshold = 9999;

# %% [markdown]
# # Cross-country comparison over absolute dates

# %%
for series in ['confirmed', 'dead']:
    compare_countries_absolute_dates(series)
# Out:
# ## Confirmed
# ## Dead

# %% [markdown]
# # Cross-country comparison with approximately aligned start days

# %%
compare_countries_relative_dates('confirmed', start_info=(0.01, '10 confirmed per million'))
# Out:
# ## Confirmed

# %%
compare_countries_relative_dates('dead', start_info=(0.001, '1 death per million'))
# Out:
# ## Dead

# %% [markdown]
# # Per-country analysis with exponential and sigmoidal projections, and new cases analysis
#
# <span style="color:red;">
# IMPORTANT: The projections are only accurate if the fit is good (it often isn't), and assuming nothing changes
# going forward. The sigmoid is omitted if a reasonable fit can't be computed, but this still doesn't mean that
# the fit is good if it is shown.
# </span>
#
# The dashed lines show best fit projections from a few previous days for comparison.

# %%
for country in countries_to_plot:
    country_deep_dive(country)
# Out:
# ## Algeria
# Population \\(43,851,044\\)
# ### Confirmed
# Start date 2020-03-15 (1st day with 1 confirmed per million)
# Latest number \\(2,534\\) on 2020-04-18
# Best fit exponential: \(212 \times 10^{0.032t}\) (doubling rate \(9.4\) days)
# Best fit sigmoid: \(\dfrac{2,664.1}{1 + 10^{-0.074 (t - 22.7)}}\) (asimptote \(2,664.1\))
# ### Dead
# Start date 2020-03-18 (1st day with 0.1 dead per million)
# Latest number \\(367\\) on 2020-04-18
# Best fit exponential: \(23.3 \times 10^{0.040t}\) (doubling rate \(7.6\) days)
# Best fit sigmoid: \(\dfrac{394.3}{1 + 10^{-0.104 (t - 21.4)}}\) (asimptote \(394.3\))
# ### Active
# Start date 2020-03-17 (1st day with 1 active per million)
# Latest number \\(1,273\\) on 2020-04-18
# ## Mauritius
# Population \\(1,271,768\\)
# ### Confirmed
# Start date 2020-03-18 (1st day with 1 confirmed per million)
# Latest number \\(325\\) on 2020-04-18
# Best fit exponential: \(58.7 \times 10^{0.026t}\) (doubling rate \(11.4\) days)
# Best fit sigmoid: \(\dfrac{345.0}{1 + 10^{-0.097 (t - 15.6)}}\) (asimptote \(345.0\))
# ### Dead
# Start date 2020-03-21 (1st day with 0.1 dead per million)
# Latest number \\(9\\) on 2020-04-18
# ### Active
# Start date 2020-03-18 (1st day with 1 active per million)
# Latest number \\(136\\) on 2020-04-18
# ## Congo (Kinshasa)
# Population \\(5,518,087\\)
# ### Confirmed
# Start date 2020-03-19 (1st day with 1 confirmed per million)
# Latest number \\(307\\) on 2020-04-18
# Best fit exponential: \(39.5 \times 10^{0.030t}\) (doubling rate \(10.2\) days)
# Best fit sigmoid: \(\dfrac{343.8}{1 + 10^{-0.062 (t - 19.8)}}\) (asimptote \(343.8\))
# ### Dead
# Start date 2020-03-21 (1st day with 0.1 dead per million)
# Latest number \\(25\\) on 2020-04-18
# Best fit exponential: \(4.63 \times 10^{0.027t}\) (doubling rate \(11.3\) days)
# Best fit sigmoid: \(\dfrac{21.8}{1 + 10^{-0.127 (t - 12.2)}}\) (asimptote \(21.8\))
# ### Active
# Start date 2020-03-19 (1st day with 1 active per million)
# Latest number \\(256\\) on 2020-04-18
# ## Morocco
# Population \\(36,910,560\\)
# ### Confirmed
# Start date 2020-03-17 (1st day with 1 confirmed per million)
# Latest number \\(2,685\\) on 2020-04-18
# Best fit exponential: \(155 \times 10^{0.038t}\) (doubling rate \(7.9\) days)
# Best fit sigmoid: \(\dfrac{4,669.0}{1 + 10^{-0.054 (t - 31.3)}}\) (asimptote \(4,669.0\))
# ### Dead
# Start date 2020-03-22 (1st day with 0.1 dead per million)
# Latest number \\(137\\) on 2020-04-18
# Best fit exponential: \(19.7 \times 10^{0.033t}\) (doubling rate \(9.2\) days)
# Best fit sigmoid: \(\dfrac{144.5}{1 + 10^{-0.096 (t - 15.3)}}\) (asimptote \(144.5\))
# ### Active
# Start date 2020-03-18 (1st day with 1 active per million)
# Latest number \\(2,234\\) on 2020-04-18
# ## Tunisia
# Population \\(11,818,619\\)
# ### Confirmed
# Start date 2020-03-13 (1st day with 1 confirmed per million)
# Latest number \\(864\\) on 2020-04-18
# Best fit exponential: \(98 \times 10^{0.027t}\) (doubling rate \(11.0\) days)
# Best fit sigmoid: \(\dfrac{838.9}{1 + 10^{-0.084 (t - 20.4)}}\) (asimptote \(838.9\))
# ### Dead
# Start date 2020-03-22 (1st day with 0.1 dead per million)
# Latest number \\(37\\) on 2020-04-18
# Best fit exponential: \(6.03 \times 10^{0.030t}\) (doubling rate \(9.9\) days)
# Best fit sigmoid: \(\dfrac{42.7}{1 + 10^{-0.073 (t - 16.2)}}\) (asimptote \(42.7\))
# ### Active
# Start date 2020-03-13 (1st day with 1 active per million)
# Latest number \\(784\\) on 2020-04-18
# ## Egypt
# Population \\(102,334,404\\)
# ### Confirmed
# Start date 2020-03-14 (1st day with 1 confirmed per million)
# Latest number \\(3,032\\) on 2020-04-18
# Best fit exponential: \(187 \times 10^{0.034t}\) (doubling rate \(8.8\) days)
# Best fit sigmoid: \(\dfrac{6,053.5}{1 + 10^{-0.047 (t - 36.1)}}\) (asimptote \(6,053.5\))
# ### Dead
# Start date 2020-03-22 (1st day with 0.1 dead per million)
# Latest number \\(224\\) on 2020-04-18
# Best fit exponential: \(21.8 \times 10^{0.037t}\) (doubling rate \(8.1\) days)
# Best fit sigmoid: \(\dfrac{341.5}{1 + 10^{-0.059 (t - 23.6)}}\) (asimptote \(341.5\))
# ### Active
# Start date 2020-03-16 (1st day with 1 active per million)
# Latest number \\(2,107\\) on 2020-04-18
# ## Djibouti
# Population \\(988,000\\)
# ### Confirmed
# Start date 2020-03-18 (1st day with 1 confirmed per million)
# Latest number \\(732\\) on 2020-04-18
# Best fit exponential: \(1.59 \times 10^{0.084t}\) (doubling rate \(3.6\) days)
# Best fit sigmoid: \(\dfrac{3,052.4}{1 + 10^{-0.098 (t - 36.7)}}\) (asimptote \(3,052.4\))
# ### Dead
# Start date 2020-04-10 (1st day with 0.1 dead per million)
# Latest number \\(2\\) on 2020-04-18
# ### Active
# Start date 2020-03-18 (1st day with 1 active per million)
# Latest number \\(654\\) on 2020-04-18
# ## Burkina Faso
# Population \\(20,903,273\\)
# ### Confirmed
# Start date 2020-03-19 (1st day with 1 confirmed per million)
# Latest number \\(565\\) on 2020-04-18
# Best fit exponential: \(114 \times 10^{0.024t}\) (doubling rate \(12.4\) days)
# Best fit sigmoid: \(\dfrac{627.7}{1 + 10^{-0.063 (t - 16.1)}}\) (asimptote \(627.7\))
# ### Dead
# Start date 2020-03-22 (1st day with 0.1 dead per million)
# Latest number \\(36\\) on 2020-04-18
# Best fit exponential: \(6.63 \times 10^{0.027t}\) (doubling rate \(11.1\) days)
# Best fit sigmoid: \(\dfrac{47.9}{1 + 10^{-0.050 (t - 19.4)}}\) (asimptote \(47.9\))
# ### Active
# Start date 2020-03-19 (1st day with 1 active per million)
# Latest number \\(208\\) on 2020-04-18

# %% [markdown]
# # Recovering countries that had over 300 active cases at peak

# %%
draw_recovering_countries(get_recovering_countries_info(continent=nb_continent))
# Out:
# ## List of all recovering countries (the top 4 not covered above are also analyzed below)

# %% [markdown]
# # Please read the [README](https://github.com/ibudiselic/covid/blob/master/README.md) file in this repository.

# %%
# Load all the data and functionality.
# %run lib.ipynb

nb_continent = 'Africa'
display(Markdown(f'# Analysis of the most affected countries in {nb_continent}'))
countries_to_plot = get_top_countries_by_relative_deaths(continent=nb_continent)
# Out:
# # Analysis of the most affected countries in Africa

# %%
# %%javascript
# IPython.OutputArea.auto_scroll_threshold = 9999;

# %% [markdown]
# # Cross-country comparison over absolute dates

# %%
for series in ['confirmed', 'dead']:
    compare_countries_absolute_dates(series)
# Out:
# ## Confirmed
# ## Dead

# %% [markdown]
# # Cross-country comparison with approximately aligned start days

# %%
compare_countries_relative_dates('confirmed', start_info=(0.01, '10 confirmed per million'))
# Out:
# ## Confirmed

# %%
compare_countries_relative_dates('dead', start_info=(0.001, '1 death per million'))
# Out:
# ## Dead

# %% [markdown]
# # Per-country analysis with exponential and sigmoidal projections, and new cases analysis
#
# <span style="color:red;">
# IMPORTANT: The projections are only accurate if the fit is good (it often isn't), and assuming nothing changes
# going forward. The sigmoid is omitted if a reasonable fit can't be computed, but this still doesn't mean that
# the fit is good if it is shown.
# </span>
#
# The dashed lines show best fit projections from a few previous days for comparison.

# %%
for country in countries_to_plot:
    country_deep_dive(country)
# Out:
# ## Algeria
# Population \\(43,851,044\\)
# ### Confirmed
# Start date 2020-03-15 (1st day with 1 confirmed per million)
# Latest number \\(2,910\\) on 2020-04-22
# Best fit exponential: \(260 \times 10^{0.028t}\) (doubling rate \(10.7\) days)
# Best fit sigmoid: \(\dfrac{3,146.1}{1 + 10^{-0.063 (t - 25.3)}}\) (asimptote \(3,146.1\))
# ### Dead
# Start date 2020-03-18 (1st day with 0.1 dead per million)
# Latest number \\(402\\) on 2020-04-22
# Best fit exponential: \(34.5 \times 10^{0.032t}\) (doubling rate \(9.5\) days)
# Best fit sigmoid: \(\dfrac{406.4}{1 + 10^{-0.100 (t - 21.7)}}\) (asimptote \(406.4\))
# ### Active
# Start date 2020-03-17 (1st day with 1 active per million)
# Latest number \\(1,304\\) on 2020-04-22
# ## Mauritius
# Population \\(1,271,768\\)
# ### Confirmed
# Start date 2020-03-18 (1st day with 1 confirmed per million)
# Latest number \\(329\\) on 2020-04-22
# Best fit exponential: \(73.1 \times 10^{0.021t}\) (doubling rate \(14.3\) days)
# Best fit sigmoid: \(\dfrac{338.9}{1 + 10^{-0.100 (t - 15.4)}}\) (asimptote \(338.9\))
# ### Dead
# Start date 2020-03-21 (1st day with 0.1 dead per million)
# Latest number \\(9\\) on 2020-04-22
# ### Active
# Start date 2020-03-18 (1st day with 1 active per million)
# Latest number \\(59\\) on 2020-04-22
# ## Congo (Kinshasa)
# Population \\(5,518,087\\)
# ### Confirmed
# Start date 2020-03-19 (1st day with 1 confirmed per million)
# Latest number \\(359\\) on 2020-04-22
# Best fit exponential: \(44.3 \times 10^{0.027t}\) (doubling rate \(11.2\) days)
# Best fit sigmoid: \(\dfrac{444.5}{1 + 10^{-0.052 (t - 24.2)}}\) (asimptote \(444.5\))
# ### Dead
# Start date 2020-03-21 (1st day with 0.1 dead per million)
# Latest number \\(25\\) on 2020-04-22
# Best fit exponential: \(5.44 \times 10^{0.022t}\) (doubling rate \(13.4\) days)
# Best fit sigmoid: \(\dfrac{23.6}{1 + 10^{-0.106 (t - 13.1)}}\) (asimptote \(23.6\))
# ### Active
# Start date 2020-03-19 (1st day with 1 active per million)
# Latest number \\(289\\) on 2020-04-22
# ## Morocco
# Population \\(36,910,560\\)
# ### Confirmed
# Start date 2020-03-17 (1st day with 1 confirmed per million)
# Latest number \\(3,446\\) on 2020-04-22
# Best fit exponential: \(179 \times 10^{0.035t}\) (doubling rate \(8.5\) days)
# Best fit sigmoid: \(\dfrac{6,438.1}{1 + 10^{-0.049 (t - 36.0)}}\) (asimptote \(6,438.1\))
# ### Dead
# Start date 2020-03-22 (1st day with 0.1 dead per million)
# Latest number \\(149\\) on 2020-04-22
# Best fit exponential: \(25 \times 10^{0.027t}\) (doubling rate \(11.3\) days)
# Best fit sigmoid: \(\dfrac{149.1}{1 + 10^{-0.092 (t - 15.7)}}\) (asimptote \(149.1\))
# ### Active
# Start date 2020-03-18 (1st day with 1 active per million)
# Latest number \\(2,880\\) on 2020-04-22
# ## Tunisia
# Population \\(11,818,619\\)
# ### Confirmed
# Start date 2020-03-13 (1st day with 1 confirmed per million)
# Latest number \\(909\\) on 2020-04-22
# Best fit exponential: \(121 \times 10^{0.023t}\) (doubling rate \(13.0\) days)
# Best fit sigmoid: \(\dfrac{895.2}{1 + 10^{-0.076 (t - 21.4)}}\) (asimptote \(895.2\))
# ### Dead
# Start date 2020-03-22 (1st day with 0.1 dead per million)
# Latest number \\(38\\) on 2020-04-22
# Best fit exponential: \(7.57 \times 10^{0.025t}\) (doubling rate \(12.3\) days)
# Best fit sigmoid: \(\dfrac{41.2}{1 + 10^{-0.077 (t - 15.7)}}\) (asimptote \(41.2\))
# ### Active
# Start date 2020-03-13 (1st day with 1 active per million)
# Latest number \\(681\\) on 2020-04-22
# ## Egypt
# Population \\(102,334,404\\)
# ### Confirmed
# Start date 2020-03-14 (1st day with 1 confirmed per million)
# Latest number \\(3,659\\) on 2020-04-22
# Best fit exponential: \(223 \times 10^{0.031t}\) (doubling rate \(9.7\) days)
# Best fit sigmoid: \(\dfrac{6,059.8}{1 + 10^{-0.047 (t - 36.1)}}\) (asimptote \(6,059.8\))
# ### Dead
# Start date 2020-03-22 (1st day with 0.1 dead per million)
# Latest number \\(276\\) on 2020-04-22
# Best fit exponential: \(25.7 \times 10^{0.033t}\) (doubling rate \(9.1\) days)
# Best fit sigmoid: \(\dfrac{398.6}{1 + 10^{-0.055 (t - 25.9)}}\) (asimptote \(398.6\))
# ### Active
# Start date 2020-03-16 (1st day with 1 active per million)
# Latest number \\(2,448\\) on 2020-04-22
# ## Djibouti
# Population \\(988,000\\)
# ### Confirmed
# Start date 2020-03-18 (1st day with 1 confirmed per million)
# Latest number \\(974\\) on 2020-04-22
# Best fit exponential: \(7.29 \times 10^{0.061t}\) (doubling rate \(5.0\) days)
# Best fit sigmoid: \(\dfrac{1,173.0}{1 + 10^{-0.129 (t - 30.3)}}\) (asimptote \(1,173.0\))
# ### Dead
# Start date 2020-04-10 (1st day with 0.1 dead per million)
# Latest number \\(2\\) on 2020-04-22
# ### Active
# Start date 2020-03-18 (1st day with 1 active per million)
# Latest number \\(789\\) on 2020-04-22
# ## Burkina Faso
# Population \\(20,903,273\\)
# ### Confirmed
# Start date 2020-03-19 (1st day with 1 confirmed per million)
# Latest number \\(609\\) on 2020-04-22
# Best fit exponential: \(132 \times 10^{0.021t}\) (doubling rate \(14.5\) days)
# Best fit sigmoid: \(\dfrac{641.8}{1 + 10^{-0.061 (t - 16.5)}}\) (asimptote \(641.8\))
# ### Dead
# Start date 2020-03-22 (1st day with 0.1 dead per million)
# Latest number \\(39\\) on 2020-04-22
# Best fit exponential: \(7.54 \times 10^{0.024t}\) (doubling rate \(12.7\) days)
# Best fit sigmoid: \(\dfrac{48.5}{1 + 10^{-0.050 (t - 19.6)}}\) (asimptote \(48.5\))
# ### Active
# Start date 2020-03-19 (1st day with 1 active per million)
# Latest number \\(181\\) on 2020-04-22

# %% [markdown]
# # Recovering countries that had over 300 active cases at peak

# %%
draw_recovering_countries(get_recovering_countries_info(continent=nb_continent))
# Out:
# ## List of all recovering countries (the top 4 not covered above are also analyzed below)
# Burkina Faso recovered 44%

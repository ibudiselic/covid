# %% [markdown]
# # Please read the [README](https://github.com/ibudiselic/covid/blob/master/README.md) file in this repository.

# %%
# Load all the data and functionality.
# %run lib.ipynb

nb_continent = 'Africa'
display(Markdown(f'# Analysis of the most affected countries in {nb_continent}'))
countries_to_plot = get_top_countries_by_relative_deaths(continent=nb_continent)
# Out:
# # Analysis of the most affected countries in Africa

# %%
# %%javascript
# IPython.OutputArea.auto_scroll_threshold = 9999;

# %% [markdown]
# # Cross-country comparison over absolute dates

# %%
for series in ['confirmed', 'dead']:
    compare_countries_absolute_dates(series)
# Out:
# ## Confirmed
# ## Dead

# %% [markdown]
# # Cross-country comparison with approximately aligned start days

# %%
compare_countries_relative_dates('confirmed', start_info=(0.01, '10 confirmed per million'))
# Out:
# ## Confirmed

# %%
compare_countries_relative_dates('dead', start_info=(0.001, '1 death per million'))
# Out:
# ## Dead

# %% [markdown]
# # Per-country analysis with exponential and sigmoidal projections, and new cases analysis
#
# <span style="color:red;">
# IMPORTANT: The projections are only accurate if the fit is good (it often isn't), and assuming nothing changes
# going forward. The sigmoid is omitted if a reasonable fit can't be computed, but this still doesn't mean that
# the fit is good if it is shown.
# </span>
#
# The dashed lines show best fit projections from a few previous days for comparison.

# %%
for country in countries_to_plot:
    country_deep_dive(country)
# Out:
# ## Algeria
# Population \\(43,851,044\\)
# ### Confirmed
# Start date 2020-03-15 (1st day with 1 confirmed per million)
# Latest number \\(3,649\\) on 2020-04-28
# Best fit exponential: \(332 \times 10^{0.024t}\) (doubling rate \(12.5\) days)
# Best fit sigmoid: \(\dfrac{3,997.6}{1 + 10^{-0.051 (t - 29.7)}}\) (asimptote \(3,997.6\))
# ### Dead
# Start date 2020-03-18 (1st day with 0.1 dead per million)
# Latest number \\(437\\) on 2020-04-28
# Best fit exponential: \(52.4 \times 10^{0.024t}\) (doubling rate \(12.5\) days)
# Best fit sigmoid: \(\dfrac{427.5}{1 + 10^{-0.092 (t - 22.4)}}\) (asimptote \(427.5\))
# ### Active
# Start date 2020-03-17 (1st day with 1 active per million)
# Latest number \\(1,561\\) on 2020-04-28
# ## Mauritius
# Population \\(1,271,768\\)
# ### Confirmed
# Start date 2020-03-18 (1st day with 1 confirmed per million)
# Latest number \\(334\\) on 2020-04-28
# Best fit exponential: \(92.4 \times 10^{0.016t}\) (doubling rate \(19.1\) days)
# Best fit sigmoid: \(\dfrac{336.4}{1 + 10^{-0.101 (t - 15.3)}}\) (asimptote \(336.4\))
# ### Dead
# Start date 2020-03-21 (1st day with 0.1 dead per million)
# Latest number \\(10\\) on 2020-04-28
# Best fit exponential: \(3.47 \times 10^{0.013t}\) (doubling rate \(22.8\) days)
# Best fit sigmoid: \(\dfrac{9.3}{1 + 10^{-0.097 (t - 11.0)}}\) (asimptote \(9.3\))
# ### Active
# Start date 2020-03-18 (1st day with 1 active per million)
# Latest number \\(21\\) on 2020-04-28
# ## Congo (Kinshasa)
# Population \\(5,518,087\\)
# ### Confirmed
# Start date 2020-03-19 (1st day with 1 confirmed per million)
# Latest number \\(471\\) on 2020-04-28
# Best fit exponential: \(51.2 \times 10^{0.024t}\) (doubling rate \(12.4\) days)
# Best fit sigmoid: \(\dfrac{647.8}{1 + 10^{-0.041 (t - 31.8)}}\) (asimptote \(647.8\))
# ### Dead
# Start date 2020-03-21 (1st day with 0.1 dead per million)
# Latest number \\(30\\) on 2020-04-28
# Best fit exponential: \(6.51 \times 10^{0.018t}\) (doubling rate \(16.6\) days)
# Best fit sigmoid: \(\dfrac{26.4}{1 + 10^{-0.081 (t - 14.7)}}\) (asimptote \(26.4\))
# ### Active
# Start date 2020-03-19 (1st day with 1 active per million)
# Latest number \\(385\\) on 2020-04-28
# ## Morocco
# Population \\(36,910,560\\)
# ### Confirmed
# Start date 2020-03-17 (1st day with 1 confirmed per million)
# Latest number \\(4,252\\) on 2020-04-28
# Best fit exponential: \(255 \times 10^{0.030t}\) (doubling rate \(10.2\) days)
# Best fit sigmoid: \(\dfrac{5,989.6}{1 + 10^{-0.050 (t - 34.8)}}\) (asimptote \(5,989.6\))
# ### Dead
# Start date 2020-03-22 (1st day with 0.1 dead per million)
# Latest number \\(165\\) on 2020-04-28
# Best fit exponential: \(32.2 \times 10^{0.021t}\) (doubling rate \(14.6\) days)
# Best fit sigmoid: \(\dfrac{160.4}{1 + 10^{-0.081 (t - 16.7)}}\) (asimptote \(160.4\))
# ### Active
# Start date 2020-03-18 (1st day with 1 active per million)
# Latest number \\(3,309\\) on 2020-04-28
# ## Egypt
# Population \\(102,334,404\\)
# ### Confirmed
# Start date 2020-03-14 (1st day with 1 confirmed per million)
# Latest number \\(5,042\\) on 2020-04-28
# Best fit exponential: \(275 \times 10^{0.028t}\) (doubling rate \(10.8\) days)
# Best fit sigmoid: \(\dfrac{8,081.9}{1 + 10^{-0.042 (t - 41.4)}}\) (asimptote \(8,081.9\))
# ### Dead
# Start date 2020-03-22 (1st day with 0.1 dead per million)
# Latest number \\(359\\) on 2020-04-28
# Best fit exponential: \(33.6 \times 10^{0.028t}\) (doubling rate \(10.8\) days)
# Best fit sigmoid: \(\dfrac{448.1}{1 + 10^{-0.051 (t - 27.9)}}\) (asimptote \(448.1\))
# ### Active
# Start date 2020-03-16 (1st day with 1 active per million)
# Latest number \\(3,379\\) on 2020-04-28
# ## Tunisia
# Population \\(11,818,619\\)
# ### Confirmed
# Start date 2020-03-13 (1st day with 1 confirmed per million)
# Latest number \\(975\\) on 2020-04-28
# Best fit exponential: \(157 \times 10^{0.019t}\) (doubling rate \(16.2\) days)
# Best fit sigmoid: \(\dfrac{949.1}{1 + 10^{-0.069 (t - 22.4)}}\) (asimptote \(949.1\))
# ### Dead
# Start date 2020-03-22 (1st day with 0.1 dead per million)
# Latest number \\(40\\) on 2020-04-28
# Best fit exponential: \(9.89 \times 10^{0.018t}\) (doubling rate \(16.7\) days)
# Best fit sigmoid: \(\dfrac{40.0}{1 + 10^{-0.080 (t - 15.3)}}\) (asimptote \(40.0\))
# ### Active
# Start date 2020-03-13 (1st day with 1 active per million)
# Latest number \\(656\\) on 2020-04-28
# ## Cameroon
# Population \\(26,545,863\\)
# ### Confirmed
# Start date 2020-03-21 (1st day with 1 confirmed per million)
# Latest number \\(1,705\\) on 2020-04-28
# Best fit exponential: \(179 \times 10^{0.026t}\) (doubling rate \(11.6\) days)
# Best fit sigmoid: \(\dfrac{2,131.9}{1 + 10^{-0.046 (t - 28.2)}}\) (asimptote \(2,131.9\))
# ### Dead
# Start date 2020-03-29 (1st day with 0.1 dead per million)
# Latest number \\(58\\) on 2020-04-28
# Best fit exponential: \(4.32 \times 10^{0.038t}\) (doubling rate \(7.9\) days)
# Best fit sigmoid: \(\dfrac{101.6}{1 + 10^{-0.058 (t - 27.9)}}\) (asimptote \(101.6\))
# ### Active
# Start date 2020-03-21 (1st day with 1 active per million)
# Latest number \\(732\\) on 2020-04-28
# ## Djibouti
# Population \\(988,000\\)
# ### Confirmed
# Start date 2020-03-18 (1st day with 1 confirmed per million)
# Latest number \\(1,072\\) on 2020-04-28
# Best fit exponential: \(32.4 \times 10^{0.038t}\) (doubling rate \(7.8\) days)
# Best fit sigmoid: \(\dfrac{1,074.8}{1 + 10^{-0.142 (t - 29.6)}}\) (asimptote \(1,074.8\))
# ### Dead
# Start date 2020-04-10 (1st day with 0.1 dead per million)
# Latest number \\(2\\) on 2020-04-28
# ### Active
# Start date 2020-03-18 (1st day with 1 active per million)
# Latest number \\(572\\) on 2020-04-28

# %% [markdown]
# # Recovering countries that had over 300 active cases at peak

# %%
draw_recovering_countries(get_recovering_countries_info(continent=nb_continent))
# Out:
# ## List of all recovering countries (the top 4 not covered above are also analyzed below)
# Burkina Faso recovered 63%
# Niger recovered 46%
# Djibouti recovered 31%
# ## Burkina Faso
# Population \\(20,903,273\\)
# ### Confirmed
# Start date 2020-03-19 (1st day with 1 confirmed per million)
# Latest number \\(638\\) on 2020-04-28
# Best fit exponential: \(159 \times 10^{0.017t}\) (doubling rate \(18.2\) days)
# Best fit sigmoid: \(\dfrac{658.5}{1 + 10^{-0.059 (t - 17.0)}}\) (asimptote \(658.5\))
# ### Dead
# Start date 2020-03-22 (1st day with 0.1 dead per million)
# Latest number \\(42\\) on 2020-04-28
# Best fit exponential: \(9.21 \times 10^{0.019t}\) (doubling rate \(15.7\) days)
# Best fit sigmoid: \(\dfrac{47.7}{1 + 10^{-0.051 (t - 19.2)}}\) (asimptote \(47.7\))
# ### Active
# Start date 2020-03-19 (1st day with 1 active per million)
# Latest number \\(120\\) on 2020-04-28
# ## Niger
# Population \\(24,206,644\\)
# ### Confirmed
# Start date 2020-03-30 (1st day with 1 confirmed per million)
# Latest number \\(709\\) on 2020-04-28
# Best fit exponential: \(204 \times 10^{0.021t}\) (doubling rate \(14.6\) days)
# Best fit sigmoid: \(\dfrac{681.7}{1 + 10^{-0.127 (t - 10.1)}}\) (asimptote \(681.7\))
# ### Dead
# Start date 2020-03-30 (1st day with 0.1 dead per million)
# Latest number \\(31\\) on 2020-04-28
# Best fit exponential: \(5.23 \times 10^{0.026t}\) (doubling rate \(11.5\) days)
# Best fit sigmoid: \(\dfrac{75.7}{1 + 10^{-0.034 (t - 34.8)}}\) (asimptote \(75.7\))
# ### Active
# Start date 2020-04-01 (1st day with 1 active per million)
# Latest number \\(275\\) on 2020-04-28

# %% [markdown]
# # Please read the [README](https://github.com/ibudiselic/covid/blob/master/README.md) file in this repository.

# %%
# Load all the data and functionality.
# %run lib.ipynb

nb_continent = 'Europe'
display(Markdown(f'# Analysis of the most affected countries in {nb_continent}'))
countries_to_plot = get_top_countries_by_relative_deaths(continent=nb_continent)
# Out:
# # Analysis of the most affected countries in Europe

# %%
# %%javascript
# IPython.OutputArea.auto_scroll_threshold = 9999;

# %% [markdown]
# # Cross-country comparison over absolute dates

# %%
for series in ['confirmed', 'dead']:
    compare_countries_absolute_dates(series)
# Out:
# ## Confirmed
# ## Dead

# %% [markdown]
# # Cross-country comparison with approximately aligned start days

# %%
compare_countries_relative_dates('confirmed', start_info=(0.01, '10 confirmed per million'))
# Out:
# ## Confirmed

# %%
compare_countries_relative_dates('dead', start_info=(0.001, '1 death per million'))
# Out:
# ## Dead

# %% [markdown]
# # Per-country analysis with exponential and sigmoidal projections, and new cases analysis
#
# <span style="color:red;">
# IMPORTANT: The projections are only accurate if the fit is good (it often isn't), and assuming nothing changes
# going forward. The sigmoid is omitted if a reasonable fit can't be computed, but this still doesn't mean that
# the fit is good if it is shown.
# </span>
#
# The dashed lines show best fit projections from a few previous days for comparison.

# %%
for country in countries_to_plot:
    country_deep_dive(country)
# Out:
# ## Belgium
# Population \\(11,589,623\\)
# ### Confirmed
# Start date 2020-03-03 (1st day with 1 confirmed per million)
# Latest number \\(45,325\\) on 2020-04-25
# Best fit exponential: \(2.28 \times 10^{3} \times 10^{0.025t}\) (doubling rate \(11.9\) days)
# Best fit sigmoid: \(\dfrac{48,255.7}{1 + 10^{-0.059 (t - 37.4)}}\) (asimptote \(48,255.7\))
# ### Dead
# Start date 2020-03-11 (1st day with 0.1 dead per million)
# Latest number \\(6,917\\) on 2020-04-25
# Best fit exponential: \(229 \times 10^{0.034t}\) (doubling rate \(8.9\) days)
# Best fit sigmoid: \(\dfrac{7,403.7}{1 + 10^{-0.080 (t - 33.5)}}\) (asimptote \(7,403.7\))
# ### Active
# Start date 2020-03-03 (1st day with 1 active per million)
# Latest number \\(27,991\\) on 2020-04-25
# ## Spain
# Population \\(46,754,778\\)
# ### Confirmed
# Start date 2020-03-01 (1st day with 1 confirmed per million)
# Latest number \\(223,759\\) on 2020-04-25
# Best fit exponential: \(1.76 \times 10^{4} \times 10^{0.021t}\) (doubling rate \(14.3\) days)
# Best fit sigmoid: \(\dfrac{215,431.4}{1 + 10^{-0.065 (t - 33.3)}}\) (asimptote \(215,431.4\))
# ### Dead
# Start date 2020-03-06 (1st day with 0.1 dead per million)
# Latest number \\(22,902\\) on 2020-04-25
# Best fit exponential: \(1.98 \times 10^{3} \times 10^{0.022t}\) (doubling rate \(13.4\) days)
# Best fit sigmoid: \(\dfrac{22,380.3}{1 + 10^{-0.072 (t - 29.7)}}\) (asimptote \(22,380.3\))
# ### Active
# Start date 2020-03-01 (1st day with 1 active per million)
# Latest number \\(105,149\\) on 2020-04-25
# ## Italy
# Population \\(60,461,826\\)
# ### Confirmed
# Start date 2020-02-22 (1st day with 1 confirmed per million)
# Latest number \\(195,351\\) on 2020-04-25
# Best fit exponential: \(1.68 \times 10^{4} \times 10^{0.018t}\) (doubling rate \(16.9\) days)
# Best fit sigmoid: \(\dfrac{193,553.6}{1 + 10^{-0.053 (t - 37.9)}}\) (asimptote \(193,553.6\))
# ### Dead
# Start date 2020-02-24 (1st day with 0.1 dead per million)
# Latest number \\(26,384\\) on 2020-04-25
# Best fit exponential: \(1.82 \times 10^{3} \times 10^{0.020t}\) (doubling rate \(15.1\) days)
# Best fit sigmoid: \(\dfrac{26,330.2}{1 + 10^{-0.056 (t - 38.8)}}\) (asimptote \(26,330.2\))
# ### Active
# Start date 2020-02-23 (1st day with 1 active per million)
# Latest number \\(105,847\\) on 2020-04-25
# ## France
# Population \\(65,273,511\\)
# ### Confirmed
# Start date 2020-02-29 (1st day with 1 confirmed per million)
# Latest number \\(161,644\\) on 2020-04-25
# Best fit exponential: \(8.06 \times 10^{3} \times 10^{0.024t}\) (doubling rate \(12.3\) days)
# Best fit sigmoid: \(\dfrac{185,032.3}{1 + 10^{-0.057 (t - 40.2)}}\) (asimptote \(185,032.3\))
# ### Dead
# Start date 2020-03-06 (1st day with 0.1 dead per million)
# Latest number \\(22,648\\) on 2020-04-25
# Best fit exponential: \(972 \times 10^{0.028t}\) (doubling rate \(10.6\) days)
# Best fit sigmoid: \(\dfrac{23,420.8}{1 + 10^{-0.077 (t - 35.0)}}\) (asimptote \(23,420.8\))
# ### Active
# Start date 2020-02-29 (1st day with 1 active per million)
# Latest number \\(93,624\\) on 2020-04-25
# ## United Kingdom
# Population \\(67,886,011\\)
# ### Confirmed
# Start date 2020-03-04 (1st day with 1 confirmed per million)
# Latest number \\(149,569\\) on 2020-04-25
# Best fit exponential: \(4.68 \times 10^{3} \times 10^{0.029t}\) (doubling rate \(10.2\) days)
# Best fit sigmoid: \(\dfrac{167,087.5}{1 + 10^{-0.062 (t - 39.9)}}\) (asimptote \(167,087.5\))
# ### Dead
# Start date 2020-03-11 (1st day with 0.1 dead per million)
# Latest number \\(20,381\\) on 2020-04-25
# Best fit exponential: \(697 \times 10^{0.033t}\) (doubling rate \(9.1\) days)
# Best fit sigmoid: \(\dfrac{21,702.7}{1 + 10^{-0.076 (t - 33.5)}}\) (asimptote \(21,702.7\))
# ### Active
# Start date 2020-03-04 (1st day with 1 active per million)
# Latest number \\(128,414\\) on 2020-04-25
# ## Netherlands
# Population \\(17,134,872\\)
# ### Confirmed
# Start date 2020-03-02 (1st day with 1 confirmed per million)
# Latest number \\(37,384\\) on 2020-04-25
# Best fit exponential: \(2.29 \times 10^{3} \times 10^{0.023t}\) (doubling rate \(12.9\) days)
# Best fit sigmoid: \(\dfrac{40,080.2}{1 + 10^{-0.055 (t - 37.0)}}\) (asimptote \(40,080.2\))
# ### Dead
# Start date 2020-03-08 (1st day with 0.1 dead per million)
# Latest number \\(4,424\\) on 2020-04-25
# Best fit exponential: \(252 \times 10^{0.027t}\) (doubling rate \(11.3\) days)
# Best fit sigmoid: \(\dfrac{4,596.6}{1 + 10^{-0.065 (t - 32.8)}}\) (asimptote \(4,596.6\))
# ### Active
# Start date 2020-03-02 (1st day with 1 active per million)
# Latest number \\(32,858\\) on 2020-04-25
# ## Sweden
# Population \\(10,099,265\\)
# ### Confirmed
# Start date 2020-02-29 (1st day with 1 confirmed per million)
# Latest number \\(18,177\\) on 2020-04-25
# Best fit exponential: \(700 \times 10^{0.026t}\) (doubling rate \(11.8\) days)
# Best fit sigmoid: \(\dfrac{22,794.2}{1 + 10^{-0.045 (t - 45.5)}}\) (asimptote \(22,794.2\))
# ### Dead
# Start date 2020-03-14 (1st day with 0.1 dead per million)
# Latest number \\(2,192\\) on 2020-04-25
# Best fit exponential: \(68.8 \times 10^{0.036t}\) (doubling rate \(8.4\) days)
# Best fit sigmoid: \(\dfrac{2,902.1}{1 + 10^{-0.062 (t - 35.4)}}\) (asimptote \(2,902.1\))
# ### Active
# Start date 2020-02-29 (1st day with 1 active per million)
# Latest number \\(14,980\\) on 2020-04-25
# ## Ireland
# Population \\(4,937,786\\)
# ### Confirmed
# Start date 2020-03-04 (1st day with 1 confirmed per million)
# Latest number \\(18,561\\) on 2020-04-25
# Best fit exponential: \(498 \times 10^{0.031t}\) (doubling rate \(9.8\) days)
# Best fit sigmoid: \(\dfrac{22,904.4}{1 + 10^{-0.059 (t - 42.2)}}\) (asimptote \(22,904.4\))
# ### Dead
# Start date 2020-03-11 (1st day with 0.1 dead per million)
# Latest number \\(1,063\\) on 2020-04-25
# Best fit exponential: \(13.2 \times 10^{0.042t}\) (doubling rate \(7.2\) days)
# Best fit sigmoid: \(\dfrac{2,288.2}{1 + 10^{-0.053 (t - 47.8)}}\) (asimptote \(2,288.2\))
# ### Active
# Start date 2020-03-04 (1st day with 1 active per million)
# Latest number \\(8,265\\) on 2020-04-25

# %% [markdown]
# # Recovering countries that had over 300 active cases at peak

# %%
draw_recovering_countries(get_recovering_countries_info(continent=nb_continent))
# Out:
# ## List of all recovering countries (the top 4 not covered above are also analyzed below)
# Iceland recovered 81%
# Austria recovered 73%
# Switzerland recovered 58%
# Malta recovered 45%
# Germany recovered 44%
# Denmark recovered 38%
# Andorra recovered 30%
# Croatia recovered 26%
# Czechia recovered 13%
# Lithuania recovered 12%
# Italy recovered 2%
# ## Iceland
# Population \\(341,243\\)
# ### Confirmed
# Start date 2020-02-28 (1st day with 1 confirmed per million)
# Latest number \\(1,790\\) on 2020-04-25
# Best fit exponential: \(249 \times 10^{0.017t}\) (doubling rate \(18.0\) days)
# Best fit sigmoid: \(\dfrac{1,802.6}{1 + 10^{-0.077 (t - 29.3)}}\) (asimptote \(1,802.6\))
# ### Dead
# Start date 2020-03-15 (1st day with 0.1 dead per million)
# Latest number \\(10\\) on 2020-04-25
# Best fit exponential: \(1.43 \times 10^{0.022t}\) (doubling rate \(13.6\) days)
# Best fit sigmoid: \(\dfrac{11.2}{1 + 10^{-0.060 (t - 24.2)}}\) (asimptote \(11.2\))
# ### Active
# Start date 2020-02-28 (1st day with 1 active per million)
# Latest number \\(210\\) on 2020-04-25
# ## Austria
# Population \\(9,006,398\\)
# ### Confirmed
# Start date 2020-03-01 (1st day with 1 confirmed per million)
# Latest number \\(15,148\\) on 2020-04-25
# Best fit exponential: \(2.12 \times 10^{3} \times 10^{0.017t}\) (doubling rate \(17.5\) days)
# Best fit sigmoid: \(\dfrac{14,696.4}{1 + 10^{-0.088 (t - 27.3)}}\) (asimptote \(14,696.4\))
# ### Dead
# Start date 2020-03-12 (1st day with 0.1 dead per million)
# Latest number \\(536\\) on 2020-04-25
# Best fit exponential: \(39.3 \times 10^{0.027t}\) (doubling rate \(11.2\) days)
# Best fit sigmoid: \(\dfrac{557.2}{1 + 10^{-0.070 (t - 28.6)}}\) (asimptote \(557.2\))
# ### Active
# Start date 2020-03-01 (1st day with 1 active per million)
# Latest number \\(2,509\\) on 2020-04-25
# ## Switzerland
# Population \\(8,654,622\\)
# ### Confirmed
# Start date 2020-02-29 (1st day with 1 confirmed per million)
# Latest number \\(28,894\\) on 2020-04-25
# Best fit exponential: \(3.48 \times 10^{3} \times 10^{0.018t}\) (doubling rate \(16.9\) days)
# Best fit sigmoid: \(\dfrac{28,277.0}{1 + 10^{-0.071 (t - 29.8)}}\) (asimptote \(28,277.0\))
# ### Dead
# Start date 2020-03-05 (1st day with 0.1 dead per million)
# Latest number \\(1,599\\) on 2020-04-25
# Best fit exponential: \(90.5 \times 10^{0.025t}\) (doubling rate \(11.8\) days)
# Best fit sigmoid: \(\dfrac{1,640.8}{1 + 10^{-0.069 (t - 34.2)}}\) (asimptote \(1,640.8\))
# ### Active
# Start date 2020-02-29 (1st day with 1 active per million)
# Latest number \\(5,995\\) on 2020-04-25
# ## Malta
# Population \\(441,543\\)
# ### Confirmed
# Start date 2020-03-07 (1st day with 1 confirmed per million)
# Latest number \\(448\\) on 2020-04-25
# Best fit exponential: \(52.6 \times 10^{0.020t}\) (doubling rate \(14.7\) days)
# Best fit sigmoid: \(\dfrac{489.9}{1 + 10^{-0.057 (t - 29.2)}}\) (asimptote \(489.9\))
# ### Dead
# Start date 2020-04-08 (1st day with 0.1 dead per million)
# Latest number \\(4\\) on 2020-04-25
# ### Active
# Start date 2020-03-07 (1st day with 1 active per million)
# Latest number \\(195\\) on 2020-04-25

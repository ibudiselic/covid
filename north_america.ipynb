# %% [markdown]
# # Please read the [README](https://github.com/ibudiselic/covid/blob/master/README.md) file in this repository.

# %%
# Load all the data and functionality.
# %run lib.ipynb

nb_continent = 'North America'
display(Markdown(f'# Analysis of the most affected countries in {nb_continent}'))
countries_to_plot = get_top_countries_by_relative_deaths(continent=nb_continent)
# Out:
# # Analysis of the most affected countries in North America

# %%
# %%javascript
# IPython.OutputArea.auto_scroll_threshold = 9999;

# %% [markdown]
# # Cross-country comparison over absolute dates

# %%
for series in ['confirmed', 'dead']:
    compare_countries_absolute_dates(series)
# Out:
# ## Confirmed
# ## Dead

# %% [markdown]
# # Cross-country comparison with approximately aligned start days

# %%
compare_countries_relative_dates('confirmed', start_info=(0.01, '10 confirmed per million'))
# Out:
# ## Confirmed

# %%
compare_countries_relative_dates('dead', start_info=(0.001, '1 death per million'))
# Out:
# ## Dead

# %% [markdown]
# # Per-country analysis with exponential and sigmoidal projections, and new cases analysis
#
# <span style="color:red;">
# IMPORTANT: The projections are only accurate if the fit is good (it often isn't), and assuming nothing changes
# going forward. The sigmoid is omitted if a reasonable fit can't be computed, but this still doesn't mean that
# the fit is good if it is shown.
# </span>
#
# The dashed lines show best fit projections from a few previous days for comparison.

# %%
for country in countries_to_plot:
    country_deep_dive(country)
# Out:
# ## US
# Population \\(331,002,651\\)
# ### Confirmed
# Start date 2020-03-07 (1st day with 1 confirmed per million)
# Latest number \\(823,786\\) on 2020-04-21
# Best fit exponential: \(3.13 \times 10^{4} \times 10^{0.032t}\) (doubling rate \(9.4\) days)
# Best fit sigmoid: \(\dfrac{893,454.0}{1 + 10^{-0.070 (t - 33.6)}}\) (asimptote \(893,454.0\))
# ### Dead
# Start date 2020-03-11 (1st day with 0.1 dead per million)
# Latest number \\(44,845\\) on 2020-04-21
# Best fit exponential: \(698 \times 10^{0.044t}\) (doubling rate \(6.8\) days)
# Best fit sigmoid: \(\dfrac{61,303.2}{1 + 10^{-0.075 (t - 36.2)}}\) (asimptote \(61,303.2\))
# ### Active
# Start date 2020-03-07 (1st day with 1 active per million)
# Latest number \\(703,737\\) on 2020-04-21
# ## Canada
# Population \\(37,742,154\\)
# ### Confirmed
# Start date 2020-03-06 (1st day with 1 confirmed per million)
# Latest number \\(39,401\\) on 2020-04-21
# Best fit exponential: \(1.22 \times 10^{3} \times 10^{0.033t}\) (doubling rate \(9.1\) days)
# Best fit sigmoid: \(\dfrac{46,367.4}{1 + 10^{-0.063 (t - 36.8)}}\) (asimptote \(46,367.4\))
# ### Dead
# Start date 2020-03-16 (1st day with 0.1 dead per million)
# Latest number \\(1,908\\) on 2020-04-21
# Best fit exponential: \(23.3 \times 10^{0.052t}\) (doubling rate \(5.8\) days)
# Best fit sigmoid: \(\dfrac{3,353.7}{1 + 10^{-0.074 (t - 35.6)}}\) (asimptote \(3,353.7\))
# ### Active
# Start date 2020-03-06 (1st day with 1 active per million)
# Latest number \\(24,305\\) on 2020-04-21
# ## Panama
# Population \\(4,314,767\\)
# ### Confirmed
# Start date 2020-03-11 (1st day with 1 confirmed per million)
# Latest number \\(4,658\\) on 2020-04-21
# Best fit exponential: \(247 \times 10^{0.032t}\) (doubling rate \(9.5\) days)
# Best fit sigmoid: \(\dfrac{5,414.2}{1 + 10^{-0.064 (t - 30.8)}}\) (asimptote \(5,414.2\))
# ### Dead
# Start date 2020-03-11 (1st day with 0.1 dead per million)
# Latest number \\(136\\) on 2020-04-21
# Best fit exponential: \(4.96 \times 10^{0.035t}\) (doubling rate \(8.6\) days)
# Best fit sigmoid: \(\dfrac{164.0}{1 + 10^{-0.064 (t - 33.0)}}\) (asimptote \(164.0\))
# ### Active
# Start date 2020-03-11 (1st day with 1 active per million)
# Latest number \\(4,318\\) on 2020-04-21
# ## Dominican Republic
# Population \\(10,847,910\\)
# ### Confirmed
# Start date 2020-03-14 (1st day with 1 confirmed per million)
# Latest number \\(5,044\\) on 2020-04-21
# Best fit exponential: \(252 \times 10^{0.034t}\) (doubling rate \(8.7\) days)
# Best fit sigmoid: \(\dfrac{7,173.2}{1 + 10^{-0.056 (t - 32.5)}}\) (asimptote \(7,173.2\))
# ### Dead
# Start date 2020-03-19 (1st day with 0.1 dead per million)
# Latest number \\(245\\) on 2020-04-21
# Best fit exponential: \(18.7 \times 10^{0.034t}\) (doubling rate \(8.7\) days)
# Best fit sigmoid: \(\dfrac{282.1}{1 + 10^{-0.072 (t - 23.6)}}\) (asimptote \(282.1\))
# ### Active
# Start date 2020-03-14 (1st day with 1 active per million)
# Latest number \\(4,336\\) on 2020-04-21
# ## Mexico
# Population \\(128,932,753\\)
# ### Confirmed
# Start date 2020-03-20 (1st day with 1 confirmed per million)
# Latest number \\(8,772\\) on 2020-04-21
# Best fit exponential: \(393 \times 10^{0.041t}\) (doubling rate \(7.3\) days)
# Best fit sigmoid: \(\dfrac{16,648.3}{1 + 10^{-0.057 (t - 32.4)}}\) (asimptote \(16,648.3\))
# ### Dead
# Start date 2020-03-29 (1st day with 0.1 dead per million)
# Latest number \\(712\\) on 2020-04-21
# Best fit exponential: \(37.4 \times 10^{0.055t}\) (doubling rate \(5.5\) days)
# Best fit sigmoid: \(\dfrac{1,149.5}{1 + 10^{-0.085 (t - 21.2)}}\) (asimptote \(1,149.5\))
# ### Active
# Start date 2020-03-20 (1st day with 1 active per million)
# Latest number \\(5,433\\) on 2020-04-21
# ## Honduras
# Population \\(9,904,607\\)
# ### Confirmed
# Start date 2020-03-19 (1st day with 1 confirmed per million)
# Latest number \\(494\\) on 2020-04-21
# Best fit exponential: \(74.9 \times 10^{0.026t}\) (doubling rate \(11.6\) days)
# Best fit sigmoid: \(\dfrac{479.7}{1 + 10^{-0.089 (t - 17.0)}}\) (asimptote \(479.7\))
# ### Dead
# Start date 2020-03-26 (1st day with 0.1 dead per million)
# Latest number \\(46\\) on 2020-04-21
# Best fit exponential: \(6.45 \times 10^{0.033t}\) (doubling rate \(9.0\) days)
# Best fit sigmoid: \(\dfrac{72.6}{1 + 10^{-0.054 (t - 21.9)}}\) (asimptote \(72.6\))
# ### Active
# Start date 2020-03-19 (1st day with 1 active per million)
# Latest number \\(419\\) on 2020-04-21
# ## Cuba
# Population \\(11,326,616\\)
# ### Confirmed
# Start date 2020-03-20 (1st day with 1 confirmed per million)
# Latest number \\(1,137\\) on 2020-04-21
# Best fit exponential: \(78.7 \times 10^{0.036t}\) (doubling rate \(8.3\) days)
# Best fit sigmoid: \(\dfrac{1,465.8}{1 + 10^{-0.066 (t - 25.3)}}\) (asimptote \(1,465.8\))
# ### Dead
# Start date 2020-03-26 (1st day with 0.1 dead per million)
# Latest number \\(38\\) on 2020-04-21
# Best fit exponential: \(3.14 \times 10^{0.041t}\) (doubling rate \(7.3\) days)
# Best fit sigmoid: \(\dfrac{66.2}{1 + 10^{-0.062 (t - 24.7)}}\) (asimptote \(66.2\))
# ### Active
# Start date 2020-03-20 (1st day with 1 active per million)
# Latest number \\(790\\) on 2020-04-21
# ## Costa Rica
# Population \\(5,094,118\\)
# ### Confirmed
# Start date 2020-03-09 (1st day with 1 confirmed per million)
# Latest number \\(669\\) on 2020-04-21
# Best fit exponential: \(94.1 \times 10^{0.021t}\) (doubling rate \(14.1\) days)
# Best fit sigmoid: \(\dfrac{684.1}{1 + 10^{-0.069 (t - 23.1)}}\) (asimptote \(684.1\))
# ### Dead
# Start date 2020-03-19 (1st day with 0.1 dead per million)
# Latest number \\(6\\) on 2020-04-21
# ### Active
# Start date 2020-03-09 (1st day with 1 active per million)
# Latest number \\(513\\) on 2020-04-21

# %% [markdown]
# # Recovering countries that had over 300 active cases at peak

# %%
draw_recovering_countries(get_recovering_countries_info(continent=nb_continent))
# Out:
# ## List of all recovering countries (the top 4 not covered above are also analyzed below)
# Costa Rica recovered 9%

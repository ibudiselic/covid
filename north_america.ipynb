# %% [markdown]
# # Please read the [README](https://github.com/ibudiselic/covid/blob/master/README.md) file in this repository.

# %%
# Load all the data and functionality.
# %run lib.ipynb

nb_continent = 'North America'
display(Markdown(f'# Analysis of the most affected countries in {nb_continent}'))
countries_to_plot = get_top_countries_by_relative_deaths(continent=nb_continent)
# Out:
# # Analysis of the most affected countries in North America

# %%
# %%javascript
# IPython.OutputArea.auto_scroll_threshold = 9999;

# %% [markdown]
# # Cross-country comparison over absolute dates

# %%
for series in ['confirmed', 'dead']:
    compare_countries_absolute_dates(series)
# Out:
# ## Confirmed
# ## Dead

# %% [markdown]
# # Cross-country comparison with approximately aligned start days

# %%
compare_countries_relative_dates('confirmed', start_info=(0.01, '10 confirmed per million'))
# Out:
# ## Confirmed

# %%
compare_countries_relative_dates('dead', start_info=(0.001, '1 death per million'))
# Out:
# ## Dead

# %% [markdown]
# # Per-country analysis with exponential and sigmoidal projections, and new cases analysis
#
# <span style="color:red;">
# IMPORTANT: The projections are only accurate if the fit is good (it often isn't), and assuming nothing changes
# going forward. The sigmoid is omitted if a reasonable fit can't be computed, but this still doesn't mean that
# the fit is good if it is shown.
# </span>
#
# The dashed lines show best fit projections from a few previous days for comparison.

# %%
for country in countries_to_plot:
    country_deep_dive(country)
# Out:
# ## US
# Population \\(331,002,651\\)
# ### Confirmed
# Start date 2020-03-07 (1st day with 1 confirmed per million)
# Latest number \\(965,785\\) on 2020-04-26
# Best fit exponential: \(4.51 \times 10^{4} \times 10^{0.027t}\) (doubling rate \(11.1\) days)
# Best fit sigmoid: \(\dfrac{1,026,237.0}{1 + 10^{-0.062 (t - 35.9)}}\) (asimptote \(1,026,237.0\))
# ### Dead
# Start date 2020-03-11 (1st day with 0.1 dead per million)
# Latest number \\(54,881\\) on 2020-04-26
# Best fit exponential: \(1.31 \times 10^{3} \times 10^{0.036t}\) (doubling rate \(8.4\) days)
# Best fit sigmoid: \(\dfrac{65,223.0}{1 + 10^{-0.072 (t - 37.0)}}\) (asimptote \(65,223.0\))
# ### Active
# Start date 2020-03-07 (1st day with 1 active per million)
# Latest number \\(803,916\\) on 2020-04-26
# ## Canada
# Population \\(37,742,154\\)
# ### Confirmed
# Start date 2020-03-06 (1st day with 1 confirmed per million)
# Latest number \\(47,145\\) on 2020-04-26
# Best fit exponential: \(1.75 \times 10^{3} \times 10^{0.029t}\) (doubling rate \(10.5\) days)
# Best fit sigmoid: \(\dfrac{55,437.4}{1 + 10^{-0.056 (t - 39.7)}}\) (asimptote \(55,437.4\))
# ### Dead
# Start date 2020-03-16 (1st day with 0.1 dead per million)
# Latest number \\(2,661\\) on 2020-04-26
# Best fit exponential: \(41.9 \times 10^{0.044t}\) (doubling rate \(6.8\) days)
# Best fit sigmoid: \(\dfrac{3,889.1}{1 + 10^{-0.071 (t - 37.2)}}\) (asimptote \(3,889.1\))
# ### Active
# Start date 2020-03-06 (1st day with 1 active per million)
# Latest number \\(27,601\\) on 2020-04-26
# ## Panama
# Population \\(4,314,767\\)
# ### Confirmed
# Start date 2020-03-11 (1st day with 1 confirmed per million)
# Latest number \\(5,779\\) on 2020-04-26
# Best fit exponential: \(327 \times 10^{0.027t}\) (doubling rate \(10.9\) days)
# Best fit sigmoid: \(\dfrac{6,535.1}{1 + 10^{-0.056 (t - 33.9)}}\) (asimptote \(6,535.1\))
# ### Dead
# Start date 2020-03-11 (1st day with 0.1 dead per million)
# Latest number \\(165\\) on 2020-04-26
# Best fit exponential: \(7.01 \times 10^{0.030t}\) (doubling rate \(10.0\) days)
# Best fit sigmoid: \(\dfrac{198.4}{1 + 10^{-0.057 (t - 36.0)}}\) (asimptote \(198.4\))
# ### Active
# Start date 2020-03-11 (1st day with 1 active per million)
# Latest number \\(5,276\\) on 2020-04-26
# ## Dominican Republic
# Population \\(10,847,910\\)
# ### Confirmed
# Start date 2020-03-14 (1st day with 1 confirmed per million)
# Latest number \\(6,135\\) on 2020-04-26
# Best fit exponential: \(344 \times 10^{0.030t}\) (doubling rate \(10.2\) days)
# Best fit sigmoid: \(\dfrac{7,844.0}{1 + 10^{-0.054 (t - 34.0)}}\) (asimptote \(7,844.0\))
# ### Dead
# Start date 2020-03-19 (1st day with 0.1 dead per million)
# Latest number \\(278\\) on 2020-04-26
# Best fit exponential: \(25.9 \times 10^{0.028t}\) (doubling rate \(10.7\) days)
# Best fit sigmoid: \(\dfrac{305.7}{1 + 10^{-0.068 (t - 24.8)}}\) (asimptote \(305.7\))
# ### Active
# Start date 2020-03-14 (1st day with 1 active per million)
# Latest number \\(4,947\\) on 2020-04-26
# ## Mexico
# Population \\(128,932,753\\)
# ### Confirmed
# Start date 2020-03-20 (1st day with 1 confirmed per million)
# Latest number \\(14,677\\) on 2020-04-26
# Best fit exponential: \(395 \times 10^{0.041t}\) (doubling rate \(7.3\) days)
# Best fit sigmoid: \(\dfrac{111,902.6}{1 + 10^{-0.044 (t - 56.7)}}\) (asimptote \(111,902.6\))
# ### Dead
# Start date 2020-03-29 (1st day with 0.1 dead per million)
# Latest number \\(1,351\\) on 2020-04-26
# Best fit exponential: \(41.1 \times 10^{0.053t}\) (doubling rate \(5.7\) days)
# Best fit sigmoid: \(\dfrac{4,301.8}{1 + 10^{-0.063 (t - 34.2)}}\) (asimptote \(4,301.8\))
# ### Active
# Start date 2020-03-20 (1st day with 1 active per million)
# Latest number \\(4,972\\) on 2020-04-26
# ## Honduras
# Population \\(9,904,607\\)
# ### Confirmed
# Start date 2020-03-19 (1st day with 1 confirmed per million)
# Latest number \\(627\\) on 2020-04-26
# Best fit exponential: \(86.2 \times 10^{0.023t}\) (doubling rate \(13.1\) days)
# Best fit sigmoid: \(\dfrac{593.6}{1 + 10^{-0.064 (t - 20.4)}}\) (asimptote \(593.6\))
# ### Dead
# Start date 2020-03-26 (1st day with 0.1 dead per million)
# Latest number \\(59\\) on 2020-04-26
# Best fit exponential: \(7.8 \times 10^{0.028t}\) (doubling rate \(10.6\) days)
# Best fit sigmoid: \(\dfrac{78.5}{1 + 10^{-0.051 (t - 23.3)}}\) (asimptote \(78.5\))
# ### Active
# Start date 2020-03-19 (1st day with 1 active per million)
# Latest number \\(503\\) on 2020-04-26
# ## Cuba
# Population \\(11,326,616\\)
# ### Confirmed
# Start date 2020-03-20 (1st day with 1 confirmed per million)
# Latest number \\(1,369\\) on 2020-04-26
# Best fit exponential: \(108 \times 10^{0.030t}\) (doubling rate \(9.9\) days)
# Best fit sigmoid: \(\dfrac{1,624.6}{1 + 10^{-0.062 (t - 26.8)}}\) (asimptote \(1,624.6\))
# ### Dead
# Start date 2020-03-26 (1st day with 0.1 dead per million)
# Latest number \\(54\\) on 2020-04-26
# Best fit exponential: \(3.87 \times 10^{0.037t}\) (doubling rate \(8.2\) days)
# Best fit sigmoid: \(\dfrac{88.6}{1 + 10^{-0.055 (t - 28.8)}}\) (asimptote \(88.6\))
# ### Active
# Start date 2020-03-20 (1st day with 1 active per million)
# Latest number \\(814\\) on 2020-04-26
# ## Jamaica
# Population \\(2,961,167\\)
# ### Confirmed
# Start date 2020-03-13 (1st day with 1 confirmed per million)
# Latest number \\(350\\) on 2020-04-26
# Best fit exponential: \(4.89 \times 10^{0.041t}\) (doubling rate \(7.3\) days)
# ### Dead
# Start date 2020-03-19 (1st day with 0.1 dead per million)
# Latest number \\(7\\) on 2020-04-26
# ### Active
# Start date 2020-03-13 (1st day with 1 active per million)
# Latest number \\(315\\) on 2020-04-26

# %% [markdown]
# # Recovering countries that had over 300 active cases at peak

# %%
draw_recovering_countries(get_recovering_countries_info(continent=nb_continent))
# Out:
# ## List of all recovering countries (the top 4 not covered above are also analyzed below)
# Costa Rica recovered 25%
# ## Costa Rica
# Population \\(5,094,118\\)
# ### Confirmed
# Start date 2020-03-09 (1st day with 1 confirmed per million)
# Latest number \\(695\\) on 2020-04-26
# Best fit exponential: \(117 \times 10^{0.018t}\) (doubling rate \(17.0\) days)
# Best fit sigmoid: \(\dfrac{697.5}{1 + 10^{-0.067 (t - 23.4)}}\) (asimptote \(697.5\))
# ### Dead
# Start date 2020-03-19 (1st day with 0.1 dead per million)
# Latest number \\(6\\) on 2020-04-26
# ### Active
# Start date 2020-03-09 (1st day with 1 active per million)
# Latest number \\(425\\) on 2020-04-26

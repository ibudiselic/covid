# %% [markdown]
# # Please read the [README](https://github.com/ibudiselic/covid/blob/master/README.md) file in this repository.

# %%
# Load all the data and functionality.
# %run lib.ipynb

nb_continent = 'North America'
display(Markdown(f'# Analysis of the most affected countries in {nb_continent}'))
countries_to_plot = get_top_countries_by_relative_deaths(continent=nb_continent)
# Out:
# # Analysis of the most affected countries in North America

# %%
# %%javascript
# IPython.OutputArea.auto_scroll_threshold = 9999;

# %% [markdown]
# # Cross-country comparison over absolute dates

# %%
for series in ['confirmed', 'dead']:
    compare_countries_absolute_dates(series)
# Out:
# ## Confirmed
# ## Dead

# %% [markdown]
# # Cross-country comparison with approximately aligned start days

# %%
compare_countries_relative_dates('confirmed', start_info=(0.01, '10 confirmed per million'))
# Out:
# ## Confirmed

# %%
compare_countries_relative_dates('dead', start_info=(0.001, '1 death per million'))
# Out:
# ## Dead

# %% [markdown]
# # Per-country analysis with exponential and sigmoidal projections, and new cases analysis
#
# <span style="color:red;">
# IMPORTANT: The projections are only accurate if the fit is good (it often isn't), and assuming nothing changes
# going forward. The sigmoid is omitted if a reasonable fit can't be computed, but this still doesn't mean that
# the fit is good if it is shown.
# </span>
#
# The dashed lines show best fit projections from a few previous days for comparison.

# %%
for country in countries_to_plot:
    country_deep_dive(country)
# Out:
# ## US
# Population \\(331,002,651\\)
# ### Confirmed
# Start date 2020-03-07 (1st day with 1 confirmed per million)
# Latest number \\(938,154\\) on 2020-04-25
# Best fit exponential: \(4.23 \times 10^{4} \times 10^{0.028t}\) (doubling rate \(10.7\) days)
# Best fit sigmoid: \(\dfrac{996,198.0}{1 + 10^{-0.063 (t - 35.3)}}\) (asimptote \(996,198.0\))
# ### Dead
# Start date 2020-03-11 (1st day with 0.1 dead per million)
# Latest number \\(53,755\\) on 2020-04-25
# Best fit exponential: \(1.16 \times 10^{3} \times 10^{0.037t}\) (doubling rate \(8.0\) days)
# Best fit sigmoid: \(\dfrac{65,024.9}{1 + 10^{-0.072 (t - 37.0)}}\) (asimptote \(65,024.9\))
# ### Active
# Start date 2020-03-07 (1st day with 1 active per million)
# Latest number \\(784,027\\) on 2020-04-25
# ## Canada
# Population \\(37,742,154\\)
# ### Confirmed
# Start date 2020-03-06 (1st day with 1 confirmed per million)
# Latest number \\(45,491\\) on 2020-04-25
# Best fit exponential: \(1.63 \times 10^{3} \times 10^{0.029t}\) (doubling rate \(10.2\) days)
# Best fit sigmoid: \(\dfrac{54,136.0}{1 + 10^{-0.056 (t - 39.3)}}\) (asimptote \(54,136.0\))
# ### Dead
# Start date 2020-03-16 (1st day with 0.1 dead per million)
# Latest number \\(2,547\\) on 2020-04-25
# Best fit exponential: \(36.7 \times 10^{0.046t}\) (doubling rate \(6.6\) days)
# Best fit sigmoid: \(\dfrac{3,919.6}{1 + 10^{-0.070 (t - 37.3)}}\) (asimptote \(3,919.6\))
# ### Active
# Start date 2020-03-06 (1st day with 1 active per million)
# Latest number \\(26,931\\) on 2020-04-25
# ## Panama
# Population \\(4,314,767\\)
# ### Confirmed
# Start date 2020-03-11 (1st day with 1 confirmed per million)
# Latest number \\(5,538\\) on 2020-04-25
# Best fit exponential: \(311 \times 10^{0.028t}\) (doubling rate \(10.7\) days)
# Best fit sigmoid: \(\dfrac{6,268.9}{1 + 10^{-0.057 (t - 33.2)}}\) (asimptote \(6,268.9\))
# ### Dead
# Start date 2020-03-11 (1st day with 0.1 dead per million)
# Latest number \\(159\\) on 2020-04-25
# Best fit exponential: \(6.56 \times 10^{0.031t}\) (doubling rate \(9.7\) days)
# Best fit sigmoid: \(\dfrac{192.5}{1 + 10^{-0.058 (t - 35.5)}}\) (asimptote \(192.5\))
# ### Active
# Start date 2020-03-11 (1st day with 1 active per million)
# Latest number \\(5,041\\) on 2020-04-25
# ## Dominican Republic
# Population \\(10,847,910\\)
# ### Confirmed
# Start date 2020-03-14 (1st day with 1 confirmed per million)
# Latest number \\(5,926\\) on 2020-04-25
# Best fit exponential: \(323 \times 10^{0.031t}\) (doubling rate \(9.9\) days)
# Best fit sigmoid: \(\dfrac{7,755.3}{1 + 10^{-0.054 (t - 33.8)}}\) (asimptote \(7,755.3\))
# ### Dead
# Start date 2020-03-19 (1st day with 0.1 dead per million)
# Latest number \\(273\\) on 2020-04-25
# Best fit exponential: \(24.3 \times 10^{0.029t}\) (doubling rate \(10.2\) days)
# Best fit sigmoid: \(\dfrac{304.1}{1 + 10^{-0.068 (t - 24.7)}}\) (asimptote \(304.1\))
# ### Active
# Start date 2020-03-14 (1st day with 1 active per million)
# Latest number \\(4,831\\) on 2020-04-25
# ## Mexico
# Population \\(128,932,753\\)
# ### Confirmed
# Start date 2020-03-20 (1st day with 1 confirmed per million)
# Latest number \\(13,842\\) on 2020-04-25
# Best fit exponential: \(393 \times 10^{0.041t}\) (doubling rate \(7.3\) days)
# Best fit sigmoid: \(\dfrac{85,534.8}{1 + 10^{-0.045 (t - 53.5)}}\) (asimptote \(85,534.8\))
# ### Dead
# Start date 2020-03-29 (1st day with 0.1 dead per million)
# Latest number \\(1,305\\) on 2020-04-25
# Best fit exponential: \(38.1 \times 10^{0.055t}\) (doubling rate \(5.5\) days)
# Best fit sigmoid: \(\dfrac{5,974.2}{1 + 10^{-0.061 (t - 37.4)}}\) (asimptote \(5,974.2\))
# ### Active
# Start date 2020-03-20 (1st day with 1 active per million)
# Latest number \\(5,388\\) on 2020-04-25
# ## Honduras
# Population \\(9,904,607\\)
# ### Confirmed
# Start date 2020-03-19 (1st day with 1 confirmed per million)
# Latest number \\(627\\) on 2020-04-25
# Best fit exponential: \(84.2 \times 10^{0.023t}\) (doubling rate \(12.8\) days)
# Best fit sigmoid: \(\dfrac{562.0}{1 + 10^{-0.069 (t - 19.5)}}\) (asimptote \(562.0\))
# ### Dead
# Start date 2020-03-26 (1st day with 0.1 dead per million)
# Latest number \\(59\\) on 2020-04-25
# Best fit exponential: \(7.55 \times 10^{0.029t}\) (doubling rate \(10.3\) days)
# Best fit sigmoid: \(\dfrac{75.5}{1 + 10^{-0.052 (t - 22.6)}}\) (asimptote \(75.5\))
# ### Active
# Start date 2020-03-19 (1st day with 1 active per million)
# Latest number \\(503\\) on 2020-04-25
# ## Cuba
# Population \\(11,326,616\\)
# ### Confirmed
# Start date 2020-03-20 (1st day with 1 confirmed per million)
# Latest number \\(1,337\\) on 2020-04-25
# Best fit exponential: \(101 \times 10^{0.032t}\) (doubling rate \(9.5\) days)
# Best fit sigmoid: \(\dfrac{1,602.6}{1 + 10^{-0.062 (t - 26.6)}}\) (asimptote \(1,602.6\))
# ### Dead
# Start date 2020-03-26 (1st day with 0.1 dead per million)
# Latest number \\(51\\) on 2020-04-25
# Best fit exponential: \(3.72 \times 10^{0.037t}\) (doubling rate \(8.0\) days)
# Best fit sigmoid: \(\dfrac{83.4}{1 + 10^{-0.056 (t - 27.9)}}\) (asimptote \(83.4\))
# ### Active
# Start date 2020-03-20 (1st day with 1 active per million)
# Latest number \\(849\\) on 2020-04-25
# ## Jamaica
# Population \\(2,961,167\\)
# ### Confirmed
# Start date 2020-03-13 (1st day with 1 confirmed per million)
# Latest number \\(305\\) on 2020-04-25
# Best fit exponential: \(5.04 \times 10^{0.041t}\) (doubling rate \(7.4\) days)
# ### Dead
# Start date 2020-03-19 (1st day with 0.1 dead per million)
# Latest number \\(7\\) on 2020-04-25
# ### Active
# Start date 2020-03-13 (1st day with 1 active per million)
# Latest number \\(270\\) on 2020-04-25

# %% [markdown]
# # Recovering countries that had over 300 active cases at peak

# %%
draw_recovering_countries(get_recovering_countries_info(continent=nb_continent))
# Out:
# ## List of all recovering countries (the top 4 not covered above are also analyzed below)
# Costa Rica recovered 21%
# ## Costa Rica
# Population \\(5,094,118\\)
# ### Confirmed
# Start date 2020-03-09 (1st day with 1 confirmed per million)
# Latest number \\(693\\) on 2020-04-25
# Best fit exponential: \(112 \times 10^{0.018t}\) (doubling rate \(16.4\) days)
# Best fit sigmoid: \(\dfrac{695.6}{1 + 10^{-0.067 (t - 23.4)}}\) (asimptote \(695.6\))
# ### Dead
# Start date 2020-03-19 (1st day with 0.1 dead per million)
# Latest number \\(6\\) on 2020-04-25
# ### Active
# Start date 2020-03-09 (1st day with 1 active per million)
# Latest number \\(445\\) on 2020-04-25

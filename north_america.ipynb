# %% [markdown]
# # Please read the [README](https://github.com/ibudiselic/covid/blob/master/README.md) file in this repository.

# %%
# Load all the data and functionality.
# %run lib.ipynb

nb_continent = 'North America'
display(Markdown(f'# Analysis of the most affected countries in {nb_continent}'))
countries_to_plot = get_top_countries_by_relative_deaths(continent=nb_continent)
# Out:
# # Analysis of the most affected countries in North America

# %%
# %%javascript
# IPython.OutputArea.auto_scroll_threshold = 9999;

# %% [markdown]
# # Cross-country comparison over absolute dates

# %%
for series in ['confirmed', 'dead', 'active']:
    compare_countries_absolute_dates(series, skip_days=55)
# Out:
# ## Confirmed
# ## Dead
# ## Active

# %% [markdown]
# # Cross-country comparison with approximately aligned start days

# %%
for series, start_info in [
        ('confirmed', (0.01, '10 confirmed per million')),
        ('dead', (0.001, '1 death per million')),
        ('active', (0.01, '10 active per million'))]:
    compare_countries_relative_dates(series, start_info)
# Out:
# ## Confirmed
# ## Dead
# ## Active

# %% [markdown]
# # Per-country analysis with exponential and sigmoidal projections, and new cases analysis
#
# <span style="color:red;">
# IMPORTANT: The projections are only accurate if the fit is good (it often isn't), and assuming nothing changes
# going forward. The sigmoid is omitted if a reasonable fit can't be computed, but this still doesn't mean that
# the fit is good if it is shown.
# </span>
#
# The dashed lines show best fit projections from a few previous days for comparison.

# %%
for country in countries_to_plot:
    country_deep_dive(country)
# Out:
# ## US
# Population \\(331,002,651\\)
# ### Confirmed
# Start date 2020-03-07 (1st day with 1 confirmed per million)
# Latest number \\(1,069,424\\) on 2020-04-30
# Best fit exponential: \(5.78 \times 10^{4} \times 10^{0.024t}\) (doubling rate \(12.5\) days)
# Best fit sigmoid: \(\dfrac{1,127,291.8}{1 + 10^{-0.056 (t - 37.6)}}\) (asimptote \(1,127,291.8\))
# ### Dead
# Start date 2020-03-11 (1st day with 0.1 dead per million)
# Latest number \\(62,996\\) on 2020-04-30
# Best fit exponential: \(2.59 \times 10^{3} \times 10^{0.028t}\) (doubling rate \(10.6\) days)
# Best fit sigmoid: \(\dfrac{67,472.3}{1 + 10^{-0.064 (t - 36.5)}}\) (asimptote \(67,472.3\))
# ### Active
# Start date 2020-03-07 (1st day with 1 active per million)
# Latest number \\(852,481\\) on 2020-04-30
# ## Canada
# Population \\(37,742,154\\)
# ### Confirmed
# Start date 2020-03-06 (1st day with 1 confirmed per million)
# Latest number \\(54,457\\) on 2020-04-30
# Best fit exponential: \(2.23 \times 10^{3} \times 10^{0.026t}\) (doubling rate \(11.7\) days)
# Best fit sigmoid: \(\dfrac{63,169.3}{1 + 10^{-0.051 (t - 42.1)}}\) (asimptote \(63,169.3\))
# ### Dead
# Start date 2020-03-16 (1st day with 0.1 dead per million)
# Latest number \\(3,310\\) on 2020-04-30
# Best fit exponential: \(66.4 \times 10^{0.038t}\) (doubling rate \(7.9\) days)
# Best fit sigmoid: \(\dfrac{4,231.2}{1 + 10^{-0.068 (t - 38.2)}}\) (asimptote \(4,231.2\))
# ### Active
# Start date 2020-03-06 (1st day with 1 active per million)
# Latest number \\(29,723\\) on 2020-04-30
# ## Panama
# Population \\(4,314,767\\)
# ### Confirmed
# Start date 2020-03-11 (1st day with 1 confirmed per million)
# Latest number \\(6,532\\) on 2020-04-30
# Best fit exponential: \(400 \times 10^{0.025t}\) (doubling rate \(12.1\) days)
# Best fit sigmoid: \(\dfrac{7,425.7}{1 + 10^{-0.050 (t - 36.4)}}\) (asimptote \(7,425.7\))
# ### Dead
# Start date 2020-03-11 (1st day with 0.1 dead per million)
# Latest number \\(188\\) on 2020-04-30
# Best fit exponential: \(9.24 \times 10^{0.027t}\) (doubling rate \(11.3\) days)
# Best fit sigmoid: \(\dfrac{210.5}{1 + 10^{-0.055 (t - 37.1)}}\) (asimptote \(210.5\))
# ### Active
# Start date 2020-03-11 (1st day with 1 active per million)
# Latest number \\(5,768\\) on 2020-04-30
# ## Dominican Republic
# Population \\(10,847,910\\)
# ### Confirmed
# Start date 2020-03-14 (1st day with 1 confirmed per million)
# Latest number \\(6,972\\) on 2020-04-30
# Best fit exponential: \(438 \times 10^{0.026t}\) (doubling rate \(11.5\) days)
# Best fit sigmoid: \(\dfrac{8,146.6}{1 + 10^{-0.052 (t - 34.7)}}\) (asimptote \(8,146.6\))
# ### Dead
# Start date 2020-03-19 (1st day with 0.1 dead per million)
# Latest number \\(301\\) on 2020-04-30
# Best fit exponential: \(32.9 \times 10^{0.024t}\) (doubling rate \(12.5\) days)
# Best fit sigmoid: \(\dfrac{312.7}{1 + 10^{-0.066 (t - 25.2)}}\) (asimptote \(312.7\))
# ### Active
# Start date 2020-03-14 (1st day with 1 active per million)
# Latest number \\(5,370\\) on 2020-04-30
# ## Mexico
# Population \\(128,932,753\\)
# ### Confirmed
# Start date 2020-03-19 (1st day with 1 confirmed per million)
# Latest number \\(19,224\\) on 2020-04-30
# Best fit exponential: \(541 \times 10^{0.036t}\) (doubling rate \(8.3\) days)
# Best fit sigmoid: \(\dfrac{44,365.8}{1 + 10^{-0.047 (t - 45.6)}}\) (asimptote \(44,365.8\))
# ### Dead
# Start date 2020-03-28 (1st day with 0.1 dead per million)
# Latest number \\(1,859\\) on 2020-04-30
# Best fit exponential: \(66.2 \times 10^{0.043t}\) (doubling rate \(6.9\) days)
# Best fit sigmoid: \(\dfrac{3,008.5}{1 + 10^{-0.064 (t - 31.1)}}\) (asimptote \(3,008.5\))
# ### Active
# Start date 2020-03-19 (1st day with 1 active per million)
# Latest number \\(5,942\\) on 2020-04-30
# ## Honduras
# Population \\(9,904,607\\)
# ### Confirmed
# Start date 2020-03-19 (1st day with 1 confirmed per million)
# Latest number \\(771\\) on 2020-04-30
# Best fit exponential: \(91.2 \times 10^{0.022t}\) (doubling rate \(13.7\) days)
# Best fit sigmoid: \(\dfrac{839.5}{1 + 10^{-0.044 (t - 27.7)}}\) (asimptote \(839.5\))
# ### Dead
# Start date 2020-03-26 (1st day with 0.1 dead per million)
# Latest number \\(71\\) on 2020-04-30
# Best fit exponential: \(8.77 \times 10^{0.026t}\) (doubling rate \(11.6\) days)
# Best fit sigmoid: \(\dfrac{92.1}{1 + 10^{-0.046 (t - 26.3)}}\) (asimptote \(92.1\))
# ### Active
# Start date 2020-03-19 (1st day with 1 active per million)
# Latest number \\(621\\) on 2020-04-30
# ## Cuba
# Population \\(11,326,616\\)
# ### Confirmed
# Start date 2020-03-20 (1st day with 1 confirmed per million)
# Latest number \\(1,501\\) on 2020-04-30
# Best fit exponential: \(137 \times 10^{0.026t}\) (doubling rate \(11.5\) days)
# Best fit sigmoid: \(\dfrac{1,673.0}{1 + 10^{-0.060 (t - 27.3)}}\) (asimptote \(1,673.0\))
# ### Dead
# Start date 2020-03-26 (1st day with 0.1 dead per million)
# Latest number \\(61\\) on 2020-04-30
# Best fit exponential: \(4.95 \times 10^{0.032t}\) (doubling rate \(9.5\) days)
# Best fit sigmoid: \(\dfrac{82.1}{1 + 10^{-0.057 (t - 27.6)}}\) (asimptote \(82.1\))
# ### Active
# Start date 2020-03-20 (1st day with 1 active per million)
# Latest number \\(759\\) on 2020-04-30
# ## Jamaica
# Population \\(2,961,167\\)
# ### Confirmed
# Start date 2020-03-13 (1st day with 1 confirmed per million)
# Latest number \\(422\\) on 2020-04-30
# Best fit exponential: \(6.77 \times 10^{0.037t}\) (doubling rate \(8.1\) days)
# Best fit sigmoid: \(\dfrac{1,222.1}{1 + 10^{-0.046 (t - 54.7)}}\) (asimptote \(1,222.1\))
# ### Dead
# Start date 2020-03-19 (1st day with 0.1 dead per million)
# Latest number \\(8\\) on 2020-04-30
# ### Active
# Start date 2020-03-13 (1st day with 1 active per million)
# Latest number \\(385\\) on 2020-04-30

# %% [markdown]
# # Recovering countries that had over 300 active cases at peak

# %%
draw_recovering_countries(get_recovering_countries_info(continent=nb_continent))
# Out:
# ## List of all recovering countries (the top 4 not covered above are also analyzed below)
# Costa Rica recovered 34%
# Cuba recovered 11%
# ## Costa Rica
# Population \\(5,094,118\\)
# ### Confirmed
# Start date 2020-03-09 (1st day with 1 confirmed per million)
# Latest number \\(719\\) on 2020-04-30
# Best fit exponential: \(134 \times 10^{0.015t}\) (doubling rate \(19.5\) days)
# Best fit sigmoid: \(\dfrac{706.4}{1 + 10^{-0.065 (t - 23.7)}}\) (asimptote \(706.4\))
# ### Dead
# Start date 2020-03-19 (1st day with 0.1 dead per million)
# Latest number \\(6\\) on 2020-04-30
# ### Active
# Start date 2020-03-09 (1st day with 1 active per million)
# Latest number \\(375\\) on 2020-04-30

# %% [markdown]
# # Please read the [README](https://github.com/ibudiselic/covid/blob/master/README.md) file in this repository.

# %%
# Load all the data and functionality.
# %run lib.ipynb

nb_continent = 'North America'
display(Markdown(f'# Analysis of the most affected countries in {nb_continent}'))
countries_to_plot = get_top_countries_by_relative_deaths(continent=nb_continent)
# Out:
# # Analysis of the most affected countries in North America

# %%
# %%javascript
# IPython.OutputArea.auto_scroll_threshold = 9999;

# %% [markdown]
# # Cross-country comparison over absolute dates

# %%
for series in ['confirmed', 'dead']:
    compare_countries_absolute_dates(series)
# Out:
# ## Confirmed
# ## Dead

# %% [markdown]
# # Cross-country comparison with approximately aligned start days

# %%
compare_countries_relative_dates('confirmed', start_info=(0.01, '10 confirmed per million'))
# Out:
# ## Confirmed

# %%
compare_countries_relative_dates('dead', start_info=(0.001, '1 death per million'))
# Out:
# ## Dead

# %% [markdown]
# # Per-country analysis with exponential and sigmoidal projections, and new cases analysis
#
# <span style="color:red;">
# IMPORTANT: The projections are only accurate if the fit is good (it often isn't), and assuming nothing changes
# going forward. The sigmoid is omitted if a reasonable fit can't be computed, but this still doesn't mean that
# the fit is good if it is shown.
# </span>
#
# The dashed lines show best fit projections from a few previous days for comparison.

# %%
for country in countries_to_plot:
    country_deep_dive(country)
# Out:
# ## US
# Population \\(331,002,651\\)
# ### Confirmed
# Start date 2020-03-07 (1st day with 1 confirmed per million)
# Latest number \\(905,358\\) on 2020-04-24
# Best fit exponential: \(3.96 \times 10^{4} \times 10^{0.029t}\) (doubling rate \(10.4\) days)
# Best fit sigmoid: \(\dfrac{964,896.4}{1 + 10^{-0.065 (t - 34.8)}}\) (asimptote \(964,896.4\))
# ### Dead
# Start date 2020-03-11 (1st day with 0.1 dead per million)
# Latest number \\(51,949\\) on 2020-04-24
# Best fit exponential: \(1.03 \times 10^{3} \times 10^{0.039t}\) (doubling rate \(7.7\) days)
# Best fit sigmoid: \(\dfrac{64,063.9}{1 + 10^{-0.073 (t - 36.8)}}\) (asimptote \(64,063.9\))
# ### Active
# Start date 2020-03-07 (1st day with 1 active per million)
# Latest number \\(754,330\\) on 2020-04-24
# ## Canada
# Population \\(37,742,154\\)
# ### Confirmed
# Start date 2020-03-06 (1st day with 1 confirmed per million)
# Latest number \\(44,054\\) on 2020-04-24
# Best fit exponential: \(1.51 \times 10^{3} \times 10^{0.030t}\) (doubling rate \(9.9\) days)
# Best fit sigmoid: \(\dfrac{52,923.1}{1 + 10^{-0.057 (t - 38.9)}}\) (asimptote \(52,923.1\))
# ### Dead
# Start date 2020-03-16 (1st day with 0.1 dead per million)
# Latest number \\(2,384\\) on 2020-04-24
# Best fit exponential: \(32.5 \times 10^{0.047t}\) (doubling rate \(6.3\) days)
# Best fit sigmoid: \(\dfrac{3,842.9}{1 + 10^{-0.071 (t - 37.1)}}\) (asimptote \(3,842.9\))
# ### Active
# Start date 2020-03-06 (1st day with 1 active per million)
# Latest number \\(26,521\\) on 2020-04-24
# ## Panama
# Population \\(4,314,767\\)
# ### Confirmed
# Start date 2020-03-11 (1st day with 1 confirmed per million)
# Latest number \\(5,338\\) on 2020-04-24
# Best fit exponential: \(295 \times 10^{0.029t}\) (doubling rate \(10.4\) days)
# Best fit sigmoid: \(\dfrac{6,032.2}{1 + 10^{-0.059 (t - 32.5)}}\) (asimptote \(6,032.2\))
# ### Dead
# Start date 2020-03-11 (1st day with 0.1 dead per million)
# Latest number \\(154\\) on 2020-04-24
# Best fit exponential: \(6.12 \times 10^{0.032t}\) (doubling rate \(9.4\) days)
# Best fit sigmoid: \(\dfrac{186.3}{1 + 10^{-0.059 (t - 35.0)}}\) (asimptote \(186.3\))
# ### Active
# Start date 2020-03-11 (1st day with 1 active per million)
# Latest number \\(4,865\\) on 2020-04-24
# ## Dominican Republic
# Population \\(10,847,910\\)
# ### Confirmed
# Start date 2020-03-14 (1st day with 1 confirmed per million)
# Latest number \\(5,749\\) on 2020-04-24
# Best fit exponential: \(303 \times 10^{0.031t}\) (doubling rate \(9.6\) days)
# Best fit sigmoid: \(\dfrac{7,675.5}{1 + 10^{-0.054 (t - 33.6)}}\) (asimptote \(7,675.5\))
# ### Dead
# Start date 2020-03-19 (1st day with 0.1 dead per million)
# Latest number \\(267\\) on 2020-04-24
# Best fit exponential: \(22.7 \times 10^{0.031t}\) (doubling rate \(9.8\) days)
# Best fit sigmoid: \(\dfrac{302.1}{1 + 10^{-0.068 (t - 24.6)}}\) (asimptote \(302.1\))
# ### Active
# Start date 2020-03-14 (1st day with 1 active per million)
# Latest number \\(4,719\\) on 2020-04-24
# ## Mexico
# Population \\(128,932,753\\)
# ### Confirmed
# Start date 2020-03-20 (1st day with 1 confirmed per million)
# Latest number \\(11,633\\) on 2020-04-24
# Best fit exponential: \(407 \times 10^{0.041t}\) (doubling rate \(7.4\) days)
# Best fit sigmoid: \(\dfrac{35,754.5}{1 + 10^{-0.049 (t - 42.5)}}\) (asimptote \(35,754.5\))
# ### Dead
# Start date 2020-03-29 (1st day with 0.1 dead per million)
# Latest number \\(1,069\\) on 2020-04-24
# Best fit exponential: \(39 \times 10^{0.054t}\) (doubling rate \(5.6\) days)
# Best fit sigmoid: \(\dfrac{2,947.1}{1 + 10^{-0.067 (t - 30.5)}}\) (asimptote \(2,947.1\))
# ### Active
# Start date 2020-03-20 (1st day with 1 active per million)
# Latest number \\(7,937\\) on 2020-04-24
# ## Honduras
# Population \\(9,904,607\\)
# ### Confirmed
# Start date 2020-03-19 (1st day with 1 confirmed per million)
# Latest number \\(591\\) on 2020-04-24
# Best fit exponential: \(83.1 \times 10^{0.024t}\) (doubling rate \(12.7\) days)
# Best fit sigmoid: \(\dfrac{526.6}{1 + 10^{-0.076 (t - 18.4)}}\) (asimptote \(526.6\))
# ### Dead
# Start date 2020-03-26 (1st day with 0.1 dead per million)
# Latest number \\(55\\) on 2020-04-24
# Best fit exponential: \(7.45 \times 10^{0.030t}\) (doubling rate \(10.2\) days)
# Best fit sigmoid: \(\dfrac{67.6}{1 + 10^{-0.056 (t - 20.8)}}\) (asimptote \(67.6\))
# ### Active
# Start date 2020-03-19 (1st day with 1 active per million)
# Latest number \\(478\\) on 2020-04-24
# ## Cuba
# Population \\(11,326,616\\)
# ### Confirmed
# Start date 2020-03-20 (1st day with 1 confirmed per million)
# Latest number \\(1,285\\) on 2020-04-24
# Best fit exponential: \(95.3 \times 10^{0.033t}\) (doubling rate \(9.2\) days)
# Best fit sigmoid: \(\dfrac{1,565.9}{1 + 10^{-0.063 (t - 26.2)}}\) (asimptote \(1,565.9\))
# ### Dead
# Start date 2020-03-26 (1st day with 0.1 dead per million)
# Latest number \\(49\\) on 2020-04-24
# Best fit exponential: \(3.58 \times 10^{0.038t}\) (doubling rate \(7.9\) days)
# Best fit sigmoid: \(\dfrac{76.8}{1 + 10^{-0.058 (t - 26.8)}}\) (asimptote \(76.8\))
# ### Active
# Start date 2020-03-20 (1st day with 1 active per million)
# Latest number \\(820\\) on 2020-04-24
# ## Costa Rica
# Population \\(5,094,118\\)
# ### Confirmed
# Start date 2020-03-09 (1st day with 1 confirmed per million)
# Latest number \\(687\\) on 2020-04-24
# Best fit exponential: \(108 \times 10^{0.019t}\) (doubling rate \(15.8\) days)
# Best fit sigmoid: \(\dfrac{693.2}{1 + 10^{-0.067 (t - 23.3)}}\) (asimptote \(693.2\))
# ### Dead
# Start date 2020-03-19 (1st day with 0.1 dead per million)
# Latest number \\(6\\) on 2020-04-24
# ### Active
# Start date 2020-03-09 (1st day with 1 active per million)
# Latest number \\(465\\) on 2020-04-24

# %% [markdown]
# # Recovering countries that had over 300 active cases at peak

# %%
draw_recovering_countries(get_recovering_countries_info(continent=nb_continent))
# Out:
# ## List of all recovering countries (the top 4 not covered above are also analyzed below)
# Costa Rica recovered 18%

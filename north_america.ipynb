# %% [markdown]
# # Please read the [README](https://github.com/ibudiselic/covid/blob/master/README.md) file in this repository.

# %%
# Load all the data and functionality.
# %run lib.ipynb

nb_continent = 'North America'
display(Markdown(f'# Analysis of the most affected countries in {nb_continent}'))
countries_to_plot = get_top_countries_by_relative_deaths(continent=nb_continent)
# Out:
# # Analysis of the most affected countries in North America

# %%
# %%javascript
# IPython.OutputArea.auto_scroll_threshold = 9999;

# %% [markdown]
# # Cross-country comparison over absolute dates

# %%
for series in ['confirmed', 'dead']:
    compare_countries_absolute_dates(series)
# Out:
# ## Confirmed
# ## Dead

# %% [markdown]
# # Cross-country comparison with approximately aligned start days

# %%
compare_countries_relative_dates('confirmed', start_info=(0.01, '10 confirmed per million'))
# Out:
# ## Confirmed

# %%
compare_countries_relative_dates('dead', start_info=(0.001, '1 death per million'))
# Out:
# ## Dead

# %% [markdown]
# # Per-country analysis with exponential and sigmoidal projections, and new cases analysis
#
# <span style="color:red;">
# IMPORTANT: The projections are only accurate if the fit is good (it often isn't), and assuming nothing changes
# going forward. The sigmoid is omitted if a reasonable fit can't be computed, but this still doesn't mean that
# the fit is good if it is shown.
# </span>
#
# The dashed lines show best fit projections from a few previous days for comparison.

# %%
for country in countries_to_plot:
    country_deep_dive(country)
# Out:
# ## US
# Population \\(331,002,651\\)
# ### Confirmed
# Start date 2020-03-07 (1st day with 1 confirmed per million)
# Latest number \\(784,326\\) on 2020-04-20
# Best fit exponential: \(2.89 \times 10^{4} \times 10^{0.033t}\) (doubling rate \(9.1\) days)
# Best fit sigmoid: \(\dfrac{862,067.4}{1 + 10^{-0.072 (t - 33.1)}}\) (asimptote \(862,067.4\))
# ### Dead
# Start date 2020-03-11 (1st day with 0.1 dead per million)
# Latest number \\(42,094\\) on 2020-04-20
# Best fit exponential: \(606 \times 10^{0.046t}\) (doubling rate \(6.5\) days)
# Best fit sigmoid: \(\dfrac{61,051.9}{1 + 10^{-0.075 (t - 36.2)}}\) (asimptote \(61,051.9\))
# ### Active
# Start date 2020-03-07 (1st day with 1 active per million)
# Latest number \\(669,903\\) on 2020-04-20
# ## Canada
# Population \\(37,742,154\\)
# ### Confirmed
# Start date 2020-03-06 (1st day with 1 confirmed per million)
# Latest number \\(37,657\\) on 2020-04-20
# Best fit exponential: \(1.14 \times 10^{3} \times 10^{0.034t}\) (doubling rate \(8.9\) days)
# Best fit sigmoid: \(\dfrac{44,077.8}{1 + 10^{-0.065 (t - 36.0)}}\) (asimptote \(44,077.8\))
# ### Dead
# Start date 2020-03-16 (1st day with 0.1 dead per million)
# Latest number \\(1,725\\) on 2020-04-20
# Best fit exponential: \(21.2 \times 10^{0.054t}\) (doubling rate \(5.6\) days)
# Best fit sigmoid: \(\dfrac{3,067.8}{1 + 10^{-0.076 (t - 34.7)}}\) (asimptote \(3,067.8\))
# ### Active
# Start date 2020-03-06 (1st day with 1 active per million)
# Latest number \\(23,389\\) on 2020-04-20
# ## Panama
# Population \\(4,314,767\\)
# ### Confirmed
# Start date 2020-03-11 (1st day with 1 confirmed per million)
# Latest number \\(4,467\\) on 2020-04-20
# Best fit exponential: \(230 \times 10^{0.033t}\) (doubling rate \(9.2\) days)
# Best fit sigmoid: \(\dfrac{5,291.0}{1 + 10^{-0.065 (t - 30.4)}}\) (asimptote \(5,291.0\))
# ### Dead
# Start date 2020-03-11 (1st day with 0.1 dead per million)
# Latest number \\(126\\) on 2020-04-20
# Best fit exponential: \(4.65 \times 10^{0.036t}\) (doubling rate \(8.3\) days)
# Best fit sigmoid: \(\dfrac{153.5}{1 + 10^{-0.067 (t - 32.1)}}\) (asimptote \(153.5\))
# ### Active
# Start date 2020-03-11 (1st day with 1 active per million)
# Latest number \\(4,176\\) on 2020-04-20
# ## Dominican Republic
# Population \\(10,847,910\\)
# ### Confirmed
# Start date 2020-03-14 (1st day with 1 confirmed per million)
# Latest number \\(4,964\\) on 2020-04-20
# Best fit exponential: \(236 \times 10^{0.036t}\) (doubling rate \(8.5\) days)
# Best fit sigmoid: \(\dfrac{7,044.9}{1 + 10^{-0.057 (t - 32.3)}}\) (asimptote \(7,044.9\))
# ### Dead
# Start date 2020-03-19 (1st day with 0.1 dead per million)
# Latest number \\(235\\) on 2020-04-20
# Best fit exponential: \(17.4 \times 10^{0.036t}\) (doubling rate \(8.4\) days)
# Best fit sigmoid: \(\dfrac{275.8}{1 + 10^{-0.073 (t - 23.3)}}\) (asimptote \(275.8\))
# ### Active
# Start date 2020-03-14 (1st day with 1 active per million)
# Latest number \\(4,313\\) on 2020-04-20
# ## Mexico
# Population \\(128,932,753\\)
# ### Confirmed
# Start date 2020-03-20 (1st day with 1 confirmed per million)
# Latest number \\(8,261\\) on 2020-04-20
# Best fit exponential: \(375 \times 10^{0.042t}\) (doubling rate \(7.1\) days)
# Best fit sigmoid: \(\dfrac{15,504.6}{1 + 10^{-0.058 (t - 31.5)}}\) (asimptote \(15,504.6\))
# ### Dead
# Start date 2020-03-29 (1st day with 0.1 dead per million)
# Latest number \\(686\\) on 2020-04-20
# Best fit exponential: \(33 \times 10^{0.058t}\) (doubling rate \(5.2\) days)
# Best fit sigmoid: \(\dfrac{1,291.8}{1 + 10^{-0.082 (t - 22.3)}}\) (asimptote \(1,291.8\))
# ### Active
# Start date 2020-03-20 (1st day with 1 active per million)
# Latest number \\(4,948\\) on 2020-04-20
# ## Honduras
# Population \\(9,904,607\\)
# ### Confirmed
# Start date 2020-03-19 (1st day with 1 confirmed per million)
# Latest number \\(477\\) on 2020-04-20
# Best fit exponential: \(71.4 \times 10^{0.027t}\) (doubling rate \(11.1\) days)
# Best fit sigmoid: \(\dfrac{470.4}{1 + 10^{-0.091 (t - 16.7)}}\) (asimptote \(470.4\))
# ### Dead
# Start date 2020-03-26 (1st day with 0.1 dead per million)
# Latest number \\(46\\) on 2020-04-20
# Best fit exponential: \(6.09 \times 10^{0.035t}\) (doubling rate \(8.6\) days)
# Best fit sigmoid: \(\dfrac{82.3}{1 + 10^{-0.051 (t - 23.8)}}\) (asimptote \(82.3\))
# ### Active
# Start date 2020-03-19 (1st day with 1 active per million)
# Latest number \\(406\\) on 2020-04-20
# ## Cuba
# Population \\(11,326,616\\)
# ### Confirmed
# Start date 2020-03-20 (1st day with 1 confirmed per million)
# Latest number \\(1,087\\) on 2020-04-20
# Best fit exponential: \(73.6 \times 10^{0.038t}\) (doubling rate \(8.0\) days)
# Best fit sigmoid: \(\dfrac{1,430.8}{1 + 10^{-0.067 (t - 24.9)}}\) (asimptote \(1,430.8\))
# ### Dead
# Start date 2020-03-26 (1st day with 0.1 dead per million)
# Latest number \\(36\\) on 2020-04-20
# Best fit exponential: \(2.94 \times 10^{0.043t}\) (doubling rate \(7.0\) days)
# Best fit sigmoid: \(\dfrac{70.6}{1 + 10^{-0.060 (t - 25.5)}}\) (asimptote \(70.6\))
# ### Active
# Start date 2020-03-20 (1st day with 1 active per million)
# Latest number \\(766\\) on 2020-04-20
# ## Costa Rica
# Population \\(5,094,118\\)
# ### Confirmed
# Start date 2020-03-09 (1st day with 1 confirmed per million)
# Latest number \\(662\\) on 2020-04-20
# Best fit exponential: \(89.5 \times 10^{0.022t}\) (doubling rate \(13.6\) days)
# Best fit sigmoid: \(\dfrac{681.6}{1 + 10^{-0.069 (t - 23.0)}}\) (asimptote \(681.6\))
# ### Dead
# Start date 2020-03-19 (1st day with 0.1 dead per million)
# Latest number \\(6\\) on 2020-04-20
# ### Active
# Start date 2020-03-09 (1st day with 1 active per million)
# Latest number \\(532\\) on 2020-04-20

# %% [markdown]
# # Recovering countries that had over 300 active cases at peak

# %%
draw_recovering_countries(get_recovering_countries_info(continent=nb_continent))
# Out:
# ## List of all recovering countries (the top 4 not covered above are also analyzed below)

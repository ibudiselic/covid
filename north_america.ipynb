# %% [markdown]
# # Please read the [README](https://github.com/ibudiselic/covid/blob/master/README.md) file in this repository.

# %%
# Load all the data and functionality.
# %run lib.ipynb

nb_continent = 'North America'
display(Markdown(f'# Analysis of the most affected countries in {nb_continent}'))
countries_to_plot = get_top_countries_by_relative_deaths(continent=nb_continent)
# Out:
# # Analysis of the most affected countries in North America

# %%
# %%javascript
# IPython.OutputArea.auto_scroll_threshold = 9999;

# %% [markdown]
# # Cross-country comparison over absolute dates

# %%
for series in ['confirmed', 'dead']:
    compare_countries_absolute_dates(series)
# Out:
# ## Confirmed
# ## Dead

# %% [markdown]
# # Cross-country comparison with approximately aligned start days

# %%
compare_countries_relative_dates('confirmed', start_info=(0.01, '10 confirmed per million'))
# Out:
# ## Confirmed

# %%
compare_countries_relative_dates('dead', start_info=(0.001, '1 death per million'))
# Out:
# ## Dead
# Costa Rica doesn't yet have 0.0010 dead per thousand.

# %% [markdown]
# # Per-country analysis with exponential and sigmoidal projections, and new cases analysis
#
# <span style="color:red;">
# IMPORTANT: The projections are only accurate if the fit is good (it often isn't), and assuming nothing changes
# going forward. The sigmoid is omitted if a reasonable fit can't be computed, but this still doesn't mean that
# the fit is good if it is shown.
# </span>
#
# The dashed lines show best fit projections from a few previous days for comparison.

# %%
for country in countries_to_plot:
    country_deep_dive(country)
# Out:
# ## US
# Population \\(331,002,651\\)
# ### Confirmed
# Start date 2020-03-07 (1st day with 1 confirmed per million)
# Latest number \\(732,197\\) on 2020-04-18
# Best fit exponential: \(2.41 \times 10^{4} \times 10^{0.036t}\) (doubling rate \(8.4\) days)
# Best fit sigmoid: \(\dfrac{811,613.9}{1 + 10^{-0.076 (t - 32.2)}}\) (asimptote \(811,613.9\))
# ### Dead
# Start date 2020-03-11 (1st day with 0.1 dead per million)
# Latest number \\(38,664\\) on 2020-04-18
# Best fit exponential: \(448 \times 10^{0.050t}\) (doubling rate \(6.0\) days)
# Best fit sigmoid: \(\dfrac{62,573.0}{1 + 10^{-0.074 (t - 36.4)}}\) (asimptote \(62,573.0\))
# ### Active
# Start date 2020-03-07 (1st day with 1 active per million)
# Latest number \\(628,693\\) on 2020-04-18
# ## Canada
# Population \\(37,742,154\\)
# ### Confirmed
# Start date 2020-03-06 (1st day with 1 confirmed per million)
# Latest number \\(34,355\\) on 2020-04-18
# Best fit exponential: \(967 \times 10^{0.036t}\) (doubling rate \(8.3\) days)
# Best fit sigmoid: \(\dfrac{39,801.6}{1 + 10^{-0.069 (t - 34.5)}}\) (asimptote \(39,801.6\))
# ### Dead
# Start date 2020-03-16 (1st day with 0.1 dead per million)
# Latest number \\(1,399\\) on 2020-04-18
# Best fit exponential: \(16.6 \times 10^{0.058t}\) (doubling rate \(5.2\) days)
# Best fit sigmoid: \(\dfrac{2,960.3}{1 + 10^{-0.077 (t - 34.3)}}\) (asimptote \(2,960.3\))
# ### Active
# Start date 2020-03-06 (1st day with 1 active per million)
# Latest number \\(21,992\\) on 2020-04-18
# ## Panama
# Population \\(4,314,767\\)
# ### Confirmed
# Start date 2020-03-11 (1st day with 1 confirmed per million)
# Latest number \\(4,210\\) on 2020-04-18
# Best fit exponential: \(196 \times 10^{0.035t}\) (doubling rate \(8.5\) days)
# Best fit sigmoid: \(\dfrac{5,159.9}{1 + 10^{-0.066 (t - 30.1)}}\) (asimptote \(5,159.9\))
# ### Dead
# Start date 2020-03-11 (1st day with 0.1 dead per million)
# Latest number \\(116\\) on 2020-04-18
# Best fit exponential: \(3.92 \times 10^{0.039t}\) (doubling rate \(7.8\) days)
# Best fit sigmoid: \(\dfrac{142.2}{1 + 10^{-0.070 (t - 31.0)}}\) (asimptote \(142.2\))
# ### Active
# Start date 2020-03-11 (1st day with 1 active per million)
# Latest number \\(3,972\\) on 2020-04-18
# ## Dominican Republic
# Population \\(10,847,910\\)
# ### Confirmed
# Start date 2020-03-14 (1st day with 1 confirmed per million)
# Latest number \\(4,335\\) on 2020-04-18
# Best fit exponential: \(216 \times 10^{0.037t}\) (doubling rate \(8.1\) days)
# Best fit sigmoid: \(\dfrac{5,865.6}{1 + 10^{-0.062 (t - 29.6)}}\) (asimptote \(5,865.6\))
# ### Dead
# Start date 2020-03-19 (1st day with 0.1 dead per million)
# Latest number \\(217\\) on 2020-04-18
# Best fit exponential: \(15 \times 10^{0.039t}\) (doubling rate \(7.7\) days)
# Best fit sigmoid: \(\dfrac{265.5}{1 + 10^{-0.075 (t - 22.8)}}\) (asimptote \(265.5\))
# ### Active
# Start date 2020-03-14 (1st day with 1 active per million)
# Latest number \\(3,806\\) on 2020-04-18
# ## Honduras
# Population \\(9,904,607\\)
# ### Confirmed
# Start date 2020-03-19 (1st day with 1 confirmed per million)
# Latest number \\(457\\) on 2020-04-18
# Best fit exponential: \(64.2 \times 10^{0.030t}\) (doubling rate \(10.1\) days)
# Best fit sigmoid: \(\dfrac{454.0}{1 + 10^{-0.096 (t - 16.3)}}\) (asimptote \(454.0\))
# ### Dead
# Start date 2020-03-26 (1st day with 0.1 dead per million)
# Latest number \\(46\\) on 2020-04-18
# Best fit exponential: \(5.78 \times 10^{0.037t}\) (doubling rate \(8.2\) days)
# Best fit sigmoid: \(\dfrac{63.8}{1 + 10^{-0.057 (t - 19.9)}}\) (asimptote \(63.8\))
# ### Active
# Start date 2020-03-19 (1st day with 1 active per million)
# Latest number \\(401\\) on 2020-04-18
# ## Mexico
# Population \\(128,932,753\\)
# ### Confirmed
# Start date 2020-03-20 (1st day with 1 confirmed per million)
# Latest number \\(6,875\\) on 2020-04-18
# Best fit exponential: \(348 \times 10^{0.044t}\) (doubling rate \(6.8\) days)
# Best fit sigmoid: \(\dfrac{12,141.5}{1 + 10^{-0.063 (t - 28.4)}}\) (asimptote \(12,141.5\))
# ### Dead
# Start date 2020-03-29 (1st day with 0.1 dead per million)
# Latest number \\(546\\) on 2020-04-18
# Best fit exponential: \(29.7 \times 10^{0.061t}\) (doubling rate \(4.9\) days)
# Best fit sigmoid: \(\dfrac{918.0}{1 + 10^{-0.091 (t - 19.3)}}\) (asimptote \(918.0\))
# ### Active
# Start date 2020-03-20 (1st day with 1 active per million)
# Latest number \\(4,204\\) on 2020-04-18
# ## Cuba
# Population \\(11,326,616\\)
# ### Confirmed
# Start date 2020-03-20 (1st day with 1 confirmed per million)
# Latest number \\(986\\) on 2020-04-18
# Best fit exponential: \(64.4 \times 10^{0.041t}\) (doubling rate \(7.4\) days)
# Best fit sigmoid: \(\dfrac{1,351.0}{1 + 10^{-0.069 (t - 24.2)}}\) (asimptote \(1,351.0\))
# ### Dead
# Start date 2020-03-26 (1st day with 0.1 dead per million)
# Latest number \\(32\\) on 2020-04-18
# Best fit exponential: \(2.63 \times 10^{0.046t}\) (doubling rate \(6.5\) days)
# Best fit sigmoid: \(\dfrac{91.7}{1 + 10^{-0.057 (t - 28.6)}}\) (asimptote \(91.7\))
# ### Active
# Start date 2020-03-20 (1st day with 1 active per million)
# Latest number \\(727\\) on 2020-04-18
# ## Costa Rica
# Population \\(5,094,118\\)
# ### Confirmed
# Start date 2020-03-09 (1st day with 1 confirmed per million)
# Latest number \\(655\\) on 2020-04-18
# Best fit exponential: \(80.6 \times 10^{0.024t}\) (doubling rate \(12.5\) days)
# Best fit sigmoid: \(\dfrac{675.2}{1 + 10^{-0.070 (t - 22.8)}}\) (asimptote \(675.2\))
# ### Dead
# Start date 2020-03-19 (1st day with 0.1 dead per million)
# Latest number \\(4\\) on 2020-04-18
# ### Active
# Start date 2020-03-09 (1st day with 1 active per million)
# Latest number \\(554\\) on 2020-04-18

# %% [markdown]
# # Recovering countries that had over 300 active cases at peak

# %%
draw_recovering_countries(get_recovering_countries_info(continent=nb_continent))
# Out:
# ## List of all recovering countries (the top 4 not covered above are also analyzed below)

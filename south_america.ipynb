# %% [markdown]
# # Please read the [README](https://github.com/ibudiselic/covid/blob/master/README.md) file in this repository.

# %%
# Load all the data and functionality.
# %run lib.ipynb

nb_continent = 'South America'
display(Markdown(f'# Analysis of the most affected countries in {nb_continent}'))
countries_to_plot = get_top_countries_by_relative_deaths(continent=nb_continent)
# Out:
# # Analysis of the most affected countries in South America

# %%
# %%javascript
# IPython.OutputArea.auto_scroll_threshold = 9999;

# %% [markdown]
# # Cross-country comparison over absolute dates

# %%
for series in ['confirmed', 'dead']:
    compare_countries_absolute_dates(series)
# Out:
# ## Confirmed
# ## Dead

# %% [markdown]
# # Cross-country comparison with approximately aligned start days

# %%
compare_countries_relative_dates('confirmed', start_info=(0.01, '10 confirmed per million'))
# Out:
# ## Confirmed

# %%
compare_countries_relative_dates('dead', start_info=(0.001, '1 death per million'))
# Out:
# ## Dead

# %% [markdown]
# # Per-country analysis with exponential and sigmoidal projections, and new cases analysis
#
# <span style="color:red;">
# IMPORTANT: The projections are only accurate if the fit is good (it often isn't), and assuming nothing changes
# going forward. The sigmoid is omitted if a reasonable fit can't be computed, but this still doesn't mean that
# the fit is good if it is shown.
# </span>
#
# The dashed lines show best fit projections from a few previous days for comparison.

# %%
for country in countries_to_plot:
    country_deep_dive(country)
# Out:
# ## Ecuador
# Population \\(17,643,054\\)
# ### Confirmed
# Start date 2020-03-14 (1st day with 1 confirmed per million)
# Latest number \\(9,468\\) on 2020-04-19
# Best fit exponential: \(604 \times 10^{0.034t}\) (doubling rate \(8.9\) days)
# Best fit sigmoid: \(\dfrac{11,638.3}{1 + 10^{-0.065 (t - 27.6)}}\) (asimptote \(11,638.3\))
# ### Dead
# Start date 2020-03-14 (1st day with 0.1 dead per million)
# Latest number \\(474\\) on 2020-04-19
# Best fit exponential: \(21.1 \times 10^{0.038t}\) (doubling rate \(7.9\) days)
# Best fit sigmoid: \(\dfrac{524.3}{1 + 10^{-0.082 (t - 26.9)}}\) (asimptote \(524.3\))
# ### Active
# Start date 2020-03-14 (1st day with 1 active per million)
# Latest number \\(7,933\\) on 2020-04-19
# ## Peru
# Population \\(32,971,854\\)
# ### Confirmed
# Start date 2020-03-14 (1st day with 1 confirmed per million)
# Latest number \\(15,628\\) on 2020-04-19
# Best fit exponential: \(164 \times 10^{0.055t}\) (doubling rate \(5.5\) days)
# Best fit sigmoid: \(\dfrac{21,198.0}{1 + 10^{-0.095 (t - 32.3)}}\) (asimptote \(21,198.0\))
# ### Dead
# Start date 2020-03-21 (1st day with 0.1 dead per million)
# Latest number \\(400\\) on 2020-04-19
# Best fit exponential: \(12.8 \times 10^{0.050t}\) (doubling rate \(6.0\) days)
# Best fit sigmoid: \(\dfrac{730.2}{1 + 10^{-0.068 (t - 29.6)}}\) (asimptote \(730.2\))
# ### Active
# Start date 2020-03-14 (1st day with 1 active per million)
# Latest number \\(8,417\\) on 2020-04-19
# ## Brazil
# Population \\(212,559,417\\)
# ### Confirmed
# Start date 2020-03-17 (1st day with 1 confirmed per million)
# Latest number \\(38,654\\) on 2020-04-19
# Best fit exponential: \(1.6 \times 10^{3} \times 10^{0.041t}\) (doubling rate \(7.3\) days)
# Best fit sigmoid: \(\dfrac{65,506.9}{1 + 10^{-0.060 (t - 31.7)}}\) (asimptote \(65,506.9\))
# ### Dead
# Start date 2020-03-22 (1st day with 0.1 dead per million)
# Latest number \\(2,462\\) on 2020-04-19
# Best fit exponential: \(90.6 \times 10^{0.051t}\) (doubling rate \(6.0\) days)
# Best fit sigmoid: \(\dfrac{4,311.4}{1 + 10^{-0.073 (t - 27.2)}}\) (asimptote \(4,311.4\))
# ### Active
# Start date 2020-03-17 (1st day with 1 active per million)
# Latest number \\(14,062\\) on 2020-04-19
# ## Chile
# Population \\(19,116,201\\)
# ### Confirmed
# Start date 2020-03-11 (1st day with 1 confirmed per million)
# Latest number \\(10,088\\) on 2020-04-19
# Best fit exponential: \(535 \times 10^{0.033t}\) (doubling rate \(9.1\) days)
# Best fit sigmoid: \(\dfrac{11,839.8}{1 + 10^{-0.065 (t - 29.7)}}\) (asimptote \(11,839.8\))
# ### Dead
# Start date 2020-03-23 (1st day with 0.1 dead per million)
# Latest number \\(133\\) on 2020-04-19
# Best fit exponential: \(7.39 \times 10^{0.046t}\) (doubling rate \(6.5\) days)
# Best fit sigmoid: \(\dfrac{169.6}{1 + 10^{-0.082 (t - 21.9)}}\) (asimptote \(169.6\))
# ### Active
# Start date 2020-03-11 (1st day with 1 active per million)
# Latest number \\(5,617\\) on 2020-04-19
# ## Colombia
# Population \\(50,882,891\\)
# ### Confirmed
# Start date 2020-03-16 (1st day with 1 confirmed per million)
# Latest number \\(3,792\\) on 2020-04-19
# Best fit exponential: \(283 \times 10^{0.033t}\) (doubling rate \(9.0\) days)
# Best fit sigmoid: \(\dfrac{4,409.5}{1 + 10^{-0.067 (t - 24.9)}}\) (asimptote \(4,409.5\))
# ### Dead
# Start date 2020-03-26 (1st day with 0.1 dead per million)
# Latest number \\(179\\) on 2020-04-19
# Best fit exponential: \(12.7 \times 10^{0.047t}\) (doubling rate \(6.4\) days)
# Best fit sigmoid: \(\dfrac{205.7}{1 + 10^{-0.095 (t - 18.0)}}\) (asimptote \(205.7\))
# ### Active
# Start date 2020-03-16 (1st day with 1 active per million)
# Latest number \\(2,902\\) on 2020-04-19
# ## Argentina
# Population \\(45,195,774\\)
# ### Confirmed
# Start date 2020-03-16 (1st day with 1 confirmed per million)
# Latest number \\(2,839\\) on 2020-04-19
# Best fit exponential: \(307 \times 10^{0.029t}\) (doubling rate \(10.4\) days)
# Best fit sigmoid: \(\dfrac{3,172.9}{1 + 10^{-0.063 (t - 22.4)}}\) (asimptote \(3,172.9\))
# ### Dead
# Start date 2020-03-24 (1st day with 0.1 dead per million)
# Latest number \\(132\\) on 2020-04-19
# Best fit exponential: \(15.5 \times 10^{0.036t}\) (doubling rate \(8.3\) days)
# Best fit sigmoid: \(\dfrac{171.5}{1 + 10^{-0.069 (t - 19.3)}}\) (asimptote \(171.5\))
# ### Active
# Start date 2020-03-16 (1st day with 1 active per million)
# Latest number \\(1,998\\) on 2020-04-19
# ## Uruguay
# Population \\(3,473,730\\)
# ### Confirmed
# Start date 2020-03-14 (1st day with 1 confirmed per million)
# Latest number \\(517\\) on 2020-04-19
# Best fit exponential: \(119 \times 10^{0.019t}\) (doubling rate \(15.6\) days)
# Best fit sigmoid: \(\dfrac{505.6}{1 + 10^{-0.082 (t - 14.9)}}\) (asimptote \(505.6\))
# ### Dead
# Start date 2020-03-29 (1st day with 0.1 dead per million)
# Latest number \\(10\\) on 2020-04-19
# Best fit exponential: \(2.8 \times 10^{0.026t}\) (doubling rate \(11.4\) days)
# Best fit sigmoid: \(\dfrac{8.8}{1 + 10^{-0.135 (t - 7.0)}}\) (asimptote \(8.8\))
# ### Active
# Start date 2020-03-14 (1st day with 1 active per million)
# Latest number \\(209\\) on 2020-04-19
# ## Bolivia
# Population \\(11,673,021\\)
# ### Confirmed
# Start date 2020-03-18 (1st day with 1 confirmed per million)
# Latest number \\(520\\) on 2020-04-19
# Best fit exponential: \(28.5 \times 10^{0.039t}\) (doubling rate \(7.7\) days)
# Best fit sigmoid: \(\dfrac{996.8}{1 + 10^{-0.054 (t - 32.3)}}\) (asimptote \(996.8\))
# ### Dead
# Start date 2020-03-30 (1st day with 0.1 dead per million)
# Latest number \\(32\\) on 2020-04-19
# Best fit exponential: \(6.8 \times 10^{0.035t}\) (doubling rate \(8.7\) days)
# Best fit sigmoid: \(\dfrac{38.2}{1 + 10^{-0.083 (t - 11.7)}}\) (asimptote \(38.2\))
# ### Active
# Start date 2020-03-18 (1st day with 1 active per million)
# Latest number \\(457\\) on 2020-04-19

# %% [markdown]
# # Recovering countries that had over 300 active cases at peak

# %%
draw_recovering_countries(get_recovering_countries_info(continent=nb_continent))
# Out:
# ## List of all recovering countries (the top 4 not covered above are also analyzed below)
# Uruguay recovered 32%

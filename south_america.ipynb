# %% [markdown]
# # Please read the [README](https://github.com/ibudiselic/covid/blob/master/README.md) file in this repository.

# %%
# Load all the data and functionality.
# %run lib.ipynb

nb_continent = 'South America'
display(Markdown(f'# Analysis of the most affected countries in {nb_continent}'))
countries_to_plot = get_top_countries_by_relative_deaths(continent=nb_continent)
# Out:
# # Analysis of the most affected countries in South America

# %%
# %%javascript
# IPython.OutputArea.auto_scroll_threshold = 9999;

# %% [markdown]
# # Cross-country comparison over absolute dates

# %%
for series in ['confirmed', 'dead']:
    compare_countries_absolute_dates(series)
# Out:
# ## Confirmed
# ## Dead

# %% [markdown]
# # Cross-country comparison with approximately aligned start days

# %%
compare_countries_relative_dates('confirmed', start_info=(0.01, '10 confirmed per million'))
# Out:
# ## Confirmed

# %%
compare_countries_relative_dates('dead', start_info=(0.001, '1 death per million'))
# Out:
# ## Dead

# %% [markdown]
# # Per-country analysis with exponential and sigmoidal projections, and new cases analysis
#
# <span style="color:red;">
# IMPORTANT: The projections are only accurate if the fit is good (it often isn't), and assuming nothing changes
# going forward. The sigmoid is omitted if a reasonable fit can't be computed, but this still doesn't mean that
# the fit is good if it is shown.
# </span>
#
# The dashed lines show best fit projections from a few previous days for comparison.

# %%
for country in countries_to_plot:
    country_deep_dive(country)
# Out:
# ## Ecuador
# Population \\(17,643,054\\)
# ### Confirmed
# Start date 2020-03-14 (1st day with 1 confirmed per million)
# Latest number \\(9,022\\) on 2020-04-18
# Best fit exponential: \(564 \times 10^{0.035t}\) (doubling rate \(8.6\) days)
# Best fit sigmoid: \(\dfrac{11,484.3}{1 + 10^{-0.065 (t - 27.4)}}\) (asimptote \(11,484.3\))
# ### Dead
# Start date 2020-03-14 (1st day with 0.1 dead per million)
# Latest number \\(456\\) on 2020-04-18
# Best fit exponential: \(19.3 \times 10^{0.039t}\) (doubling rate \(7.6\) days)
# Best fit sigmoid: \(\dfrac{504.1}{1 + 10^{-0.084 (t - 26.4)}}\) (asimptote \(504.1\))
# ### Active
# Start date 2020-03-14 (1st day with 1 active per million)
# Latest number \\(7,558\\) on 2020-04-18
# ## Brazil
# Population \\(212,559,417\\)
# ### Confirmed
# Start date 2020-03-17 (1st day with 1 confirmed per million)
# Latest number \\(36,658\\) on 2020-04-18
# Best fit exponential: \(1.51 \times 10^{3} \times 10^{0.042t}\) (doubling rate \(7.1\) days)
# Best fit sigmoid: \(\dfrac{60,833.2}{1 + 10^{-0.061 (t - 30.7)}}\) (asimptote \(60,833.2\))
# ### Dead
# Start date 2020-03-22 (1st day with 0.1 dead per million)
# Latest number \\(2,354\\) on 2020-04-18
# Best fit exponential: \(82.1 \times 10^{0.053t}\) (doubling rate \(5.7\) days)
# Best fit sigmoid: \(\dfrac{4,463.2}{1 + 10^{-0.072 (t - 27.6)}}\) (asimptote \(4,463.2\))
# ### Active
# Start date 2020-03-17 (1st day with 1 active per million)
# Latest number \\(20,278\\) on 2020-04-18
# ## Peru
# Population \\(32,971,854\\)
# ### Confirmed
# Start date 2020-03-14 (1st day with 1 confirmed per million)
# Latest number \\(14,420\\) on 2020-04-18
# Best fit exponential: \(136 \times 10^{0.057t}\) (doubling rate \(5.2\) days)
# Best fit sigmoid: \(\dfrac{20,938.5}{1 + 10^{-0.095 (t - 32.2)}}\) (asimptote \(20,938.5\))
# ### Dead
# Start date 2020-03-21 (1st day with 0.1 dead per million)
# Latest number \\(348\\) on 2020-04-18
# Best fit exponential: \(12.7 \times 10^{0.050t}\) (doubling rate \(6.0\) days)
# Best fit sigmoid: \(\dfrac{506.9}{1 + 10^{-0.077 (t - 25.6)}}\) (asimptote \(506.9\))
# ### Active
# Start date 2020-03-14 (1st day with 1 active per million)
# Latest number \\(7,388\\) on 2020-04-18
# ## Chile
# Population \\(19,116,201\\)
# ### Confirmed
# Start date 2020-03-11 (1st day with 1 confirmed per million)
# Latest number \\(9,730\\) on 2020-04-18
# Best fit exponential: \(500 \times 10^{0.034t}\) (doubling rate \(8.8\) days)
# Best fit sigmoid: \(\dfrac{11,399.3}{1 + 10^{-0.066 (t - 29.1)}}\) (asimptote \(11,399.3\))
# ### Dead
# Start date 2020-03-23 (1st day with 0.1 dead per million)
# Latest number \\(126\\) on 2020-04-18
# Best fit exponential: \(6.83 \times 10^{0.048t}\) (doubling rate \(6.3\) days)
# Best fit sigmoid: \(\dfrac{157.8}{1 + 10^{-0.086 (t - 21.1)}}\) (asimptote \(157.8\))
# ### Active
# Start date 2020-03-11 (1st day with 1 active per million)
# Latest number \\(5,569\\) on 2020-04-18
# ## Colombia
# Population \\(50,882,891\\)
# ### Confirmed
# Start date 2020-03-16 (1st day with 1 confirmed per million)
# Latest number \\(3,439\\) on 2020-04-18
# Best fit exponential: \(268 \times 10^{0.034t}\) (doubling rate \(8.8\) days)
# Best fit sigmoid: \(\dfrac{4,222.9}{1 + 10^{-0.069 (t - 24.3)}}\) (asimptote \(4,222.9\))
# ### Dead
# Start date 2020-03-26 (1st day with 0.1 dead per million)
# Latest number \\(153\\) on 2020-04-18
# Best fit exponential: \(12 \times 10^{0.049t}\) (doubling rate \(6.2\) days)
# Best fit sigmoid: \(\dfrac{187.1}{1 + 10^{-0.102 (t - 17.0)}}\) (asimptote \(187.1\))
# ### Active
# Start date 2020-03-16 (1st day with 1 active per million)
# Latest number \\(2,652\\) on 2020-04-18
# ## Argentina
# Population \\(45,195,774\\)
# ### Confirmed
# Start date 2020-03-16 (1st day with 1 confirmed per million)
# Latest number \\(2,758\\) on 2020-04-18
# Best fit exponential: \(293 \times 10^{0.030t}\) (doubling rate \(10.0\) days)
# Best fit sigmoid: \(\dfrac{3,068.7}{1 + 10^{-0.065 (t - 21.9)}}\) (asimptote \(3,068.7\))
# ### Dead
# Start date 2020-03-24 (1st day with 0.1 dead per million)
# Latest number \\(129\\) on 2020-04-18
# Best fit exponential: \(14.6 \times 10^{0.038t}\) (doubling rate \(8.0\) days)
# Best fit sigmoid: \(\dfrac{172.7}{1 + 10^{-0.068 (t - 19.4)}}\) (asimptote \(172.7\))
# ### Active
# Start date 2020-03-16 (1st day with 1 active per million)
# Latest number \\(1,944\\) on 2020-04-18
# ## Bolivia
# Population \\(11,673,021\\)
# ### Confirmed
# Start date 2020-03-18 (1st day with 1 confirmed per million)
# Latest number \\(493\\) on 2020-04-18
# Best fit exponential: \(27 \times 10^{0.040t}\) (doubling rate \(7.5\) days)
# Best fit sigmoid: \(\dfrac{1,009.3}{1 + 10^{-0.054 (t - 32.4)}}\) (asimptote \(1,009.3\))
# ### Dead
# Start date 2020-03-30 (1st day with 0.1 dead per million)
# Latest number \\(31\\) on 2020-04-18
# Best fit exponential: \(6.4 \times 10^{0.037t}\) (doubling rate \(8.1\) days)
# Best fit sigmoid: \(\dfrac{39.3}{1 + 10^{-0.081 (t - 12.1)}}\) (asimptote \(39.3\))
# ### Active
# Start date 2020-03-18 (1st day with 1 active per million)
# Latest number \\(431\\) on 2020-04-18
# ## Uruguay
# Population \\(3,473,730\\)
# ### Confirmed
# Start date 2020-03-14 (1st day with 1 confirmed per million)
# Latest number \\(508\\) on 2020-04-18
# Best fit exponential: \(115 \times 10^{0.020t}\) (doubling rate \(14.9\) days)
# Best fit sigmoid: \(\dfrac{501.9}{1 + 10^{-0.084 (t - 14.8)}}\) (asimptote \(501.9\))
# ### Dead
# Start date 2020-03-29 (1st day with 0.1 dead per million)
# Latest number \\(9\\) on 2020-04-18
# ### Active
# Start date 2020-03-14 (1st day with 1 active per million)
# Latest number \\(205\\) on 2020-04-18

# %% [markdown]
# # Recovering countries that had over 300 active cases at peak

# %%
draw_recovering_countries(get_recovering_countries_info(continent=nb_continent))
# Out:
# ## List of all recovering countries (the top 4 not covered above are also analyzed below)
# Uruguay recovered 34%

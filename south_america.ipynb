# %% [markdown]
# # Please read the [README](https://github.com/ibudiselic/covid/blob/master/README.md) file in this repository.

# %%
# Load all the data and functionality.
# %run lib.ipynb

nb_continent = 'South America'
display(Markdown(f'# Analysis of the most affected countries in {nb_continent}'))
countries_to_plot = get_top_countries_by_relative_deaths(continent=nb_continent)
# Out:
# # Analysis of the most affected countries in South America

# %%
# %%javascript
# IPython.OutputArea.auto_scroll_threshold = 9999;

# %% [markdown]
# # Cross-country comparison over absolute dates

# %%
for series in ['confirmed', 'dead']:
    compare_countries_absolute_dates(series)
# Out:
# ## Confirmed
# ## Dead

# %% [markdown]
# # Cross-country comparison with approximately aligned start days

# %%
compare_countries_relative_dates('confirmed', start_info=(0.01, '10 confirmed per million'))
# Out:
# ## Confirmed

# %%
compare_countries_relative_dates('dead', start_info=(0.001, '1 death per million'))
# Out:
# ## Dead

# %% [markdown]
# # Per-country analysis with exponential and sigmoidal projections, and new cases analysis
#
# <span style="color:red;">
# IMPORTANT: The projections are only accurate if the fit is good (it often isn't), and assuming nothing changes
# going forward. The sigmoid is omitted if a reasonable fit can't be computed, but this still doesn't mean that
# the fit is good if it is shown.
# </span>
#
# The dashed lines show best fit projections from a few previous days for comparison.

# %%
for country in countries_to_plot:
    country_deep_dive(country)
# Out:
# ## Ecuador
# Population \\(17,643,054\\)
# ### Confirmed
# Start date 2020-03-14 (1st day with 1 confirmed per million)
# Latest number \\(11,183\\) on 2020-04-23
# Best fit exponential: \(761 \times 10^{0.030t}\) (doubling rate \(10.1\) days)
# Best fit sigmoid: \(\dfrac{13,094.1}{1 + 10^{-0.060 (t - 29.4)}}\) (asimptote \(13,094.1\))
# ### Dead
# Start date 2020-03-14 (1st day with 0.1 dead per million)
# Latest number \\(560\\) on 2020-04-23
# Best fit exponential: \(28.9 \times 10^{0.033t}\) (doubling rate \(9.2\) days)
# Best fit sigmoid: \(\dfrac{613.9}{1 + 10^{-0.071 (t - 29.1)}}\) (asimptote \(613.9\))
# ### Active
# Start date 2020-03-14 (1st day with 1 active per million)
# Latest number \\(9,295\\) on 2020-04-23
# ## Peru
# Population \\(32,971,854\\)
# ### Confirmed
# Start date 2020-03-14 (1st day with 1 confirmed per million)
# Latest number \\(20,914\\) on 2020-04-23
# Best fit exponential: \(300 \times 10^{0.046t}\) (doubling rate \(6.6\) days)
# Best fit sigmoid: \(\dfrac{25,691.9}{1 + 10^{-0.083 (t - 34.4)}}\) (asimptote \(25,691.9\))
# ### Dead
# Start date 2020-03-21 (1st day with 0.1 dead per million)
# Latest number \\(572\\) on 2020-04-23
# Best fit exponential: \(14.7 \times 10^{0.047t}\) (doubling rate \(6.4\) days)
# Best fit sigmoid: \(\dfrac{1,466.2}{1 + 10^{-0.059 (t - 37.3)}}\) (asimptote \(1,466.2\))
# ### Active
# Start date 2020-03-14 (1st day with 1 active per million)
# Latest number \\(12,920\\) on 2020-04-23
# ## Brazil
# Population \\(212,559,417\\)
# ### Confirmed
# Start date 2020-03-17 (1st day with 1 confirmed per million)
# Latest number \\(50,036\\) on 2020-04-23
# Best fit exponential: \(2.04 \times 10^{3} \times 10^{0.037t}\) (doubling rate \(8.1\) days)
# Best fit sigmoid: \(\dfrac{77,484.8}{1 + 10^{-0.056 (t - 34.0)}}\) (asimptote \(77,484.8\))
# ### Dead
# Start date 2020-03-22 (1st day with 0.1 dead per million)
# Latest number \\(3,331\\) on 2020-04-23
# Best fit exponential: \(130 \times 10^{0.043t}\) (doubling rate \(7.0\) days)
# Best fit sigmoid: \(\dfrac{4,569.0}{1 + 10^{-0.070 (t - 28.0)}}\) (asimptote \(4,569.0\))
# ### Active
# Start date 2020-03-17 (1st day with 1 active per million)
# Latest number \\(20,132\\) on 2020-04-23
# ## Chile
# Population \\(19,116,201\\)
# ### Confirmed
# Start date 2020-03-11 (1st day with 1 confirmed per million)
# Latest number \\(11,812\\) on 2020-04-23
# Best fit exponential: \(687 \times 10^{0.029t}\) (doubling rate \(10.3\) days)
# Best fit sigmoid: \(\dfrac{13,507.7}{1 + 10^{-0.059 (t - 31.8)}}\) (asimptote \(13,507.7\))
# ### Dead
# Start date 2020-03-23 (1st day with 0.1 dead per million)
# Latest number \\(168\\) on 2020-04-23
# Best fit exponential: \(10 \times 10^{0.040t}\) (doubling rate \(7.6\) days)
# Best fit sigmoid: \(\dfrac{208.7}{1 + 10^{-0.073 (t - 24.4)}}\) (asimptote \(208.7\))
# ### Active
# Start date 2020-03-11 (1st day with 1 active per million)
# Latest number \\(5,840\\) on 2020-04-23
# ## Colombia
# Population \\(50,882,891\\)
# ### Confirmed
# Start date 2020-03-16 (1st day with 1 confirmed per million)
# Latest number \\(4,561\\) on 2020-04-23
# Best fit exponential: \(343 \times 10^{0.030t}\) (doubling rate \(10.1\) days)
# Best fit sigmoid: \(\dfrac{5,324.8}{1 + 10^{-0.059 (t - 27.9)}}\) (asimptote \(5,324.8\))
# ### Dead
# Start date 2020-03-26 (1st day with 0.1 dead per million)
# Latest number \\(215\\) on 2020-04-23
# Best fit exponential: \(17.3 \times 10^{0.039t}\) (doubling rate \(7.6\) days)
# Best fit sigmoid: \(\dfrac{249.2}{1 + 10^{-0.082 (t - 20.1)}}\) (asimptote \(249.2\))
# ### Active
# Start date 2020-03-16 (1st day with 1 active per million)
# Latest number \\(3,419\\) on 2020-04-23
# ## Bolivia
# Population \\(11,673,021\\)
# ### Confirmed
# Start date 2020-03-18 (1st day with 1 confirmed per million)
# Latest number \\(703\\) on 2020-04-23
# Best fit exponential: \(34 \times 10^{0.036t}\) (doubling rate \(8.4\) days)
# Best fit sigmoid: \(\dfrac{1,207.6}{1 + 10^{-0.051 (t - 35.1)}}\) (asimptote \(1,207.6\))
# ### Dead
# Start date 2020-03-30 (1st day with 0.1 dead per million)
# Latest number \\(43\\) on 2020-04-23
# Best fit exponential: \(7.8 \times 10^{0.030t}\) (doubling rate \(10.1\) days)
# Best fit sigmoid: \(\dfrac{44.3}{1 + 10^{-0.070 (t - 13.8)}}\) (asimptote \(44.3\))
# ### Active
# Start date 2020-03-18 (1st day with 1 active per million)
# Latest number \\(616\\) on 2020-04-23
# ## Argentina
# Population \\(45,195,774\\)
# ### Confirmed
# Start date 2020-03-16 (1st day with 1 confirmed per million)
# Latest number \\(3,435\\) on 2020-04-23
# Best fit exponential: \(359 \times 10^{0.026t}\) (doubling rate \(11.6\) days)
# Best fit sigmoid: \(\dfrac{3,714.1}{1 + 10^{-0.055 (t - 25.2)}}\) (asimptote \(3,714.1\))
# ### Dead
# Start date 2020-03-24 (1st day with 0.1 dead per million)
# Latest number \\(165\\) on 2020-04-23
# Best fit exponential: \(18.7 \times 10^{0.031t}\) (doubling rate \(9.6\) days)
# Best fit sigmoid: \(\dfrac{194.6}{1 + 10^{-0.063 (t - 21.1)}}\) (asimptote \(194.6\))
# ### Active
# Start date 2020-03-16 (1st day with 1 active per million)
# Latest number \\(2,351\\) on 2020-04-23
# ## Uruguay
# Population \\(3,473,730\\)
# ### Confirmed
# Start date 2020-03-14 (1st day with 1 confirmed per million)
# Latest number \\(557\\) on 2020-04-23
# Best fit exponential: \(134 \times 10^{0.017t}\) (doubling rate \(18.0\) days)
# Best fit sigmoid: \(\dfrac{525.9}{1 + 10^{-0.076 (t - 15.5)}}\) (asimptote \(525.9\))
# ### Dead
# Start date 2020-03-29 (1st day with 0.1 dead per million)
# Latest number \\(12\\) on 2020-04-23
# Best fit exponential: \(2.97 \times 10^{0.024t}\) (doubling rate \(12.5\) days)
# Best fit sigmoid: \(\dfrac{11.9}{1 + 10^{-0.070 (t - 10.9)}}\) (asimptote \(11.9\))
# ### Active
# Start date 2020-03-14 (1st day with 1 active per million)
# Latest number \\(191\\) on 2020-04-23

# %% [markdown]
# # Recovering countries that had over 300 active cases at peak

# %%
draw_recovering_countries(get_recovering_countries_info(continent=nb_continent))
# Out:
# ## List of all recovering countries (the top 4 not covered above are also analyzed below)

# %% [markdown]
# # Please read the [README](https://github.com/ibudiselic/covid/blob/master/README.md) file in this repository.

# %%
# Load all the data and functionality.
# %run lib.ipynb

nb_continent = 'South America'
display(Markdown(f'# Analysis of the most affected countries in {nb_continent}'))
countries_to_plot = get_top_countries_by_relative_deaths(continent=nb_continent)
# Out:
# # Analysis of the most affected countries in South America

# %%
# %%javascript
# IPython.OutputArea.auto_scroll_threshold = 9999;

# %% [markdown]
# # Cross-country comparison over absolute dates

# %%
for series in ['confirmed', 'dead']:
    compare_countries_absolute_dates(series)
# Out:
# ## Confirmed
# ## Dead

# %% [markdown]
# # Cross-country comparison with approximately aligned start days

# %%
compare_countries_relative_dates('confirmed', start_info=(0.01, '10 confirmed per million'))
# Out:
# ## Confirmed

# %%
compare_countries_relative_dates('dead', start_info=(0.001, '1 death per million'))
# Out:
# ## Dead

# %% [markdown]
# # Per-country analysis with exponential and sigmoidal projections, and new cases analysis
#
# <span style="color:red;">
# IMPORTANT: The projections are only accurate if the fit is good (it often isn't), and assuming nothing changes
# going forward. The sigmoid is omitted if a reasonable fit can't be computed, but this still doesn't mean that
# the fit is good if it is shown.
# </span>
#
# The dashed lines show best fit projections from a few previous days for comparison.

# %%
for country in countries_to_plot:
    country_deep_dive(country)
# Out:
# ## Ecuador
# Population \\(17,643,054\\)
# ### Confirmed
# Start date 2020-03-14 (1st day with 1 confirmed per million)
# Latest number \\(10,128\\) on 2020-04-20
# Best fit exponential: \(638 \times 10^{0.033t}\) (doubling rate \(9.2\) days)
# Best fit sigmoid: \(\dfrac{12,096.7}{1 + 10^{-0.063 (t - 28.1)}}\) (asimptote \(12,096.7\))
# ### Dead
# Start date 2020-03-14 (1st day with 0.1 dead per million)
# Latest number \\(507\\) on 2020-04-20
# Best fit exponential: \(22.7 \times 10^{0.037t}\) (doubling rate \(8.2\) days)
# Best fit sigmoid: \(\dfrac{554.2}{1 + 10^{-0.078 (t - 27.6)}}\) (asimptote \(554.2\))
# ### Active
# Start date 2020-03-14 (1st day with 1 active per million)
# Latest number \\(8,471\\) on 2020-04-20
# ## Peru
# Population \\(32,971,854\\)
# ### Confirmed
# Start date 2020-03-14 (1st day with 1 confirmed per million)
# Latest number \\(16,325\\) on 2020-04-20
# Best fit exponential: \(201 \times 10^{0.052t}\) (doubling rate \(5.8\) days)
# Best fit sigmoid: \(\dfrac{21,027.6}{1 + 10^{-0.095 (t - 32.3)}}\) (asimptote \(21,027.6\))
# ### Dead
# Start date 2020-03-21 (1st day with 0.1 dead per million)
# Latest number \\(445\\) on 2020-04-20
# Best fit exponential: \(12.9 \times 10^{0.050t}\) (doubling rate \(6.1\) days)
# Best fit sigmoid: \(\dfrac{1,062.2}{1 + 10^{-0.062 (t - 33.8)}}\) (asimptote \(1,062.2\))
# ### Active
# Start date 2020-03-14 (1st day with 1 active per million)
# Latest number \\(8,912\\) on 2020-04-20
# ## Brazil
# Population \\(212,559,417\\)
# ### Confirmed
# Start date 2020-03-17 (1st day with 1 confirmed per million)
# Latest number \\(40,743\\) on 2020-04-20
# Best fit exponential: \(1.71 \times 10^{3} \times 10^{0.040t}\) (doubling rate \(7.5\) days)
# Best fit sigmoid: \(\dfrac{67,480.8}{1 + 10^{-0.059 (t - 32.1)}}\) (asimptote \(67,480.8\))
# ### Dead
# Start date 2020-03-22 (1st day with 0.1 dead per million)
# Latest number \\(2,587\\) on 2020-04-20
# Best fit exponential: \(101 \times 10^{0.048t}\) (doubling rate \(6.2\) days)
# Best fit sigmoid: \(\dfrac{4,097.0}{1 + 10^{-0.074 (t - 26.7)}}\) (asimptote \(4,097.0\))
# ### Active
# Start date 2020-03-17 (1st day with 1 active per million)
# Latest number \\(16,026\\) on 2020-04-20
# ## Chile
# Population \\(19,116,201\\)
# ### Confirmed
# Start date 2020-03-11 (1st day with 1 confirmed per million)
# Latest number \\(10,507\\) on 2020-04-20
# Best fit exponential: \(571 \times 10^{0.032t}\) (doubling rate \(9.4\) days)
# Best fit sigmoid: \(\dfrac{12,274.6}{1 + 10^{-0.063 (t - 30.2)}}\) (asimptote \(12,274.6\))
# ### Dead
# Start date 2020-03-23 (1st day with 0.1 dead per million)
# Latest number \\(139\\) on 2020-04-20
# Best fit exponential: \(8.07 \times 10^{0.044t}\) (doubling rate \(6.8\) days)
# Best fit sigmoid: \(\dfrac{176.3}{1 + 10^{-0.081 (t - 22.3)}}\) (asimptote \(176.3\))
# ### Active
# Start date 2020-03-11 (1st day with 1 active per million)
# Latest number \\(5,692\\) on 2020-04-20
# ## Colombia
# Population \\(50,882,891\\)
# ### Confirmed
# Start date 2020-03-16 (1st day with 1 confirmed per million)
# Latest number \\(3,977\\) on 2020-04-20
# Best fit exponential: \(298 \times 10^{0.032t}\) (doubling rate \(9.3\) days)
# Best fit sigmoid: \(\dfrac{4,615.7}{1 + 10^{-0.065 (t - 25.6)}}\) (asimptote \(4,615.7\))
# ### Dead
# Start date 2020-03-26 (1st day with 0.1 dead per million)
# Latest number \\(189\\) on 2020-04-20
# Best fit exponential: \(13.7 \times 10^{0.045t}\) (doubling rate \(6.7\) days)
# Best fit sigmoid: \(\dfrac{222.1}{1 + 10^{-0.090 (t - 18.8)}}\) (asimptote \(222.1\))
# ### Active
# Start date 2020-03-16 (1st day with 1 active per million)
# Latest number \\(2,984\\) on 2020-04-20
# ## Argentina
# Population \\(45,195,774\\)
# ### Confirmed
# Start date 2020-03-16 (1st day with 1 confirmed per million)
# Latest number \\(2,941\\) on 2020-04-20
# Best fit exponential: \(321 \times 10^{0.028t}\) (doubling rate \(10.7\) days)
# Best fit sigmoid: \(\dfrac{3,277.2}{1 + 10^{-0.062 (t - 23.0)}}\) (asimptote \(3,277.2\))
# ### Dead
# Start date 2020-03-24 (1st day with 0.1 dead per million)
# Latest number \\(136\\) on 2020-04-20
# Best fit exponential: \(16.5 \times 10^{0.035t}\) (doubling rate \(8.7\) days)
# Best fit sigmoid: \(\dfrac{170.3}{1 + 10^{-0.069 (t - 19.2)}}\) (asimptote \(170.3\))
# ### Active
# Start date 2020-03-16 (1st day with 1 active per million)
# Latest number \\(2,068\\) on 2020-04-20
# ## Uruguay
# Population \\(3,473,730\\)
# ### Confirmed
# Start date 2020-03-14 (1st day with 1 confirmed per million)
# Latest number \\(535\\) on 2020-04-20
# Best fit exponential: \(123 \times 10^{0.019t}\) (doubling rate \(16.2\) days)
# Best fit sigmoid: \(\dfrac{511.1}{1 + 10^{-0.081 (t - 15.0)}}\) (asimptote \(511.1\))
# ### Dead
# Start date 2020-03-29 (1st day with 0.1 dead per million)
# Latest number \\(10\\) on 2020-04-20
# Best fit exponential: \(2.88 \times 10^{0.025t}\) (doubling rate \(11.9\) days)
# Best fit sigmoid: \(\dfrac{9.1}{1 + 10^{-0.121 (t - 7.4)}}\) (asimptote \(9.1\))
# ### Active
# Start date 2020-03-14 (1st day with 1 active per million)
# Latest number \\(212\\) on 2020-04-20
# ## Bolivia
# Population \\(11,673,021\\)
# ### Confirmed
# Start date 2020-03-18 (1st day with 1 confirmed per million)
# Latest number \\(564\\) on 2020-04-20
# Best fit exponential: \(29.7 \times 10^{0.038t}\) (doubling rate \(7.9\) days)
# Best fit sigmoid: \(\dfrac{1,050.5}{1 + 10^{-0.053 (t - 33.0)}}\) (asimptote \(1,050.5\))
# ### Dead
# Start date 2020-03-30 (1st day with 0.1 dead per million)
# Latest number \\(33\\) on 2020-04-20
# Best fit exponential: \(7.18 \times 10^{0.033t}\) (doubling rate \(9.2\) days)
# Best fit sigmoid: \(\dfrac{37.8}{1 + 10^{-0.084 (t - 11.6)}}\) (asimptote \(37.8\))
# ### Active
# Start date 2020-03-18 (1st day with 1 active per million)
# Latest number \\(500\\) on 2020-04-20

# %% [markdown]
# # Recovering countries that had over 300 active cases at peak

# %%
draw_recovering_countries(get_recovering_countries_info(continent=nb_continent))
# Out:
# ## List of all recovering countries (the top 4 not covered above are also analyzed below)

# %% [markdown]
# # Please read the [README](https://github.com/ibudiselic/covid/blob/master/README.md) file in this repository.

# %%
# Load all the data and functionality.
# %run lib.ipynb

nb_continent = 'South America'
display(Markdown(f'# Analysis of the most affected countries in {nb_continent}'))
countries_to_plot = get_top_countries_by_relative_deaths(continent=nb_continent)
# Out:
# # Analysis of the most affected countries in South America

# %%
# %%javascript
# IPython.OutputArea.auto_scroll_threshold = 9999;

# %% [markdown]
# # Cross-country comparison over absolute dates

# %%
for series in ['confirmed', 'dead']:
    compare_countries_absolute_dates(series)
# Out:
# ## Confirmed
# ## Dead

# %% [markdown]
# # Cross-country comparison with approximately aligned start days

# %%
compare_countries_relative_dates('confirmed', start_info=(0.01, '10 confirmed per million'))
# Out:
# ## Confirmed

# %%
compare_countries_relative_dates('dead', start_info=(0.001, '1 death per million'))
# Out:
# ## Dead

# %% [markdown]
# # Per-country analysis with exponential and sigmoidal projections, and new cases analysis
#
# <span style="color:red;">
# IMPORTANT: The projections are only accurate if the fit is good (it often isn't), and assuming nothing changes
# going forward. The sigmoid is omitted if a reasonable fit can't be computed, but this still doesn't mean that
# the fit is good if it is shown.
# </span>
#
# The dashed lines show best fit projections from a few previous days for comparison.

# %%
for country in countries_to_plot:
    country_deep_dive(country)
# Out:
# ## Ecuador
# Population \\(17,643,054\\)
# ### Confirmed
# Start date 2020-03-14 (1st day with 1 confirmed per million)
# Latest number \\(10,850\\) on 2020-04-22
# Best fit exponential: \(718 \times 10^{0.031t}\) (doubling rate \(9.8\) days)
# Best fit sigmoid: \(\dfrac{12,780.2}{1 + 10^{-0.061 (t - 29.0)}}\) (asimptote \(12,780.2\))
# ### Dead
# Start date 2020-03-14 (1st day with 0.1 dead per million)
# Latest number \\(537\\) on 2020-04-22
# Best fit exponential: \(26.8 \times 10^{0.034t}\) (doubling rate \(8.9\) days)
# Best fit sigmoid: \(\dfrac{593.8}{1 + 10^{-0.073 (t - 28.6)}}\) (asimptote \(593.8\))
# ### Active
# Start date 2020-03-14 (1st day with 1 active per million)
# Latest number \\(9,051\\) on 2020-04-22
# ## Peru
# Population \\(32,971,854\\)
# ### Confirmed
# Start date 2020-03-14 (1st day with 1 confirmed per million)
# Latest number \\(19,250\\) on 2020-04-22
# Best fit exponential: \(268 \times 10^{0.047t}\) (doubling rate \(6.4\) days)
# Best fit sigmoid: \(\dfrac{23,550.3}{1 + 10^{-0.088 (t - 33.4)}}\) (asimptote \(23,550.3\))
# ### Dead
# Start date 2020-03-21 (1st day with 0.1 dead per million)
# Latest number \\(530\\) on 2020-04-22
# Best fit exponential: \(13.9 \times 10^{0.048t}\) (doubling rate \(6.2\) days)
# Best fit sigmoid: \(\dfrac{1,455.1}{1 + 10^{-0.059 (t - 37.2)}}\) (asimptote \(1,455.1\))
# ### Active
# Start date 2020-03-14 (1st day with 1 active per million)
# Latest number \\(11,693\\) on 2020-04-22
# ## Brazil
# Population \\(212,559,417\\)
# ### Confirmed
# Start date 2020-03-17 (1st day with 1 confirmed per million)
# Latest number \\(45,757\\) on 2020-04-22
# Best fit exponential: \(1.95 \times 10^{3} \times 10^{0.038t}\) (doubling rate \(7.9\) days)
# Best fit sigmoid: \(\dfrac{70,913.8}{1 + 10^{-0.058 (t - 32.7)}}\) (asimptote \(70,913.8\))
# ### Dead
# Start date 2020-03-22 (1st day with 0.1 dead per million)
# Latest number \\(2,906\\) on 2020-04-22
# Best fit exponential: \(125 \times 10^{0.044t}\) (doubling rate \(6.8\) days)
# Best fit sigmoid: \(\dfrac{4,014.7}{1 + 10^{-0.075 (t - 26.4)}}\) (asimptote \(4,014.7\))
# ### Active
# Start date 2020-03-17 (1st day with 1 active per million)
# Latest number \\(17,533\\) on 2020-04-22
# ## Chile
# Population \\(19,116,201\\)
# ### Confirmed
# Start date 2020-03-11 (1st day with 1 confirmed per million)
# Latest number \\(11,296\\) on 2020-04-22
# Best fit exponential: \(649 \times 10^{0.030t}\) (doubling rate \(10.0\) days)
# Best fit sigmoid: \(\dfrac{13,026.1}{1 + 10^{-0.060 (t - 31.2)}}\) (asimptote \(13,026.1\))
# ### Dead
# Start date 2020-03-23 (1st day with 0.1 dead per million)
# Latest number \\(160\\) on 2020-04-22
# Best fit exponential: \(9.35 \times 10^{0.041t}\) (doubling rate \(7.4\) days)
# Best fit sigmoid: \(\dfrac{197.2}{1 + 10^{-0.075 (t - 23.7)}}\) (asimptote \(197.2\))
# ### Active
# Start date 2020-03-11 (1st day with 1 active per million)
# Latest number \\(5,750\\) on 2020-04-22
# ## Colombia
# Population \\(50,882,891\\)
# ### Confirmed
# Start date 2020-03-16 (1st day with 1 confirmed per million)
# Latest number \\(4,356\\) on 2020-04-22
# Best fit exponential: \(328 \times 10^{0.031t}\) (doubling rate \(9.8\) days)
# Best fit sigmoid: \(\dfrac{5,063.4}{1 + 10^{-0.061 (t - 27.1)}}\) (asimptote \(5,063.4\))
# ### Dead
# Start date 2020-03-26 (1st day with 0.1 dead per million)
# Latest number \\(206\\) on 2020-04-22
# Best fit exponential: \(16 \times 10^{0.041t}\) (doubling rate \(7.3\) days)
# Best fit sigmoid: \(\dfrac{241.2}{1 + 10^{-0.084 (t - 19.7)}}\) (asimptote \(241.2\))
# ### Active
# Start date 2020-03-16 (1st day with 1 active per million)
# Latest number \\(3,280\\) on 2020-04-22
# ## Uruguay
# Population \\(3,473,730\\)
# ### Confirmed
# Start date 2020-03-14 (1st day with 1 confirmed per million)
# Latest number \\(543\\) on 2020-04-22
# Best fit exponential: \(130 \times 10^{0.017t}\) (doubling rate \(17.4\) days)
# Best fit sigmoid: \(\dfrac{520.2}{1 + 10^{-0.078 (t - 15.3)}}\) (asimptote \(520.2\))
# ### Dead
# Start date 2020-03-29 (1st day with 0.1 dead per million)
# Latest number \\(12\\) on 2020-04-22
# Best fit exponential: \(2.93 \times 10^{0.025t}\) (doubling rate \(12.2\) days)
# Best fit sigmoid: \(\dfrac{10.8}{1 + 10^{-0.082 (t - 9.6)}}\) (asimptote \(10.8\))
# ### Active
# Start date 2020-03-14 (1st day with 1 active per million)
# Latest number \\(207\\) on 2020-04-22
# ## Argentina
# Population \\(45,195,774\\)
# ### Confirmed
# Start date 2020-03-16 (1st day with 1 confirmed per million)
# Latest number \\(3,144\\) on 2020-04-22
# Best fit exponential: \(350 \times 10^{0.026t}\) (doubling rate \(11.4\) days)
# Best fit sigmoid: \(\dfrac{3,478.8}{1 + 10^{-0.058 (t - 24.0)}}\) (asimptote \(3,478.8\))
# ### Dead
# Start date 2020-03-24 (1st day with 0.1 dead per million)
# Latest number \\(152\\) on 2020-04-22
# Best fit exponential: \(18.1 \times 10^{0.032t}\) (doubling rate \(9.3\) days)
# Best fit sigmoid: \(\dfrac{182.1}{1 + 10^{-0.066 (t - 20.1)}}\) (asimptote \(182.1\))
# ### Active
# Start date 2020-03-16 (1st day with 1 active per million)
# Latest number \\(2,120\\) on 2020-04-22
# ## Bolivia
# Population \\(11,673,021\\)
# ### Confirmed
# Start date 2020-03-18 (1st day with 1 confirmed per million)
# Latest number \\(609\\) on 2020-04-22
# Best fit exponential: \(33.4 \times 10^{0.036t}\) (doubling rate \(8.3\) days)
# Best fit sigmoid: \(\dfrac{1,029.9}{1 + 10^{-0.054 (t - 32.7)}}\) (asimptote \(1,029.9\))
# ### Dead
# Start date 2020-03-30 (1st day with 0.1 dead per million)
# Latest number \\(37\\) on 2020-04-22
# Best fit exponential: \(7.79 \times 10^{0.030t}\) (doubling rate \(10.1\) days)
# Best fit sigmoid: \(\dfrac{39.2}{1 + 10^{-0.081 (t - 12.0)}}\) (asimptote \(39.2\))
# ### Active
# Start date 2020-03-18 (1st day with 1 active per million)
# Latest number \\(528\\) on 2020-04-22

# %% [markdown]
# # Recovering countries that had over 300 active cases at peak

# %%
draw_recovering_countries(get_recovering_countries_info(continent=nb_continent))
# Out:
# ## List of all recovering countries (the top 4 not covered above are also analyzed below)

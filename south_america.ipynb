# %% [markdown]
# # Please read the [README](https://github.com/ibudiselic/covid/blob/master/README.md) file in this repository.

# %%
# Load all the data and functionality.
# %run lib.ipynb

nb_continent = 'South America'
display(Markdown(f'# Analysis of the most affected countries in {nb_continent}'))
countries_to_plot = get_top_countries_by_relative_deaths(continent=nb_continent)
# Out:
# # Analysis of the most affected countries in South America

# %%
# %%javascript
# IPython.OutputArea.auto_scroll_threshold = 9999;

# %% [markdown]
# # Cross-country comparison over absolute dates

# %%
for series in ['confirmed', 'dead']:
    compare_countries_absolute_dates(series)
# Out:
# ## Confirmed
# ## Dead

# %% [markdown]
# # Cross-country comparison with approximately aligned start days

# %%
compare_countries_relative_dates('confirmed', start_info=(0.01, '10 confirmed per million'))
# Out:
# ## Confirmed

# %%
compare_countries_relative_dates('dead', start_info=(0.001, '1 death per million'))
# Out:
# ## Dead

# %% [markdown]
# # Per-country analysis with exponential and sigmoidal projections, and new cases analysis
#
# <span style="color:red;">
# IMPORTANT: The projections are only accurate if the fit is good (it often isn't), and assuming nothing changes
# going forward. The sigmoid is omitted if a reasonable fit can't be computed, but this still doesn't mean that
# the fit is good if it is shown.
# </span>
#
# The dashed lines show best fit projections from a few previous days for comparison.

# %%
for country in countries_to_plot:
    country_deep_dive(country)
# Out:
# ## Ecuador
# Population \\(17,643,054\\)
# ### Confirmed
# Start date 2020-03-14 (1st day with 1 confirmed per million)
# Latest number \\(22,719\\) on 2020-04-24
# Best fit exponential: \(541 \times 10^{0.035t}\) (doubling rate \(8.6\) days)
# ### Dead
# Start date 2020-03-14 (1st day with 0.1 dead per million)
# Latest number \\(576\\) on 2020-04-24
# Best fit exponential: \(31.1 \times 10^{0.032t}\) (doubling rate \(9.5\) days)
# Best fit sigmoid: \(\dfrac{630.7}{1 + 10^{-0.070 (t - 29.5)}}\) (asimptote \(630.7\))
# ### Active
# Start date 2020-03-14 (1st day with 1 active per million)
# Latest number \\(20,777\\) on 2020-04-24
# ## Peru
# Population \\(32,971,854\\)
# ### Confirmed
# Start date 2020-03-14 (1st day with 1 confirmed per million)
# Latest number \\(21,648\\) on 2020-04-24
# Best fit exponential: \(344 \times 10^{0.044t}\) (doubling rate \(6.9\) days)
# Best fit sigmoid: \(\dfrac{26,781.3}{1 + 10^{-0.081 (t - 34.9)}}\) (asimptote \(26,781.3\))
# ### Dead
# Start date 2020-03-21 (1st day with 0.1 dead per million)
# Latest number \\(634\\) on 2020-04-24
# Best fit exponential: \(15.4 \times 10^{0.047t}\) (doubling rate \(6.5\) days)
# Best fit sigmoid: \(\dfrac{1,621.2}{1 + 10^{-0.058 (t - 38.5)}}\) (asimptote \(1,621.2\))
# ### Active
# Start date 2020-03-14 (1st day with 1 active per million)
# Latest number \\(13,518\\) on 2020-04-24
# ## Brazil
# Population \\(212,559,417\\)
# ### Confirmed
# Start date 2020-03-17 (1st day with 1 confirmed per million)
# Latest number \\(54,043\\) on 2020-04-24
# Best fit exponential: \(2.12 \times 10^{3} \times 10^{0.037t}\) (doubling rate \(8.2\) days)
# Best fit sigmoid: \(\dfrac{86,412.7}{1 + 10^{-0.054 (t - 35.6)}}\) (asimptote \(86,412.7\))
# ### Dead
# Start date 2020-03-22 (1st day with 0.1 dead per million)
# Latest number \\(3,704\\) on 2020-04-24
# Best fit exponential: \(134 \times 10^{0.043t}\) (doubling rate \(7.0\) days)
# Best fit sigmoid: \(\dfrac{5,515.2}{1 + 10^{-0.065 (t - 30.4)}}\) (asimptote \(5,515.2\))
# ### Active
# Start date 2020-03-17 (1st day with 1 active per million)
# Latest number \\(22,684\\) on 2020-04-24
# ## Chile
# Population \\(19,116,201\\)
# ### Confirmed
# Start date 2020-03-11 (1st day with 1 confirmed per million)
# Latest number \\(12,306\\) on 2020-04-24
# Best fit exponential: \(724 \times 10^{0.028t}\) (doubling rate \(10.6\) days)
# Best fit sigmoid: \(\dfrac{14,030.9}{1 + 10^{-0.057 (t - 32.4)}}\) (asimptote \(14,030.9\))
# ### Dead
# Start date 2020-03-23 (1st day with 0.1 dead per million)
# Latest number \\(174\\) on 2020-04-24
# Best fit exponential: \(10.8 \times 10^{0.038t}\) (doubling rate \(7.9\) days)
# Best fit sigmoid: \(\dfrac{215.6}{1 + 10^{-0.071 (t - 24.9)}}\) (asimptote \(215.6\))
# ### Active
# Start date 2020-03-11 (1st day with 1 active per million)
# Latest number \\(5,805\\) on 2020-04-24
# ## Colombia
# Population \\(50,882,891\\)
# ### Confirmed
# Start date 2020-03-16 (1st day with 1 confirmed per million)
# Latest number \\(4,881\\) on 2020-04-24
# Best fit exponential: \(355 \times 10^{0.029t}\) (doubling rate \(10.3\) days)
# Best fit sigmoid: \(\dfrac{5,717.2}{1 + 10^{-0.056 (t - 29.1)}}\) (asimptote \(5,717.2\))
# ### Dead
# Start date 2020-03-26 (1st day with 0.1 dead per million)
# Latest number \\(225\\) on 2020-04-24
# Best fit exponential: \(18.6 \times 10^{0.038t}\) (doubling rate \(8.0\) days)
# Best fit sigmoid: \(\dfrac{257.5}{1 + 10^{-0.080 (t - 20.5)}}\) (asimptote \(257.5\))
# ### Active
# Start date 2020-03-16 (1st day with 1 active per million)
# Latest number \\(3,653\\) on 2020-04-24
# ## Argentina
# Population \\(45,195,774\\)
# ### Confirmed
# Start date 2020-03-16 (1st day with 1 confirmed per million)
# Latest number \\(3,607\\) on 2020-04-24
# Best fit exponential: \(368 \times 10^{0.025t}\) (doubling rate \(11.8\) days)
# Best fit sigmoid: \(\dfrac{3,989.6}{1 + 10^{-0.052 (t - 26.5)}}\) (asimptote \(3,989.6\))
# ### Dead
# Start date 2020-03-24 (1st day with 0.1 dead per million)
# Latest number \\(176\\) on 2020-04-24
# Best fit exponential: \(19.2 \times 10^{0.031t}\) (doubling rate \(9.8\) days)
# Best fit sigmoid: \(\dfrac{211.4}{1 + 10^{-0.059 (t - 22.4)}}\) (asimptote \(211.4\))
# ### Active
# Start date 2020-03-16 (1st day with 1 active per million)
# Latest number \\(2,455\\) on 2020-04-24
# ## Bolivia
# Population \\(11,673,021\\)
# ### Confirmed
# Start date 2020-03-18 (1st day with 1 confirmed per million)
# Latest number \\(807\\) on 2020-04-24
# Best fit exponential: \(33.3 \times 10^{0.036t}\) (doubling rate \(8.3\) days)
# Best fit sigmoid: \(\dfrac{1,774.0}{1 + 10^{-0.046 (t - 40.9)}}\) (asimptote \(1,774.0\))
# ### Dead
# Start date 2020-03-30 (1st day with 0.1 dead per million)
# Latest number \\(44\\) on 2020-04-24
# Best fit exponential: \(7.91 \times 10^{0.029t}\) (doubling rate \(10.3\) days)
# Best fit sigmoid: \(\dfrac{49.4}{1 + 10^{-0.063 (t - 15.4)}}\) (asimptote \(49.4\))
# ### Active
# Start date 2020-03-18 (1st day with 1 active per million)
# Latest number \\(709\\) on 2020-04-24
# ## Uruguay
# Population \\(3,473,730\\)
# ### Confirmed
# Start date 2020-03-14 (1st day with 1 confirmed per million)
# Latest number \\(563\\) on 2020-04-24
# Best fit exponential: \(137 \times 10^{0.016t}\) (doubling rate \(18.6\) days)
# Best fit sigmoid: \(\dfrac{531.4}{1 + 10^{-0.075 (t - 15.7)}}\) (asimptote \(531.4\))
# ### Dead
# Start date 2020-03-29 (1st day with 0.1 dead per million)
# Latest number \\(12\\) on 2020-04-24
# Best fit exponential: \(3.05 \times 10^{0.023t}\) (doubling rate \(12.9\) days)
# Best fit sigmoid: \(\dfrac{12.5}{1 + 10^{-0.065 (t - 11.8)}}\) (asimptote \(12.5\))
# ### Active
# Start date 2020-03-14 (1st day with 1 active per million)
# Latest number \\(182\\) on 2020-04-24

# %% [markdown]
# # Recovering countries that had over 300 active cases at peak

# %%
draw_recovering_countries(get_recovering_countries_info(continent=nb_continent))
# Out:
# ## List of all recovering countries (the top 4 not covered above are also analyzed below)
# Uruguay recovered 41%

# %% [markdown]
# # Please read the [README](https://github.com/ibudiselic/covid/blob/master/README.md) file in this repository.

# %%
# Load all the data and functionality.
# %run lib.ipynb

nb_continent = 'South America'
display(Markdown(f'# Analysis of the most affected countries in {nb_continent}'))
countries_to_plot = get_top_countries_by_relative_deaths(continent=nb_continent)
# Out:
# # Analysis of the most affected countries in South America

# %%
# %%javascript
# IPython.OutputArea.auto_scroll_threshold = 9999;

# %% [markdown]
# # Cross-country comparison over absolute dates

# %%
for series in ['confirmed', 'dead']:
    compare_countries_absolute_dates(series)
# Out:
# ## Confirmed
# ## Dead

# %% [markdown]
# # Cross-country comparison with approximately aligned start days

# %%
compare_countries_relative_dates('confirmed', start_info=(0.01, '10 confirmed per million'))
# Out:
# ## Confirmed

# %%
compare_countries_relative_dates('dead', start_info=(0.001, '1 death per million'))
# Out:
# ## Dead

# %% [markdown]
# # Per-country analysis with exponential and sigmoidal projections, and new cases analysis
#
# <span style="color:red;">
# IMPORTANT: The projections are only accurate if the fit is good (it often isn't), and assuming nothing changes
# going forward. The sigmoid is omitted if a reasonable fit can't be computed, but this still doesn't mean that
# the fit is good if it is shown.
# </span>
#
# The dashed lines show best fit projections from a few previous days for comparison.

# %%
for country in countries_to_plot:
    country_deep_dive(country)
# Out:
# ## Ecuador
# Population \\(17,643,054\\)
# ### Confirmed
# Start date 2020-03-14 (1st day with 1 confirmed per million)
# Latest number \\(23,240\\) on 2020-04-27
# Best fit exponential: \(375 \times 10^{0.040t}\) (doubling rate \(7.6\) days)
# ### Dead
# Start date 2020-03-14 (1st day with 0.1 dead per million)
# Latest number \\(663\\) on 2020-04-27
# Best fit exponential: \(38.5 \times 10^{0.028t}\) (doubling rate \(10.6\) days)
# Best fit sigmoid: \(\dfrac{671.3}{1 + 10^{-0.066 (t - 30.5)}}\) (asimptote \(671.3\))
# ### Active
# Start date 2020-03-14 (1st day with 1 active per million)
# Latest number \\(21,020\\) on 2020-04-27
# ## Peru
# Population \\(32,971,854\\)
# ### Confirmed
# Start date 2020-03-14 (1st day with 1 confirmed per million)
# Latest number \\(28,699\\) on 2020-04-27
# Best fit exponential: \(411 \times 10^{0.042t}\) (doubling rate \(7.2\) days)
# Best fit sigmoid: \(\dfrac{42,492.3}{1 + 10^{-0.064 (t - 40.6)}}\) (asimptote \(42,492.3\))
# ### Dead
# Start date 2020-03-21 (1st day with 0.1 dead per million)
# Latest number \\(782\\) on 2020-04-27
# Best fit exponential: \(18.8 \times 10^{0.043t}\) (doubling rate \(6.9\) days)
# Best fit sigmoid: \(\dfrac{1,610.8}{1 + 10^{-0.058 (t - 38.3)}}\) (asimptote \(1,610.8\))
# ### Active
# Start date 2020-03-14 (1st day with 1 active per million)
# Latest number \\(19,492\\) on 2020-04-27
# ## Brazil
# Population \\(212,559,417\\)
# ### Confirmed
# Start date 2020-03-17 (1st day with 1 confirmed per million)
# Latest number \\(67,446\\) on 2020-04-27
# Best fit exponential: \(2.31 \times 10^{3} \times 10^{0.035t}\) (doubling rate \(8.5\) days)
# Best fit sigmoid: \(\dfrac{130,470.2}{1 + 10^{-0.048 (t - 41.9)}}\) (asimptote \(130,470.2\))
# ### Dead
# Start date 2020-03-22 (1st day with 0.1 dead per million)
# Latest number \\(4,603\\) on 2020-04-27
# Best fit exponential: \(152 \times 10^{0.041t}\) (doubling rate \(7.4\) days)
# Best fit sigmoid: \(\dfrac{8,367.1}{1 + 10^{-0.056 (t - 35.8)}}\) (asimptote \(8,367.1\))
# ### Active
# Start date 2020-03-17 (1st day with 1 active per million)
# Latest number \\(31,701\\) on 2020-04-27
# ## Chile
# Population \\(19,116,201\\)
# ### Confirmed
# Start date 2020-03-11 (1st day with 1 confirmed per million)
# Latest number \\(13,813\\) on 2020-04-27
# Best fit exponential: \(837 \times 10^{0.026t}\) (doubling rate \(11.4\) days)
# Best fit sigmoid: \(\dfrac{15,821.6}{1 + 10^{-0.052 (t - 34.6)}}\) (asimptote \(15,821.6\))
# ### Dead
# Start date 2020-03-23 (1st day with 0.1 dead per million)
# Latest number \\(198\\) on 2020-04-27
# Best fit exponential: \(13.3 \times 10^{0.034t}\) (doubling rate \(8.9\) days)
# Best fit sigmoid: \(\dfrac{233.9}{1 + 10^{-0.067 (t - 26.0)}}\) (asimptote \(233.9\))
# ### Active
# Start date 2020-03-11 (1st day with 1 active per million)
# Latest number \\(6,288\\) on 2020-04-27
# ## Colombia
# Population \\(50,882,891\\)
# ### Confirmed
# Start date 2020-03-16 (1st day with 1 confirmed per million)
# Latest number \\(5,597\\) on 2020-04-27
# Best fit exponential: \(393 \times 10^{0.028t}\) (doubling rate \(10.9\) days)
# Best fit sigmoid: \(\dfrac{7,064.4}{1 + 10^{-0.049 (t - 32.9)}}\) (asimptote \(7,064.4\))
# ### Dead
# Start date 2020-03-26 (1st day with 0.1 dead per million)
# Latest number \\(253\\) on 2020-04-27
# Best fit exponential: \(22.8 \times 10^{0.033t}\) (doubling rate \(9.0\) days)
# Best fit sigmoid: \(\dfrac{280.6}{1 + 10^{-0.074 (t - 21.7)}}\) (asimptote \(280.6\))
# ### Active
# Start date 2020-03-16 (1st day with 1 active per million)
# Latest number \\(4,134\\) on 2020-04-27
# ## Bolivia
# Population \\(11,673,021\\)
# ### Confirmed
# Start date 2020-03-18 (1st day with 1 confirmed per million)
# Latest number \\(1,014\\) on 2020-04-27
# Best fit exponential: \(32.9 \times 10^{0.036t}\) (doubling rate \(8.3\) days)
# Best fit sigmoid: \(\dfrac{5,523.7}{1 + 10^{-0.040 (t - 57.5)}}\) (asimptote \(5,523.7\))
# ### Dead
# Start date 2020-03-30 (1st day with 0.1 dead per million)
# Latest number \\(53\\) on 2020-04-27
# Best fit exponential: \(8.17 \times 10^{0.028t}\) (doubling rate \(10.6\) days)
# Best fit sigmoid: \(\dfrac{75.8}{1 + 10^{-0.047 (t - 22.8)}}\) (asimptote \(75.8\))
# ### Active
# Start date 2020-03-18 (1st day with 1 active per million)
# Latest number \\(863\\) on 2020-04-27
# ## Argentina
# Population \\(45,195,774\\)
# ### Confirmed
# Start date 2020-03-16 (1st day with 1 confirmed per million)
# Latest number \\(4,003\\) on 2020-04-27
# Best fit exponential: \(397 \times 10^{0.024t}\) (doubling rate \(12.5\) days)
# Best fit sigmoid: \(\dfrac{4,837.0}{1 + 10^{-0.045 (t - 30.4)}}\) (asimptote \(4,837.0\))
# ### Dead
# Start date 2020-03-24 (1st day with 0.1 dead per million)
# Latest number \\(197\\) on 2020-04-27
# Best fit exponential: \(21.2 \times 10^{0.029t}\) (doubling rate \(10.5\) days)
# Best fit sigmoid: \(\dfrac{253.4}{1 + 10^{-0.052 (t - 25.5)}}\) (asimptote \(253.4\))
# ### Active
# Start date 2020-03-16 (1st day with 1 active per million)
# Latest number \\(2,666\\) on 2020-04-27
# ## Uruguay
# Population \\(3,473,730\\)
# ### Confirmed
# Start date 2020-03-14 (1st day with 1 confirmed per million)
# Latest number \\(620\\) on 2020-04-27
# Best fit exponential: \(145 \times 10^{0.015t}\) (doubling rate \(20.0\) days)
# Best fit sigmoid: \(\dfrac{559.6}{1 + 10^{-0.067 (t - 16.6)}}\) (asimptote \(559.6\))
# ### Dead
# Start date 2020-03-29 (1st day with 0.1 dead per million)
# Latest number \\(15\\) on 2020-04-27
# Best fit exponential: \(3.04 \times 10^{0.023t}\) (doubling rate \(12.8\) days)
# Best fit sigmoid: \(\dfrac{21.6}{1 + 10^{-0.040 (t - 22.6)}}\) (asimptote \(21.6\))
# ### Active
# Start date 2020-03-14 (1st day with 1 active per million)
# Latest number \\(219\\) on 2020-04-27

# %% [markdown]
# # Recovering countries that had over 300 active cases at peak

# %%
draw_recovering_countries(get_recovering_countries_info(continent=nb_continent))
# Out:
# ## List of all recovering countries (the top 4 not covered above are also analyzed below)

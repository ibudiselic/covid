# %% [markdown]
# # Please read the [README](https://github.com/ibudiselic/covid/blob/master/README.md) file in this repository.

# %%
# Load all the data and functionality.
# %run lib.ipynb

nb_continent = 'South America'
display(Markdown(f'# Analysis of the most affected countries in {nb_continent}'))
countries_to_plot = get_top_countries_by_relative_deaths(continent=nb_continent)
# Out:
# # Analysis of the most affected countries in South America

# %%
# %%javascript
# IPython.OutputArea.auto_scroll_threshold = 9999;

# %% [markdown]
# # Cross-country comparison over absolute dates

# %%
for series in ['confirmed', 'dead']:
    compare_countries_absolute_dates(series)
# Out:
# ## Confirmed
# ## Dead

# %% [markdown]
# # Cross-country comparison with approximately aligned start days

# %%
compare_countries_relative_dates('confirmed', start_info=(0.01, '10 confirmed per million'))
# Out:
# ## Confirmed

# %%
compare_countries_relative_dates('dead', start_info=(0.001, '1 death per million'))
# Out:
# ## Dead

# %% [markdown]
# # Per-country analysis with exponential and sigmoidal projections, and new cases analysis
#
# <span style="color:red;">
# IMPORTANT: The projections are only accurate if the fit is good (it often isn't), and assuming nothing changes
# going forward. The sigmoid is omitted if a reasonable fit can't be computed, but this still doesn't mean that
# the fit is good if it is shown.
# </span>
#
# The dashed lines show best fit projections from a few previous days for comparison.

# %%
for country in countries_to_plot:
    country_deep_dive(country)
# Out:
# ## Ecuador
# Population \\(17,643,054\\)
# ### Confirmed
# Start date 2020-03-14 (1st day with 1 confirmed per million)
# Latest number \\(10,398\\) on 2020-04-21
# Best fit exponential: \(678 \times 10^{0.032t}\) (doubling rate \(9.5\) days)
# Best fit sigmoid: \(\dfrac{12,409.4}{1 + 10^{-0.062 (t - 28.5)}}\) (asimptote \(12,409.4\))
# ### Dead
# Start date 2020-03-14 (1st day with 0.1 dead per million)
# Latest number \\(520\\) on 2020-04-21
# Best fit exponential: \(24.7 \times 10^{0.035t}\) (doubling rate \(8.5\) days)
# Best fit sigmoid: \(\dfrac{575.7}{1 + 10^{-0.075 (t - 28.1)}}\) (asimptote \(575.7\))
# ### Active
# Start date 2020-03-14 (1st day with 1 active per million)
# Latest number \\(8,671\\) on 2020-04-21
# ## Peru
# Population \\(32,971,854\\)
# ### Confirmed
# Start date 2020-03-14 (1st day with 1 confirmed per million)
# Latest number \\(17,837\\) on 2020-04-21
# Best fit exponential: \(235 \times 10^{0.049t}\) (doubling rate \(6.1\) days)
# Best fit sigmoid: \(\dfrac{22,061.8}{1 + 10^{-0.092 (t - 32.7)}}\) (asimptote \(22,061.8\))
# ### Dead
# Start date 2020-03-21 (1st day with 0.1 dead per million)
# Latest number \\(484\\) on 2020-04-21
# Best fit exponential: \(13.3 \times 10^{0.049t}\) (doubling rate \(6.1\) days)
# Best fit sigmoid: \(\dfrac{1,297.0}{1 + 10^{-0.060 (t - 36.0)}}\) (asimptote \(1,297.0\))
# ### Active
# Start date 2020-03-14 (1st day with 1 active per million)
# Latest number \\(10,371\\) on 2020-04-21
# ## Brazil
# Population \\(212,559,417\\)
# ### Confirmed
# Start date 2020-03-17 (1st day with 1 confirmed per million)
# Latest number \\(43,079\\) on 2020-04-21
# Best fit exponential: \(1.83 \times 10^{3} \times 10^{0.039t}\) (doubling rate \(7.7\) days)
# Best fit sigmoid: \(\dfrac{68,870.7}{1 + 10^{-0.059 (t - 32.3)}}\) (asimptote \(68,870.7\))
# ### Dead
# Start date 2020-03-22 (1st day with 0.1 dead per million)
# Latest number \\(2,741\\) on 2020-04-21
# Best fit exponential: \(113 \times 10^{0.046t}\) (doubling rate \(6.5\) days)
# Best fit sigmoid: \(\dfrac{4,010.7}{1 + 10^{-0.075 (t - 26.4)}}\) (asimptote \(4,010.7\))
# ### Active
# Start date 2020-03-17 (1st day with 1 active per million)
# Latest number \\(17,347\\) on 2020-04-21
# ## Chile
# Population \\(19,116,201\\)
# ### Confirmed
# Start date 2020-03-11 (1st day with 1 confirmed per million)
# Latest number \\(10,832\\) on 2020-04-21
# Best fit exponential: \(610 \times 10^{0.031t}\) (doubling rate \(9.7\) days)
# Best fit sigmoid: \(\dfrac{12,623.4}{1 + 10^{-0.062 (t - 30.7)}}\) (asimptote \(12,623.4\))
# ### Dead
# Start date 2020-03-23 (1st day with 0.1 dead per million)
# Latest number \\(147\\) on 2020-04-21
# Best fit exponential: \(8.77 \times 10^{0.042t}\) (doubling rate \(7.1\) days)
# Best fit sigmoid: \(\dfrac{183.2}{1 + 10^{-0.079 (t - 22.8)}}\) (asimptote \(183.2\))
# ### Active
# Start date 2020-03-11 (1st day with 1 active per million)
# Latest number \\(5,716\\) on 2020-04-21
# ## Colombia
# Population \\(50,882,891\\)
# ### Confirmed
# Start date 2020-03-16 (1st day with 1 confirmed per million)
# Latest number \\(4,149\\) on 2020-04-21
# Best fit exponential: \(313 \times 10^{0.031t}\) (doubling rate \(9.6\) days)
# Best fit sigmoid: \(\dfrac{4,823.7}{1 + 10^{-0.063 (t - 26.3)}}\) (asimptote \(4,823.7\))
# ### Dead
# Start date 2020-03-26 (1st day with 0.1 dead per million)
# Latest number \\(196\\) on 2020-04-21
# Best fit exponential: \(14.8 \times 10^{0.043t}\) (doubling rate \(7.0\) days)
# Best fit sigmoid: \(\dfrac{231.9}{1 + 10^{-0.087 (t - 19.3)}}\) (asimptote \(231.9\))
# ### Active
# Start date 2020-03-16 (1st day with 1 active per million)
# Latest number \\(3,149\\) on 2020-04-21
# ## Argentina
# Population \\(45,195,774\\)
# ### Confirmed
# Start date 2020-03-16 (1st day with 1 confirmed per million)
# Latest number \\(3,031\\) on 2020-04-21
# Best fit exponential: \(336 \times 10^{0.027t}\) (doubling rate \(11.1\) days)
# Best fit sigmoid: \(\dfrac{3,373.4}{1 + 10^{-0.060 (t - 23.5)}}\) (asimptote \(3,373.4\))
# ### Dead
# Start date 2020-03-24 (1st day with 0.1 dead per million)
# Latest number \\(147\\) on 2020-04-21
# Best fit exponential: \(17.3 \times 10^{0.033t}\) (doubling rate \(9.0\) days)
# Best fit sigmoid: \(\dfrac{177.0}{1 + 10^{-0.067 (t - 19.7)}}\) (asimptote \(177.0\))
# ### Active
# Start date 2020-03-16 (1st day with 1 active per million)
# Latest number \\(2,044\\) on 2020-04-21
# ## Uruguay
# Population \\(3,473,730\\)
# ### Confirmed
# Start date 2020-03-14 (1st day with 1 confirmed per million)
# Latest number \\(535\\) on 2020-04-21
# Best fit exponential: \(127 \times 10^{0.018t}\) (doubling rate \(16.8\) days)
# Best fit sigmoid: \(\dfrac{515.6}{1 + 10^{-0.079 (t - 15.2)}}\) (asimptote \(515.6\))
# ### Dead
# Start date 2020-03-29 (1st day with 0.1 dead per million)
# Latest number \\(11\\) on 2020-04-21
# Best fit exponential: \(2.92 \times 10^{0.025t}\) (doubling rate \(12.1\) days)
# Best fit sigmoid: \(\dfrac{9.7}{1 + 10^{-0.102 (t - 8.1)}}\) (asimptote \(9.7\))
# ### Active
# Start date 2020-03-14 (1st day with 1 active per million)
# Latest number \\(211\\) on 2020-04-21
# ## Bolivia
# Population \\(11,673,021\\)
# ### Confirmed
# Start date 2020-03-18 (1st day with 1 confirmed per million)
# Latest number \\(598\\) on 2020-04-21
# Best fit exponential: \(31.1 \times 10^{0.037t}\) (doubling rate \(8.1\) days)
# Best fit sigmoid: \(\dfrac{1,086.3}{1 + 10^{-0.053 (t - 33.5)}}\) (asimptote \(1,086.3\))
# ### Dead
# Start date 2020-03-30 (1st day with 0.1 dead per million)
# Latest number \\(34\\) on 2020-04-21
# Best fit exponential: \(7.55 \times 10^{0.031t}\) (doubling rate \(9.8\) days)
# Best fit sigmoid: \(\dfrac{37.8}{1 + 10^{-0.084 (t - 11.6)}}\) (asimptote \(37.8\))
# ### Active
# Start date 2020-03-18 (1st day with 1 active per million)
# Latest number \\(527\\) on 2020-04-21

# %% [markdown]
# # Recovering countries that had over 300 active cases at peak

# %%
draw_recovering_countries(get_recovering_countries_info(continent=nb_continent))
# Out:
# ## List of all recovering countries (the top 4 not covered above are also analyzed below)
